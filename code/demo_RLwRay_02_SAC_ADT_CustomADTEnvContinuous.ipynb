# %% [markdown]
# # SAC with CustomADTEnvContinuous

# %%
import datetime,gym,time,os,psutil,ray
import numpy as np
import tensorflow as tf
from util import gpu_sess,suppress_tf_warning,tic,toc
from sac import ReplayBuffer,create_sac_model,create_sac_graph,\
    save_sac_model_and_buffers,restore_sac_model_and_buffers
np.set_printoptions(precision=2)
suppress_tf_warning() # suppress warning 
gym.logger.set_level(40) # gym logger 

from episci.environment_wrappers.tactical_action_adt_env_continuous import CustomADTEnvContinuous
from episci.agents.utils.constants import Agents, RewardType
print ("Packaged loaded. TF version is [%s]."%(tf.__version__))
# Out:
# Packaged loaded. TF version is [1.15.0].

# %% [markdown]
# ### Rollout Worker

# %%
action_length = 5
def get_env():
    from episci.environment_wrappers.tactical_action_adt_env_continuous import CustomADTEnvContinuous
    from episci.agents.utils.constants import Agents, RewardType
    
    red_distribution = {
        Agents.SPOT_4G: 0.15,
        Agents.SPOT_5G: 0.30,
        Agents.SPOT_RANDOM: 0.45,
        Agents.EXPERT_SYSTEM_TRIAL_2: 0.6,
        Agents.EXPERT_SYSTEM_TRIAL_3_SCRIMMAGE_4: 0.75,
        Agents.EXPERT_SYSTEM: 1.0
    }
    env_config = {
        "red_distribution": red_distribution,
        "reward_type": RewardType.SHAPED
    }
    return CustomADTEnvContinuous(env_config,action_length=action_length)

def get_eval_env():
    # from episci.environment_wrappers.tactical_action_adt_env_continuous import CustomADTEnvContinuous
    # from episci.agents.utils.constants import Agents, RewardType
    red_distribution = {
        Agents.SPOT_4G: 0.15,
        Agents.SPOT_5G: 0.30,
        Agents.SPOT_RANDOM: 0.45,
        Agents.EXPERT_SYSTEM_TRIAL_2: 0.6,
        Agents.EXPERT_SYSTEM_TRIAL_3_SCRIMMAGE_4: 0.75,
        Agents.EXPERT_SYSTEM: 1.0
    }
    env_config = {
        "red_distribution": red_distribution,
        "reward_type": RewardType.SHAPED
    }
    return CustomADTEnvContinuous(env_config,action_length=action_length)

# %%
class RolloutWorkerClass(object):
    """
    Worker without RAY (for update purposes)
    """
    def __init__(self,hdims=[256,256],actv=tf.nn.relu,
                 lr=1e-3,gamma=0.99,alpha_q=0.1,alpha_pi=0.1,polyak=0.995,epsilon=1e-2,
                 seed=1):
        self.seed = seed
        # Each worker should maintain its own environment
        import gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) 
        self.env = get_eval_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        _ = self.env.reset()
        
        # Create SAC model and computational graph 
        self.model,self.sess = create_sac_model(
            odim=self.odim,adim=self.adim,hdims=hdims,actv=actv)
        self.step_ops,self.target_init = \
            create_sac_graph(self.model,lr=lr,gamma=gamma,alpha_q=alpha_q,alpha_pi=alpha_pi,
                             polyak=polyak,epsilon=epsilon)
        
        # Initialize model 
        tf.set_random_seed(self.seed)
        np.random.seed(self.seed)
        self.sess.run(tf.global_variables_initializer())
        self.sess.run(self.target_init)
    
    def get_action(self,o,deterministic=False):
        act_op = self.model['mu'] if deterministic else self.model['pi']
        return self.sess.run(act_op, feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]

    def get_weights(self):
        """
        Get weights
        """
        weight_vals = self.sess.run(self.model['main_vars'])
        return weight_vals
    
@ray.remote
class RayRolloutWorkerClass(object):
    """
    Rollout Worker with RAY
    """
    def __init__(self,worker_id=0,hdims=[256,256],actv=tf.nn.relu,
                 ep_len_rollout=1000):
        # Parse
        self.worker_id = worker_id
        self.ep_len_rollout = ep_len_rollout
        # Each worker should maintain its own environment
        import gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) 
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        _ = self.env.reset()
        
        # Replay buffers to pass
        self.o_buffer = np.zeros((self.ep_len_rollout,self.odim))
        self.a_buffer = np.zeros((self.ep_len_rollout,self.adim))
        self.r_buffer = np.zeros((self.ep_len_rollout))
        self.o2_buffer = np.zeros((self.ep_len_rollout,self.odim))
        self.d_buffer = np.zeros((self.ep_len_rollout))
        
        # Create SAC model
        self.model,self.sess = create_sac_model(
            odim=self.odim,adim=self.adim,hdims=hdims,actv=actv)
        self.sess.run(tf.global_variables_initializer())
        print ("Ray Worker [%d] Ready."%(self.worker_id))
        
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True
        
        # Flag to initialize rollout
        self.FIRST_ROLLOUT_FLAG = True
        
    def get_action(self,o,deterministic=False):
        act_op = self.model['mu'] if deterministic else self.model['pi']
        return self.sess.run(act_op, feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
    
    def set_weights(self,weight_vals):
        """
        Set weights without memory leakage
        """
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
            # Memory-leakage-free assign (hopefully)
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:weight_vals[w_idx]})
            
    def rollout(self):
        """
        Rollout
        """
        if self.FIRST_ROLLOUT_FLAG:
            self.FIRST_ROLLOUT_FLAG = False
            self.o = self.env.reset() # reset environment
        # Loop
        r_sum = 0
        for t in range(ep_len_rollout):
            self.a = self.get_action(self.o,deterministic=False) 
            self.o2,self.r,self.d,_ = self.env.step(self.a)
            r_sum += self.r
            # Append
            self.o_buffer[t,:] = self.o
            self.a_buffer[t,:] = self.a
            self.r_buffer[t] = self.r
            self.o2_buffer[t,:] = self.o2
            self.d_buffer[t] = self.d
            # Save next state 
            self.o = self.o2
            if self.d: self.o = self.env.reset() # reset when done 
        r_avg = r_sum / ep_len_rollout
        return self.o_buffer,self.a_buffer,self.r_buffer,self.o2_buffer,self.d_buffer,r_avg
    
    def evaluate(self,red=None):
        """
        Evaluate
        """
        o,d,ep_ret,ep_len = self.env.reset(red=red),False,0,0
        while not(d or (ep_len == max_ep_len_eval)):
            a = self.get_action(o,deterministic=True)
            o,r,d,_ = self.env.step(a)
            ep_ret += r # compute return 
            ep_len += 1
        blue_health,red_health = self.env.blue_health,self.env.red_health
        eval_res = [ep_ret,ep_len,blue_health,red_health] # evaluation result 
        return eval_res
    
print ("Rollout worker classes (with and without RAY) ready.")
# Out:
# Rollout worker classes (with and without RAY) ready.

# %% [markdown]
# ### Hyperparameters

# %%
n_cpu = 11
n_workers = 11
total_steps,evaluate_every,print_every = 50000,50,5
ep_len_rollout = 50*30 # 30sec rollout
hdims,actv = [128,128],tf.nn.relu # [64,32,16],tf.nn.relu
red_list = [Agents.SPOT_4G,
            Agents.SPOT_5G,
            Agents.SPOT_RANDOM,
            Agents.EXPERT_SYSTEM_TRIAL_2,
            Agents.EXPERT_SYSTEM_TRIAL_3_SCRIMMAGE_4,
            Agents.EXPERT_SYSTEM,
            Agents.SPOT_4G,
            Agents.SPOT_5G,
            Agents.EXPERT_SYSTEM_TRIAL_2,
            Agents.EXPERT_SYSTEM_TRIAL_3_SCRIMMAGE_4,
            Agents.EXPERT_SYSTEM
           ]
num_eval,max_ep_len_eval = len(red_list),15e3 # evaluation 
# Learning hyp
batch_size,update_count = 2**12,50*10 # batchsize / number of updates
lr = 1e-4 # 1e-3
epsilon = 1e-5
# SAC
gamma = 0.98 # discount 0.99
alpha_q,alpha_pi = 0.05,0.5 # 0.2
polyak = 0.995 # 0.995
# Buffer
buffer_sz_long,buffer_sz_short = 1e7,1e6 # 1e5,1e5

# %% [markdown]
# ### Initialize Workers

# %%
ray.init(num_cpus=n_cpu,
         memory = 5*1024*1024*1024,
         object_store_memory = 10*1024*1024*1024,
         driver_object_store_memory = 5*1024*1024*1024)
tf.reset_default_graph()
R = RolloutWorkerClass(hdims=hdims,actv=actv,
                       lr=lr,gamma=gamma,alpha_q=alpha_q,alpha_pi=alpha_pi,
                       polyak=polyak,epsilon=epsilon,
                       seed=0)
workers = [RayRolloutWorkerClass.remote(worker_id=i,hdims=hdims,actv=actv,
                                        ep_len_rollout=ep_len_rollout) 
           for i in range(n_workers)]
print ("RAY initialized with [%d] cpus and [%d] workers."%
       (n_cpu,n_workers))
# Out:
# 2020-07-07 10:25:33,503	WARNING services.py:586 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-07-07 10:25:33,527	INFO resource_spec.py:212 -- Starting Ray with 4.98 GiB memory available for workers and up to 10.0 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-07-07 10:25:33,897	INFO services.py:1078 -- View the Ray dashboard at localhost:8266
# RAY initialized with [11] cpus and [11] workers.

# %%
time.sleep(1)

# %% [markdown]
# ### Replay Buffers

# %%
replay_buffer_long = ReplayBuffer(odim=R.odim,adim=R.adim,size=int(buffer_sz_long))
replay_buffer_short = ReplayBuffer(odim=R.odim,adim=R.adim,size=int(buffer_sz_short))

# %% [markdown]
# ### Loop

# %%
RESTORE = False
if RESTORE:
    npz_path = '../data/net/adt_cont_tactic/model_and_buffers_final.npz'
    restore_sac_model_and_buffers(npz_path,R,replay_buffer_long,replay_buffer_short,
                                  VERBOSE=False,IGNORE_BUFFERS=False)

# %%
start_time = time.time()
n_env_step = 0 # number of environment steps
for t in range(int(total_steps)):
    esec = time.time()-start_time
    
    # Synchronize worker weights
    weights = R.get_weights()
    set_weights_list = [worker.set_weights.remote(weights) for worker in workers] 
    
    # Make rollout and accumulate to Buffers
    t_start = time.time()
    ops = [worker.rollout.remote() for worker in workers]
    rollout_vals = ray.get(ops)
    r_sum = 0
    for rollout_val in rollout_vals:
        o_buffer,a_buffer,r_buffer,o2_buffer,d_buffer,r_rollout_avg = rollout_val
        r_sum += r_rollout_avg
        for i in range(ep_len_rollout):
            o,a,r,o2,d = o_buffer[i,:],a_buffer[i,:],r_buffer[i],o2_buffer[i,:],d_buffer[i]
            replay_buffer_long.store(o, a, r, o2, d) 
            replay_buffer_short.store(o, a, r, o2, d) 
            n_env_step += 1
    r_avg = r_sum / len(rollout_vals)
    sec_rollout = time.time() - t_start
    
    # Update
    t_start = time.time()
    avg_qs = np.zeros(int(update_count))
    for c_idx in range(int(update_count)):
        batch_long = replay_buffer_long.sample_batch(batch_size//2) 
        batch_short = replay_buffer_short.sample_batch(batch_size//2) 
        feed_dict = {R.model['o_ph']: np.concatenate((batch_long['obs1'],batch_short['obs1'])),
                     R.model['o2_ph']: np.concatenate((batch_long['obs2'],batch_short['obs2'])),
                     R.model['a_ph']: np.concatenate((batch_long['acts'],batch_short['acts'])),
                     R.model['r_ph']: np.concatenate((batch_long['rews'],batch_short['rews'])),
                     R.model['d_ph']: np.concatenate((batch_long['done'],batch_short['done']))
                    }
        outs = R.sess.run(R.step_ops, feed_dict)
        q1_vals,q2_vals = outs[3],outs[4]
        avg_q = 0.5*np.mean(q1_vals)+0.5*np.mean(q2_vals)
        avg_qs[c_idx] = avg_q
    sec_update = time.time() - t_start
    
    # Synchronize worker weights (after update)
    weights = R.get_weights()
    set_weights_list = [worker.set_weights.remote(weights) for worker in workers] 
    
    # Print
    if (t == 0) or (((t+1)%print_every) == 0): 
        print ("[%d/%d] rollout:[%.1f]s update:[%.1f]s r_avg:[%.4f] avg_q:[%.3f]."%
               (t+1,total_steps,sec_rollout,sec_update,r_avg,np.mean(avg_qs)))
    
    # Evaluate
    if (t == 0) or (((t+1)%evaluate_every) == 0): 
        ram_percent = psutil.virtual_memory().percent # memory usage
        print ("[Eval. start] step:[%d/%d][%.1f%%] #step:[%.1e] time:[%s] ram:[%.1f%%]."%
               (t+1,total_steps,t/total_steps*100,
                n_env_step,
                time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
                ram_percent)
              )
        
        LOCAL_EVAL = 0
        if LOCAL_EVAL:
            ep_ret_sum = 0
            for eval_idx in range(num_eval): 
                red = red_list[eval_idx]
                o,d,ep_ret,ep_len = R.env.reset(red=red),False,0,0
                while not(d or (ep_len == max_ep_len_eval)):
                    a = R.get_action(o,deterministic=True)
                    o,r,d,_ = R.env.step(a)
                    ep_ret += r # compute return
                    ep_len += 1
                ep_ret_sum += ep_ret
                blue_health,red_health = R.env.blue_health,R.env.red_health
                print (" [%d/%d] [%s] ep_ret:[%.4f] ep_len:[%d]. blue health:[%.2f] red health:[%.2f]"
                    %(eval_idx,num_eval,red,ep_ret,ep_len, blue_health,red_health))
            ep_ret_avg = ep_ret_sum / num_eval
            print ("[Eval. done] time:[%s] ep_ret_avg:[%.3f]."%
                   (time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
                    ep_ret_avg)
                  )
        else: # parallel evaluation with Ray
            ops = []
            for i_idx in range(num_eval):
                worker,red = workers[i_idx],red_list[i_idx]
                ops.append(worker.evaluate.remote(red=red))
            eval_vals = ray.get(ops)
            ep_ret_sum = 0
            for i_idx in range(num_eval):
                red,eval_val = red_list[i_idx],eval_vals[i_idx]
                ep_ret,ep_len,blue_health,red_health = eval_val[0],eval_val[1],eval_val[2],eval_val[3]
                ep_ret_sum += ep_ret
                print (" [%d/%d] [%s] ep_ret:[%.4f] ep_len:[%d]. blue health:[%.2f] red health:[%.2f]"
                    %(i_idx,len(eval_vals),red,ep_ret,ep_len,blue_health,red_health))
            ep_ret_avg = ep_ret_sum / num_eval
            print ("[Eval. done] time:[%s] ep_ret_avg:[%.3f].\n"%
                   (time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
                    ep_ret_avg)
                  )
        
        # Save current SAC model and replay buffers 
        npz_path = '../data/net/adt_cont_tactic/model_and_buffers_%d.npz'%(t+1)
        save_sac_model_and_buffers(npz_path,R,replay_buffer_long,replay_buffer_short,
                                   VERBOSE=False,IGNORE_BUFFERS=True)

print ("Done.")
# Out:
# (pid=22945)
# (pid=22945)
# (pid=22945)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22943)
# (pid=22943)
# (pid=22943)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22946)
# (pid=22946)
# (pid=22946)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22942)
# (pid=22942)
# (pid=22942)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22949)
# (pid=22949)
# (pid=22949)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22947)
# (pid=22947)
# (pid=22947)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22940)
# (pid=22940)
# (pid=22940)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22948)
# (pid=22948)
# (pid=22948)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22941)
# (pid=22941)
# (pid=22941)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22950)
# (pid=22950)
# (pid=22950)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22944)
# (pid=22944)
# (pid=22944)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jun 16 2020 00:16:24
# (pid=22946) Ray Worker [10] Ready.
# (pid=22945) Ray Worker [2] Ready.
# (pid=22943) Ray Worker [8] Ready.
# (pid=22942) Ray Worker [3] Ready.
# (pid=22948) Ray Worker [6] Ready.
# (pid=22950) Ray Worker [4] Ready.
# (pid=22949) Ray Worker [0] Ready.
# (pid=22947) Ray Worker [1] Ready.
# (pid=22941) Ray Worker [9] Ready.
# (pid=22940) Ray Worker [7] Ready.
# (pid=22944) Ray Worker [5] Ready.
# [1/50000] rollout:[126.1]s update:[8.6]s r_avg:[-0.0495] avg_q:[0.072].
# [Eval. start] step:[1/50000][0.0%] #step:[1.6e+04] time:[day:[01] 00:02:14] ram:[14.2%].
#  [0/11] [spot_4g] ep_ret:[100.6199] ep_len:[629]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[0.3559] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [2/11] [spot_random] ep_ret:[102.0799] ep_len:[1854]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[101.6012] ep_len:[2107]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-1.6183] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [5/11] [expert_system] ep_ret:[-100.2550] ep_len:[1650]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[35.2735] ep_len:[3001]. blue health:[1.00] red health:[0.66]
#  [7/11] [spot_5g] ep_ret:[99.6642] ep_len:[2647]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[94.1405] ep_len:[1088]. blue health:[0.93] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-100.7762] ep_len:[1068]. blue health:[0.00] red health:[1.00]
#  [10/11] [expert_system] ep_ret:[-26.8850] ep_len:[2988]. blue health:[0.00] red health:[0.26]
# [Eval. done] time:[day:[01] 00:06:17] ep_ret_avg:[27.655].
#
# [../data/net/adt_cont_tactic/model_and_buffers_1.npz] saved.
# [5/50000] rollout:[137.6]s update:[8.5]s r_avg:[-0.0117] avg_q:[0.890].
# [10/50000] rollout:[143.2]s update:[8.6]s r_avg:[-0.0182] avg_q:[1.660].
# [15/50000] rollout:[139.4]s update:[8.6]s r_avg:[-0.0009] avg_q:[2.166].
# [20/50000] rollout:[142.3]s update:[8.7]s r_avg:[-0.0224] avg_q:[2.554].
# [25/50000] rollout:[137.2]s update:[8.7]s r_avg:[-0.0078] avg_q:[2.860].
# [30/50000] rollout:[136.3]s update:[8.6]s r_avg:[-0.0092] avg_q:[3.041].
# [35/50000] rollout:[136.9]s update:[8.7]s r_avg:[-0.0130] avg_q:[3.197].
# (pid=raylet) E0707 11:54:12.582572 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080ff020000 was evicted before the raylet could pin it.
# [40/50000] rollout:[138.3]s update:[8.7]s r_avg:[-0.0189] avg_q:[3.231].
# [45/50000] rollout:[128.0]s update:[8.7]s r_avg:[-0.0072] avg_q:[3.256].
# (pid=raylet) E0707 12:20:32.909548 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080f3030000 was evicted before the raylet could pin it.
# [50/50000] rollout:[139.0]s update:[8.7]s r_avg:[-0.0313] avg_q:[3.125].
# [Eval. start] step:[50/50000][0.1%] #step:[8.2e+05] time:[day:[01] 02:04:44] ram:[17.3%].
#  [0/11] [spot_4g] ep_ret:[1.5429] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [1/11] [spot_5g] ep_ret:[67.1575] ep_len:[3001]. blue health:[1.00] red health:[0.35]
#  [2/11] [spot_random] ep_ret:[0.3336] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [3/11] [es_trial2] ep_ret:[101.1650] ep_len:[1107]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[43.6369] ep_len:[3001]. blue health:[1.00] red health:[0.56]
#  [5/11] [expert_system] ep_ret:[-100.4597] ep_len:[598]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[100.3418] ep_len:[547]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[-0.1756] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [8/11] [es_trial2] ep_ret:[100.2602] ep_len:[1400]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[94.2026] ep_len:[366]. blue health:[0.94] red health:[0.00]
#  [10/11] [expert_system] ep_ret:[-100.2880] ep_len:[495]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 02:08:47] ep_ret_avg:[27.974].
#
# [../data/net/adt_cont_tactic/model_and_buffers_50.npz] saved.
# [55/50000] rollout:[121.0]s update:[8.7]s r_avg:[-0.0057] avg_q:[3.137].
# [60/50000] rollout:[103.5]s update:[8.7]s r_avg:[-0.0440] avg_q:[3.073].
# [65/50000] rollout:[138.4]s update:[8.8]s r_avg:[-0.0131] avg_q:[3.063].
# [70/50000] rollout:[142.7]s update:[8.7]s r_avg:[-0.0228] avg_q:[3.025].
# [75/50000] rollout:[138.3]s update:[8.7]s r_avg:[-0.0009] avg_q:[2.988].
# [80/50000] rollout:[131.5]s update:[8.8]s r_avg:[-0.0147] avg_q:[2.932].
# [85/50000] rollout:[125.5]s update:[8.7]s r_avg:[-0.0167] avg_q:[2.805].
# (pid=raylet) E0707 13:58:55.980983 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000804d070000 was evicted before the raylet could pin it.
# [90/50000] rollout:[139.1]s update:[8.8]s r_avg:[-0.0224] avg_q:[2.717].
# [95/50000] rollout:[119.8]s update:[8.8]s r_avg:[-0.0299] avg_q:[2.645].
# [100/50000] rollout:[139.3]s update:[8.8]s r_avg:[-0.0186] avg_q:[2.657].
# [Eval. start] step:[100/50000][0.2%] #step:[1.6e+06] time:[day:[01] 04:09:15] ram:[19.6%].
#  [0/11] [spot_4g] ep_ret:[100.3201] ep_len:[335]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[8.1390] ep_len:[3001]. blue health:[1.00] red health:[0.92]
#  [2/11] [spot_random] ep_ret:[100.1550] ep_len:[272]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[29.2473] ep_len:[3001]. blue health:[1.00] red health:[0.71]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-41.4621] ep_len:[3001]. blue health:[0.42] red health:[0.82]
#  [5/11] [expert_system] ep_ret:[-100.6324] ep_len:[1479]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[0.4607] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [7/11] [spot_5g] ep_ret:[30.5838] ep_len:[3001]. blue health:[1.00] red health:[0.70]
#  [8/11] [es_trial2] ep_ret:[100.2638] ep_len:[397]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[75.7685] ep_len:[2728]. blue health:[0.77] red health:[0.00]
#  [10/11] [expert_system] ep_ret:[-100.2391] ep_len:[559]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 04:13:18] ep_ret_avg:[18.419].
#
# [../data/net/adt_cont_tactic/model_and_buffers_100.npz] saved.
# [105/50000] rollout:[139.8]s update:[8.7]s r_avg:[-0.0078] avg_q:[2.627].
# (pid=raylet) E0707 14:51:12.024507 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008006090000 was evicted before the raylet could pin it.
# (pid=raylet) E0707 15:00:50.907896 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008065090000 was evicted before the raylet could pin it.
# [110/50000] rollout:[137.9]s update:[8.7]s r_avg:[-0.0334] avg_q:[2.600].
# [115/50000] rollout:[127.6]s update:[8.7]s r_avg:[-0.0252] avg_q:[2.543].
# [120/50000] rollout:[114.9]s update:[8.7]s r_avg:[-0.0200] avg_q:[2.505].
# [125/50000] rollout:[139.7]s update:[8.7]s r_avg:[-0.0314] avg_q:[2.468].
# (pid=raylet) E0707 15:38:04.780090 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080be0a0000 was evicted before the raylet could pin it.
# [130/50000] rollout:[137.7]s update:[8.8]s r_avg:[-0.0137] avg_q:[2.394].
# [135/50000] rollout:[141.4]s update:[8.8]s r_avg:[-0.0140] avg_q:[2.300].
# [140/50000] rollout:[137.1]s update:[8.8]s r_avg:[-0.0574] avg_q:[2.139].
# [145/50000] rollout:[136.8]s update:[8.7]s r_avg:[-0.0291] avg_q:[2.037].
# [150/50000] rollout:[118.6]s update:[8.7]s r_avg:[-0.0189] avg_q:[1.984].
# [Eval. start] step:[150/50000][0.3%] #step:[2.5e+06] time:[day:[01] 06:12:05] ram:[21.8%].
#  [0/11] [spot_4g] ep_ret:[99.9886] ep_len:[2027]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[89.2485] ep_len:[3001]. blue health:[1.00] red health:[0.11]
#  [2/11] [spot_random] ep_ret:[100.0681] ep_len:[1216]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.1087] ep_len:[570]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[34.5635] ep_len:[3001]. blue health:[1.00] red health:[0.65]
#  [5/11] [expert_system] ep_ret:[100.2742] ep_len:[940]. blue health:[1.00] red health:[0.00]
#  [6/11] [spot_4g] ep_ret:[100.0773] ep_len:[116]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[13.5375] ep_len:[3001]. blue health:[1.00] red health:[0.86]
#  [8/11] [es_trial2] ep_ret:[100.3015] ep_len:[722]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-59.7369] ep_len:[3001]. blue health:[0.42] red health:[1.00]
#  [10/11] [expert_system] ep_ret:[-55.3530] ep_len:[1732]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 06:15:59] ep_ret_avg:[56.643].
#
# [../data/net/adt_cont_tactic/model_and_buffers_150.npz] saved.
# [155/50000] rollout:[104.4]s update:[8.8]s r_avg:[-0.0225] avg_q:[1.912].
# [160/50000] rollout:[138.2]s update:[8.8]s r_avg:[-0.0134] avg_q:[1.800].
# [165/50000] rollout:[141.4]s update:[8.8]s r_avg:[0.0041] avg_q:[1.737].
# [170/50000] rollout:[139.0]s update:[8.8]s r_avg:[-0.0473] avg_q:[1.708].
# [175/50000] rollout:[138.6]s update:[8.7]s r_avg:[-0.0130] avg_q:[1.647].
# [180/50000] rollout:[138.3]s update:[8.8]s r_avg:[-0.0292] avg_q:[1.600].
# [185/50000] rollout:[140.2]s update:[8.7]s r_avg:[-0.0199] avg_q:[1.518].
# [190/50000] rollout:[137.9]s update:[8.8]s r_avg:[-0.0237] avg_q:[1.527].
# (pid=raylet) E0707 18:25:04.248927 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008099100000 was evicted before the raylet could pin it.
# [195/50000] rollout:[136.3]s update:[8.8]s r_avg:[-0.0084] avg_q:[1.472].
# [200/50000] rollout:[138.6]s update:[8.8]s r_avg:[-0.0027] avg_q:[1.507].
# [Eval. start] step:[200/50000][0.4%] #step:[3.3e+06] time:[day:[01] 08:16:33] ram:[24.2%].
#  [0/11] [spot_4g] ep_ret:[100.2840] ep_len:[417]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[26.3102] ep_len:[3001]. blue health:[1.00] red health:[0.74]
#  [2/11] [spot_random] ep_ret:[100.4931] ep_len:[621]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.3758] ep_len:[1213]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-29.1577] ep_len:[1738]. blue health:[0.00] red health:[0.95]
#  [5/11] [expert_system] ep_ret:[44.0998] ep_len:[3001]. blue health:[0.99] red health:[0.54]
#  [6/11] [spot_4g] ep_ret:[100.7837] ep_len:[1028]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[99.9645] ep_len:[2940]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.4219] ep_len:[1574]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[100.3446] ep_len:[411]. blue health:[1.00] red health:[0.00]
#  [10/11] [expert_system] ep_ret:[100.4734] ep_len:[1164]. blue health:[1.00] red health:[0.00]
# [Eval. done] time:[day:[01] 08:19:29] ep_ret_avg:[76.763].
#
# [../data/net/adt_cont_tactic/model_and_buffers_200.npz] saved.
# [205/50000] rollout:[140.9]s update:[8.8]s r_avg:[-0.0190] avg_q:[1.568].
# [210/50000] rollout:[149.9]s update:[9.5]s r_avg:[-0.0409] avg_q:[1.459].
# [215/50000] rollout:[161.0]s update:[9.4]s r_avg:[-0.0103] avg_q:[1.455].
# [220/50000] rollout:[158.4]s update:[10.2]s r_avg:[-0.0185] avg_q:[1.482].
# [225/50000] rollout:[178.4]s update:[10.6]s r_avg:[-0.0184] avg_q:[1.500].
# [230/50000] rollout:[142.7]s update:[10.2]s r_avg:[-0.0128] avg_q:[1.511].
# (pid=raylet) E0707 20:14:40.435509 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008004140000 was evicted before the raylet could pin it.
# [235/50000] rollout:[144.0]s update:[10.2]s r_avg:[-0.0208] avg_q:[1.526].
# [240/50000] rollout:[155.0]s update:[10.0]s r_avg:[-0.0121] avg_q:[1.529].
# (pid=raylet) E0707 20:43:52.718828 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008000150000 was evicted before the raylet could pin it.
# [245/50000] rollout:[124.2]s update:[10.0]s r_avg:[-0.0190] avg_q:[1.588].
# [250/50000] rollout:[153.1]s update:[10.0]s r_avg:[-0.0064] avg_q:[1.575].
# [Eval. start] step:[250/50000][0.5%] #step:[4.1e+06] time:[day:[01] 10:34:18] ram:[35.4%].
#  [0/11] [spot_4g] ep_ret:[100.3119] ep_len:[2325]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[0.2255] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [2/11] [spot_random] ep_ret:[12.4022] ep_len:[3001]. blue health:[1.00] red health:[0.88]
#  [3/11] [es_trial2] ep_ret:[100.1790] ep_len:[701]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-34.4183] ep_len:[1021]. blue health:[0.00] red health:[0.34]
#  [5/11] [expert_system] ep_ret:[99.8514] ep_len:[1928]. blue health:[1.00] red health:[0.00]
#  [6/11] [spot_4g] ep_ret:[100.9110] ep_len:[595]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[33.4993] ep_len:[3001]. blue health:[0.97] red health:[0.64]
#  [8/11] [es_trial2] ep_ret:[100.5685] ep_len:[617]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[100.7033] ep_len:[1181]. blue health:[1.00] red health:[0.00]
#  [10/11] [expert_system] ep_ret:[-100.1221] ep_len:[263]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 10:36:49] ep_ret_avg:[46.737].
#
# [../data/net/adt_cont_tactic/model_and_buffers_250.npz] saved.
# [255/50000] rollout:[156.0]s update:[10.1]s r_avg:[-0.0247] avg_q:[1.605].
# (pid=raylet) E0707 21:24:32.565359 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000802b160000 was evicted before the raylet could pin it.
# [260/50000] rollout:[153.8]s update:[10.0]s r_avg:[-0.0279] avg_q:[1.662].
# [265/50000] rollout:[156.4]s update:[10.0]s r_avg:[-0.0314] avg_q:[1.681].
# (pid=raylet) E0707 21:46:30.006094 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080da160000 was evicted before the raylet could pin it.
# [270/50000] rollout:[141.9]s update:[8.8]s r_avg:[-0.0372] avg_q:[1.699].
# [275/50000] rollout:[137.6]s update:[9.4]s r_avg:[-0.0064] avg_q:[1.710].
# (pid=raylet) E0707 22:19:51.440423 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080fe170000 was evicted before the raylet could pin it.
# [280/50000] rollout:[159.8]s update:[11.1]s r_avg:[-0.0106] avg_q:[1.707].
# [285/50000] rollout:[161.2]s update:[10.1]s r_avg:[-0.0367] avg_q:[1.681].
# [290/50000] rollout:[158.7]s update:[10.2]s r_avg:[-0.0263] avg_q:[1.630].
# (pid=raylet) E0707 22:56:30.377734 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000801b190000 was evicted before the raylet could pin it.
# (pid=raylet) E0707 22:59:13.054991 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000802b190000 was evicted before the raylet could pin it.
# [295/50000] rollout:[140.6]s update:[10.0]s r_avg:[-0.0242] avg_q:[1.588].
# (pid=raylet) E0707 23:09:34.554888 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008084190000 was evicted before the raylet could pin it.
# [300/50000] rollout:[157.4]s update:[10.0]s r_avg:[-0.0189] avg_q:[1.543].
# [Eval. start] step:[300/50000][0.6%] #step:[5.0e+06] time:[day:[01] 12:52:25] ram:[36.6%].
#  [0/11] [spot_4g] ep_ret:[25.8581] ep_len:[3001]. blue health:[1.00] red health:[0.75]
#  [1/11] [spot_5g] ep_ret:[34.0036] ep_len:[2588]. blue health:[0.00] red health:[0.64]
#  [2/11] [spot_random] ep_ret:[100.8095] ep_len:[2252]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.4802] ep_len:[715]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[76.6049] ep_len:[2555]. blue health:[0.79] red health:[0.00]
#  [5/11] [expert_system] ep_ret:[-100.4231] ep_len:[368]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[0.1972] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [7/11] [spot_5g] ep_ret:[100.4054] ep_len:[2967]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.2698] ep_len:[557]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[46.6348] ep_len:[1845]. blue health:[0.47] red health:[0.00]
#  [10/11] [expert_system] ep_ret:[-76.0480] ep_len:[3001]. blue health:[0.06] red health:[0.81]
# [Eval. done] time:[day:[01] 12:56:14] ep_ret_avg:[37.163].
#
# [../data/net/adt_cont_tactic/model_and_buffers_300.npz] saved.
# [305/50000] rollout:[155.7]s update:[10.1]s r_avg:[-0.0190] avg_q:[1.425].
# [310/50000] rollout:[154.4]s update:[10.0]s r_avg:[-0.0072] avg_q:[1.439].
# [315/50000] rollout:[161.5]s update:[10.0]s r_avg:[-0.0222] avg_q:[1.411].
# [320/50000] rollout:[154.5]s update:[10.1]s r_avg:[-0.0160] avg_q:[1.394].
# [325/50000] rollout:[141.8]s update:[10.0]s r_avg:[-0.0421] avg_q:[1.318].
# (pid=raylet) E0708 00:35:39.631788 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080171c0000 was evicted before the raylet could pin it.
# [330/50000] rollout:[158.6]s update:[10.1]s r_avg:[-0.0145] avg_q:[1.353].
# [335/50000] rollout:[165.5]s update:[11.0]s r_avg:[-0.0200] avg_q:[1.320].
# [340/50000] rollout:[169.4]s update:[10.1]s r_avg:[-0.0220] avg_q:[1.263].
# [345/50000] rollout:[156.6]s update:[10.1]s r_avg:[-0.0070] avg_q:[1.275].
# (pid=raylet) E0708 01:37:58.403350 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080031e0000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 01:37:58.404412 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080041e0000 was evicted before the raylet could pin it.
# [350/50000] rollout:[152.2]s update:[10.1]s r_avg:[-0.0064] avg_q:[1.313].
# [Eval. start] step:[350/50000][0.7%] #step:[5.8e+06] time:[day:[01] 15:15:03] ram:[40.9%].
#  [0/11] [spot_4g] ep_ret:[100.1227] ep_len:[163]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[9.0595] ep_len:[3001]. blue health:[1.00] red health:[0.91]
#  [2/11] [spot_random] ep_ret:[102.3803] ep_len:[2363]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.4958] ep_len:[1219]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-78.7091] ep_len:[2040]. blue health:[0.00] red health:[0.78]
#  [5/11] [expert_system] ep_ret:[-98.9744] ep_len:[1714]. blue health:[0.00] red health:[0.99]
#  [6/11] [spot_4g] ep_ret:[0.6692] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [7/11] [spot_5g] ep_ret:[100.2703] ep_len:[1098]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.1691] ep_len:[1041]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-6.8342] ep_len:[1036]. blue health:[0.00] red health:[0.07]
#  [10/11] [expert_system] ep_ret:[-63.1295] ep_len:[2184]. blue health:[0.00] red health:[0.62]
# [Eval. done] time:[day:[01] 15:18:11] ep_ret_avg:[24.138].
#
# [../data/net/adt_cont_tactic/model_and_buffers_350.npz] saved.
# [355/50000] rollout:[144.7]s update:[11.1]s r_avg:[-0.0195] avg_q:[1.292].
# (pid=raylet) E0708 02:08:35.769883 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080d61e0000 was evicted before the raylet could pin it.
# [360/50000] rollout:[155.1]s update:[10.0]s r_avg:[-0.0192] avg_q:[1.335].
# [365/50000] rollout:[157.4]s update:[10.0]s r_avg:[-0.0255] avg_q:[1.346].
# [370/50000] rollout:[156.2]s update:[10.0]s r_avg:[-0.0010] avg_q:[1.358].
# [375/50000] rollout:[152.6]s update:[10.0]s r_avg:[-0.0012] avg_q:[1.425].
# [380/50000] rollout:[155.9]s update:[10.0]s r_avg:[-0.0280] avg_q:[1.412].
# [385/50000] rollout:[160.0]s update:[10.0]s r_avg:[-0.0130] avg_q:[1.398].
# (pid=raylet) E0708 03:24:44.712813 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008043210000 was evicted before the raylet could pin it.
# [390/50000] rollout:[112.7]s update:[10.1]s r_avg:[-0.0008] avg_q:[1.467].
# [395/50000] rollout:[154.2]s update:[10.2]s r_avg:[-0.0191] avg_q:[1.442].
# (pid=raylet) E0708 03:45:34.980957 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080f0210000 was evicted before the raylet could pin it.
# [400/50000] rollout:[149.9]s update:[10.1]s r_avg:[-0.0084] avg_q:[1.419].
# [Eval. start] step:[400/50000][0.8%] #step:[6.6e+06] time:[day:[01] 17:33:00] ram:[44.3%].
#  [0/11] [spot_4g] ep_ret:[100.2756] ep_len:[344]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[0.7115] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [2/11] [spot_random] ep_ret:[100.4242] ep_len:[426]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.5397] ep_len:[820]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[100.3933] ep_len:[807]. blue health:[1.00] red health:[0.00]
#  [5/11] [expert_system] ep_ret:[-100.2979] ep_len:[1333]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[0.1813] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [7/11] [spot_5g] ep_ret:[100.4587] ep_len:[1114]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[97.5974] ep_len:[1356]. blue health:[0.97] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-44.7586] ep_len:[3001]. blue health:[0.57] red health:[1.00]
#  [10/11] [expert_system] ep_ret:[100.6466] ep_len:[975]. blue health:[1.00] red health:[0.00]
# [Eval. done] time:[day:[01] 17:37:05] ep_ret_avg:[50.561].
#
# [../data/net/adt_cont_tactic/model_and_buffers_400.npz] saved.
# [405/50000] rollout:[153.4]s update:[10.1]s r_avg:[-0.0176] avg_q:[1.384].
# [410/50000] rollout:[154.4]s update:[10.0]s r_avg:[-0.0112] avg_q:[1.348].
# (pid=raylet) E0708 04:32:19.969756 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000805a230000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 04:35:03.859161 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008064230000 was evicted before the raylet could pin it.
# [415/50000] rollout:[124.0]s update:[9.4]s r_avg:[-0.0275] avg_q:[1.391].
# [420/50000] rollout:[148.9]s update:[9.3]s r_avg:[-0.0293] avg_q:[1.417].
# [425/50000] rollout:[143.3]s update:[9.3]s r_avg:[-0.0085] avg_q:[1.447].
# [430/50000] rollout:[149.6]s update:[9.9]s r_avg:[-0.0137] avg_q:[1.422].
# [435/50000] rollout:[144.4]s update:[9.4]s r_avg:[-0.0186] avg_q:[1.375].
# [440/50000] rollout:[149.5]s update:[9.4]s r_avg:[-0.0133] avg_q:[1.376].
# [445/50000] rollout:[145.8]s update:[9.4]s r_avg:[-0.0241] avg_q:[1.392].
# [450/50000] rollout:[146.7]s update:[9.3]s r_avg:[-0.0041] avg_q:[1.384].
# [Eval. start] step:[450/50000][0.9%] #step:[7.4e+06] time:[day:[01] 19:45:01] ram:[40.0%].
#  [0/11] [spot_4g] ep_ret:[77.1066] ep_len:[3001]. blue health:[1.00] red health:[0.24]
#  [1/11] [spot_5g] ep_ret:[100.4394] ep_len:[544]. blue health:[1.00] red health:[0.00]
#  [2/11] [spot_random] ep_ret:[11.1378] ep_len:[3001]. blue health:[1.00] red health:[0.90]
#  [3/11] [es_trial2] ep_ret:[100.6848] ep_len:[2655]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-1.3705] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [5/11] [expert_system] ep_ret:[100.4174] ep_len:[1002]. blue health:[1.00] red health:[0.00]
#  [6/11] [spot_4g] ep_ret:[100.2276] ep_len:[275]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[100.4625] ep_len:[994]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.4486] ep_len:[876]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[47.0384] ep_len:[3001]. blue health:[0.94] red health:[0.46]
#  [10/11] [expert_system] ep_ret:[94.8845] ep_len:[1191]. blue health:[0.95] red health:[0.00]
# [Eval. done] time:[day:[01] 19:48:54] ep_ret_avg:[75.589].
#
# [../data/net/adt_cont_tactic/model_and_buffers_450.npz] saved.
# [455/50000] rollout:[148.8]s update:[9.3]s r_avg:[-0.0169] avg_q:[1.408].
# (pid=raylet) E0708 06:35:29.348553 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000805e270000 was evicted before the raylet could pin it.
# [460/50000] rollout:[136.5]s update:[9.3]s r_avg:[-0.0182] avg_q:[1.389].
# [465/50000] rollout:[148.0]s update:[9.5]s r_avg:[-0.0237] avg_q:[1.449].
# [470/50000] rollout:[150.3]s update:[9.4]s r_avg:[-0.0259] avg_q:[1.507].
# [475/50000] rollout:[147.4]s update:[9.4]s r_avg:[-0.0496] avg_q:[1.481].
# (pid=raylet) E0708 07:21:52.043387 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080e6280000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 07:24:28.567756 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008001290000 was evicted before the raylet could pin it.
# [480/50000] rollout:[146.7]s update:[9.5]s r_avg:[-0.0238] avg_q:[1.486].
# [485/50000] rollout:[148.5]s update:[9.3]s r_avg:[-0.0300] avg_q:[1.460].
# (pid=raylet) E0708 07:45:12.665117 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080ae290000 was evicted before the raylet could pin it.
# [490/50000] rollout:[136.9]s update:[9.5]s r_avg:[-0.0071] avg_q:[1.482].
# (pid=raylet) E0708 08:03:09.471024 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080462a0000 was evicted before the raylet could pin it.
# [495/50000] rollout:[148.0]s update:[9.4]s r_avg:[-0.0056] avg_q:[1.490].
# [500/50000] rollout:[114.7]s update:[9.8]s r_avg:[0.0030] avg_q:[1.538].
# [Eval. start] step:[500/50000][1.0%] #step:[8.2e+06] time:[day:[01] 21:57:51] ram:[43.6%].
#  [0/11] [spot_4g] ep_ret:[102.0362] ep_len:[2904]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[100.0783] ep_len:[167]. blue health:[1.00] red health:[0.00]
#  [2/11] [spot_random] ep_ret:[101.2862] ep_len:[1434]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.6654] ep_len:[1420]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-28.6506] ep_len:[3001]. blue health:[0.22] red health:[0.50]
#  [5/11] [expert_system] ep_ret:[-101.1948] ep_len:[2942]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[100.9043] ep_len:[974]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[-2.5965] ep_len:[3001]. blue health:[0.95] red health:[0.98]
#  [8/11] [es_trial2] ep_ret:[100.4444] ep_len:[777]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-5.4601] ep_len:[3001]. blue health:[0.96] red health:[1.00]
#  [10/11] [expert_system] ep_ret:[-40.4986] ep_len:[3001]. blue health:[0.27] red health:[0.67]
# [Eval. done] time:[day:[01] 22:02:09] ep_ret_avg:[38.819].
#
# [../data/net/adt_cont_tactic/model_and_buffers_500.npz] saved.
# [505/50000] rollout:[120.0]s update:[9.4]s r_avg:[-0.0289] avg_q:[1.495].
# [510/50000] rollout:[145.3]s update:[9.3]s r_avg:[-0.0071] avg_q:[1.464].
# [515/50000] rollout:[134.7]s update:[9.4]s r_avg:[-0.0268] avg_q:[1.485].
# [520/50000] rollout:[125.7]s update:[9.4]s r_avg:[-0.0314] avg_q:[1.525].
# [525/50000] rollout:[145.2]s update:[9.4]s r_avg:[-0.0171] avg_q:[1.527].
# [530/50000] rollout:[146.6]s update:[9.4]s r_avg:[-0.0251] avg_q:[1.499].
# [535/50000] rollout:[147.3]s update:[9.4]s r_avg:[-0.0200] avg_q:[1.527].
# [540/50000] rollout:[150.3]s update:[9.6]s r_avg:[-0.0131] avg_q:[1.490].
# [545/50000] rollout:[150.5]s update:[9.6]s r_avg:[-0.0199] avg_q:[1.505].
# (pid=raylet) E0708 10:31:14.999189 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080172f0000 was evicted before the raylet could pin it.
# [550/50000] rollout:[153.2]s update:[9.6]s r_avg:[-0.0246] avg_q:[1.465].
# [Eval. start] step:[550/50000][1.1%] #step:[9.1e+06] time:[day:[02] 00:10:57] ram:[41.1%].
#  [0/11] [spot_4g] ep_ret:[100.1644] ep_len:[180]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[31.8493] ep_len:[3001]. blue health:[1.00] red health:[0.68]
#  [2/11] [spot_random] ep_ret:[0.2998] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [3/11] [es_trial2] ep_ret:[38.7995] ep_len:[3001]. blue health:[1.00] red health:[0.60]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[100.3788] ep_len:[972]. blue health:[1.00] red health:[0.00]
#  [5/11] [expert_system] ep_ret:[-89.7358] ep_len:[1606]. blue health:[0.00] red health:[0.89]
#  [6/11] [spot_4g] ep_ret:[100.1850] ep_len:[344]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[100.9742] ep_len:[2939]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.2476] ep_len:[236]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[45.2954] ep_len:[3001]. blue health:[1.00] red health:[0.54]
#  [10/11] [expert_system] ep_ret:[-35.0755] ep_len:[3001]. blue health:[0.34] red health:[0.67]
# [Eval. done] time:[day:[02] 00:15:19] ep_ret_avg:[44.853].
#
# [../data/net/adt_cont_tactic/model_and_buffers_550.npz] saved.
# [555/50000] rollout:[148.7]s update:[9.6]s r_avg:[-0.0131] avg_q:[1.455].
# [560/50000] rollout:[149.3]s update:[9.6]s r_avg:[-0.0191] avg_q:[1.403].
# [565/50000] rollout:[144.9]s update:[9.4]s r_avg:[-0.0244] avg_q:[1.413].
# [570/50000] rollout:[148.2]s update:[9.6]s r_avg:[-0.0068] avg_q:[1.503].
# (pid=raylet) E0708 11:33:29.661444 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080fa300000 was evicted before the raylet could pin it.
# [575/50000] rollout:[151.1]s update:[9.6]s r_avg:[-0.0128] avg_q:[1.540].
# (pid=raylet) E0708 11:57:29.684319 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080c9310000 was evicted before the raylet could pin it.
# [580/50000] rollout:[153.7]s update:[9.5]s r_avg:[-0.0295] avg_q:[1.490].
# (pid=raylet) E0708 12:05:35.772357 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008003320000 was evicted before the raylet could pin it.
# [585/50000] rollout:[140.7]s update:[9.6]s r_avg:[-0.0401] avg_q:[1.405].
# [590/50000] rollout:[148.9]s update:[9.5]s r_avg:[-0.0253] avg_q:[1.338].
# [595/50000] rollout:[150.5]s update:[9.6]s r_avg:[-0.0222] avg_q:[1.343].
# [600/50000] rollout:[145.4]s update:[9.5]s r_avg:[-0.0185] avg_q:[1.396].
# [Eval. start] step:[600/50000][1.2%] #step:[9.9e+06] time:[day:[02] 02:27:12] ram:[41.8%].
#  [0/11] [spot_4g] ep_ret:[101.1308] ep_len:[2367]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[16.1433] ep_len:[3001]. blue health:[0.90] red health:[0.74]
#  [2/11] [spot_random] ep_ret:[100.1981] ep_len:[225]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.3430] ep_len:[667]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-12.6783] ep_len:[3001]. blue health:[0.89] red health:[1.00]
#  [5/11] [expert_system] ep_ret:[99.8008] ep_len:[1530]. blue health:[1.00] red health:[0.00]
#  [6/11] [spot_4g] ep_ret:[17.7118] ep_len:[3001]. blue health:[1.00] red health:[0.84]
#  [7/11] [spot_5g] ep_ret:[100.2301] ep_len:[346]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.6536] ep_len:[996]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[100.2951] ep_len:[1360]. blue health:[1.00] red health:[0.00]
#  [10/11] [expert_system] ep_ret:[-80.3787] ep_len:[2504]. blue health:[0.00] red health:[0.79]
# [Eval. done] time:[day:[02] 02:31:25] ep_ret_avg:[58.495].
#
# [../data/net/adt_cont_tactic/model_and_buffers_600.npz] saved.
# [605/50000] rollout:[136.4]s update:[9.6]s r_avg:[-0.0049] avg_q:[1.383].
# (pid=raylet) E0708 13:17:10.462553 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008045340000 was evicted before the raylet could pin it.
# [610/50000] rollout:[147.1]s update:[9.5]s r_avg:[-0.0072] avg_q:[1.439].
# [615/50000] rollout:[148.1]s update:[9.5]s r_avg:[-0.0113] avg_q:[1.428].
# [620/50000] rollout:[149.4]s update:[9.5]s r_avg:[-0.0069] avg_q:[1.457].
# [625/50000] rollout:[142.3]s update:[9.5]s r_avg:[-0.0136] avg_q:[1.453].
# (pid=raylet) E0708 14:06:33.124011 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080ed350000 was evicted before the raylet could pin it.
# [630/50000] rollout:[150.0]s update:[9.5]s r_avg:[-0.0266] avg_q:[1.407].
# (pid=raylet) E0708 14:16:49.731897 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008037360000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 14:18:45.477232 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008052360000 was evicted before the raylet could pin it.
# [635/50000] rollout:[135.1]s update:[9.5]s r_avg:[-0.0104] avg_q:[1.429].
# (pid=raylet) E0708 14:27:43.099149 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080b2360000 was evicted before the raylet could pin it.
# [640/50000] rollout:[152.9]s update:[9.5]s r_avg:[-0.0193] avg_q:[1.478].
# [645/50000] rollout:[153.8]s update:[9.5]s r_avg:[-0.0035] avg_q:[1.519].
# (pid=raylet) E0708 14:59:54.927903 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080af370000 was evicted before the raylet could pin it.
# [650/50000] rollout:[150.7]s update:[9.5]s r_avg:[0.0036] avg_q:[1.557].
# [Eval. start] step:[650/50000][1.3%] #step:[1.1e+07] time:[day:[02] 04:39:38] ram:[41.7%].
#  [0/11] [spot_4g] ep_ret:[0.5136] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [1/11] [spot_5g] ep_ret:[100.0839] ep_len:[496]. blue health:[1.00] red health:[0.00]
#  [2/11] [spot_random] ep_ret:[100.2699] ep_len:[454]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.6475] ep_len:[949]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-101.1287] ep_len:[2022]. blue health:[0.00] red health:[1.00]
#  [5/11] [expert_system] ep_ret:[-101.1086] ep_len:[1510]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[100.0762] ep_len:[127]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[101.6195] ep_len:[1258]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.2730] ep_len:[317]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[62.5951] ep_len:[3001]. blue health:[1.00] red health:[0.36]
#  [10/11] [expert_system] ep_ret:[58.0705] ep_len:[3001]. blue health:[0.82] red health:[0.24]
# [Eval. done] time:[day:[02] 04:43:34] ep_ret_avg:[47.447].
#
# [../data/net/adt_cont_tactic/model_and_buffers_650.npz] saved.
# (pid=raylet) E0708 15:14:34.103966 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008007380000 was evicted before the raylet could pin it.
# [655/50000] rollout:[137.5]s update:[9.5]s r_avg:[-0.0061] avg_q:[1.563].
# [660/50000] rollout:[148.7]s update:[9.6]s r_avg:[-0.0132] avg_q:[1.549].
# [665/50000] rollout:[151.4]s update:[9.6]s r_avg:[-0.0137] avg_q:[1.534].
# (pid=raylet) E0708 15:58:30.871366 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000807c390000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 15:58:30.880434 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008082390000 was evicted before the raylet could pin it.
# [670/50000] rollout:[150.0]s update:[9.6]s r_avg:[-0.0009] avg_q:[1.521].
# (pid=raylet) E0708 16:10:58.373066 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080e8390000 was evicted before the raylet could pin it.
# [675/50000] rollout:[109.8]s update:[9.5]s r_avg:[-0.0071] avg_q:[1.571].
# [680/50000] rollout:[127.9]s update:[9.6]s r_avg:[-0.0395] avg_q:[1.615].
# [685/50000] rollout:[141.4]s update:[9.5]s r_avg:[-0.0210] avg_q:[1.630].
# [690/50000] rollout:[155.6]s update:[9.5]s r_avg:[-0.0275] avg_q:[1.632].
# (pid=raylet) E0708 16:52:03.521661 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000804b3b0000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 17:02:24.050971 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000809f3b0000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 17:02:24.059566 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080a43b0000 was evicted before the raylet could pin it.
# [695/50000] rollout:[144.7]s update:[9.6]s r_avg:[-0.0229] avg_q:[1.609].
# [700/50000] rollout:[149.9]s update:[10.1]s r_avg:[-0.0251] avg_q:[1.634].
# [Eval. start] step:[700/50000][1.4%] #step:[1.2e+07] time:[day:[02] 06:52:39] ram:[44.5%].
#  [0/11] [spot_4g] ep_ret:[100.1190] ep_len:[168]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[80.4163] ep_len:[3001]. blue health:[1.00] red health:[0.20]
#  [2/11] [spot_random] ep_ret:[100.3693] ep_len:[592]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.2192] ep_len:[694]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-46.7207] ep_len:[3001]. blue health:[0.54] red health:[1.00]
#  [5/11] [expert_system] ep_ret:[100.1574] ep_len:[901]. blue health:[1.00] red health:[0.00]
#  [6/11] [spot_4g] ep_ret:[0.2138] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [7/11] [spot_5g] ep_ret:[33.1217] ep_len:[3001]. blue health:[1.00] red health:[0.67]
#  [8/11] [es_trial2] ep_ret:[100.3677] ep_len:[1031]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-92.7118] ep_len:[713]. blue health:[0.00] red health:[0.93]
#  [10/11] [expert_system] ep_ret:[100.5393] ep_len:[1101]. blue health:[1.00] red health:[0.00]
# [Eval. done] time:[day:[02] 06:56:48] ep_ret_avg:[52.372].
#
# [../data/net/adt_cont_tactic/model_and_buffers_700.npz] saved.
# [705/50000] rollout:[156.4]s update:[10.6]s r_avg:[-0.0254] avg_q:[1.639].
# [710/50000] rollout:[147.7]s update:[9.6]s r_avg:[-0.0192] avg_q:[1.706].
# [715/50000] rollout:[151.2]s update:[9.6]s r_avg:[-0.0036] avg_q:[1.659].
# (pid=raylet) E0708 18:09:35.020305 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080b03d0000 was evicted before the raylet could pin it.
# [720/50000] rollout:[128.7]s update:[9.6]s r_avg:[-0.0256] avg_q:[1.656].
# [725/50000] rollout:[151.8]s update:[9.6]s r_avg:[-0.0075] avg_q:[1.708].
# (pid=raylet) E0708 18:29:54.833652 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080693e0000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 18:37:50.475675 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080a43e0000 was evicted before the raylet could pin it.
# [730/50000] rollout:[149.7]s update:[9.6]s r_avg:[-0.0175] avg_q:[1.694].
# [735/50000] rollout:[123.7]s update:[9.4]s r_avg:[-0.0178] avg_q:[1.727].
# [740/50000] rollout:[148.9]s update:[9.6]s r_avg:[-0.0173] avg_q:[1.715].
# (pid=raylet) E0708 19:09:18.017213 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080ae3f0000 was evicted before the raylet could pin it.
# [745/50000] rollout:[148.7]s update:[9.6]s r_avg:[-0.0176] avg_q:[1.670].
# [750/50000] rollout:[136.7]s update:[9.6]s r_avg:[-0.0272] avg_q:[1.669].
# [Eval. start] step:[750/50000][1.5%] #step:[1.2e+07] time:[day:[02] 09:06:52] ram:[42.3%].
#  [0/11] [spot_4g] ep_ret:[100.1791] ep_len:[191]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[3.2714] ep_len:[3001]. blue health:[1.00] red health:[0.97]
#  [2/11] [spot_random] ep_ret:[100.1640] ep_len:[223]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.6205] ep_len:[1217]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[99.9608] ep_len:[645]. blue health:[1.00] red health:[0.00]
#  [5/11] [expert_system] ep_ret:[-90.7937] ep_len:[2068]. blue health:[0.00] red health:[0.90]
#  [6/11] [spot_4g] ep_ret:[0.8137] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [7/11] [spot_5g] ep_ret:[-4.5180] ep_len:[3001]. blue health:[0.96] red health:[1.00]
#  [8/11] [es_trial2] ep_ret:[74.7813] ep_len:[3001]. blue health:[1.00] red health:[0.25]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[2.9914] ep_len:[3001]. blue health:[1.00] red health:[0.96]
#  [10/11] [expert_system] ep_ret:[100.4059] ep_len:[1459]. blue health:[1.00] red health:[0.00]
# [Eval. done] time:[day:[02] 09:11:21] ep_ret_avg:[44.352].
#
# [../data/net/adt_cont_tactic/model_and_buffers_750.npz] saved.
# (pid=raylet) E0708 19:39:38.885147 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000808d400000 was evicted before the raylet could pin it.
# [755/50000] rollout:[148.1]s update:[9.5]s r_avg:[-0.0192] avg_q:[1.598].
# [760/50000] rollout:[150.3]s update:[9.5]s r_avg:[-0.0130] avg_q:[1.590].
# [765/50000] rollout:[127.9]s update:[9.5]s r_avg:[-0.0249] avg_q:[1.589].
# [770/50000] rollout:[156.3]s update:[9.5]s r_avg:[-0.0240] avg_q:[1.600].
# [775/50000] rollout:[167.7]s update:[11.4]s r_avg:[-0.0108] avg_q:[1.608].
# [780/50000] rollout:[148.4]s update:[9.5]s r_avg:[-0.0146] avg_q:[1.555].
# [785/50000] rollout:[184.8]s update:[14.3]s r_avg:[-0.0119] avg_q:[1.507].
# [790/50000] rollout:[179.8]s update:[12.9]s r_avg:[-0.0033] avg_q:[1.508].
# [795/50000] rollout:[177.2]s update:[12.8]s r_avg:[-0.0251] avg_q:[1.447].
# [800/50000] rollout:[187.5]s update:[12.8]s r_avg:[-0.0090] avg_q:[1.414].
# [Eval. start] step:[800/50000][1.6%] #step:[1.3e+07] time:[day:[02] 11:32:29] ram:[64.5%].
#  [0/11] [spot_4g] ep_ret:[100.7160] ep_len:[2058]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[4.1415] ep_len:[3001]. blue health:[1.00] red health:[0.96]
#  [2/11] [spot_random] ep_ret:[100.2347] ep_len:[255]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.0795] ep_len:[624]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-100.4895] ep_len:[593]. blue health:[0.00] red health:[1.00]
#  [5/11] [expert_system] ep_ret:[41.8956] ep_len:[2966]. blue health:[0.43] red health:[0.00]
#  [6/11] [spot_4g] ep_ret:[0.5020] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [7/11] [spot_5g] ep_ret:[2.6752] ep_len:[3001]. blue health:[1.00] red health:[0.98]
#  [8/11] [es_trial2] ep_ret:[100.0511] ep_len:[712]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-101.4651] ep_len:[2389]. blue health:[0.00] red health:[1.00]
#  [10/11] [expert_system] ep_ret:[-101.9421] ep_len:[2303]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[02] 11:36:36] ep_ret_avg:[13.309].
#
# [../data/net/adt_cont_tactic/model_and_buffers_800.npz] saved.
# (pid=raylet) E0708 22:05:33.084923 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080cf440000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 22:11:53.123816 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008001450000 was evicted before the raylet could pin it.
# [805/50000] rollout:[163.1]s update:[12.8]s r_avg:[-0.0174] avg_q:[1.397].
# [810/50000] rollout:[162.9]s update:[12.9]s r_avg:[-0.0072] avg_q:[1.389].
# [815/50000] rollout:[188.3]s update:[12.8]s r_avg:[-0.0316] avg_q:[1.406].
# (pid=raylet) E0708 22:57:41.335184 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000802f460000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 23:00:53.123297 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008049460000 was evicted before the raylet could pin it.
# [820/50000] rollout:[179.2]s update:[12.8]s r_avg:[-0.0193] avg_q:[1.368].
# (pid=raylet) E0708 23:16:57.026561 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080b6460000 was evicted before the raylet could pin it.
# (pid=raylet) E0708 23:16:57.028941 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080b7460000 was evicted before the raylet could pin it.
# [825/50000] rollout:[177.7]s update:[12.9]s r_avg:[-0.0211] avg_q:[1.267].
# [830/50000] rollout:[159.3]s update:[12.8]s r_avg:[-0.0280] avg_q:[1.233].
# [835/50000] rollout:[185.3]s update:[12.8]s r_avg:[-0.0252] avg_q:[1.217].
# [840/50000] rollout:[186.4]s update:[12.8]s r_avg:[-0.0127] avg_q:[1.181].
# [845/50000] rollout:[181.2]s update:[12.7]s r_avg:[-0.0217] avg_q:[1.213].
# (pid=raylet) E0709 00:40:25.984707 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080f2480000 was evicted before the raylet could pin it.
# [850/50000] rollout:[190.6]s update:[12.8]s r_avg:[0.0109] avg_q:[1.192].
# [Eval. start] step:[850/50000][1.7%] #step:[1.4e+07] time:[day:[02] 14:18:11] ram:[64.8%].
#  [0/11] [spot_4g] ep_ret:[100.4460] ep_len:[598]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[4.1534] ep_len:[3001]. blue health:[1.00] red health:[0.96]
#  [2/11] [spot_random] ep_ret:[100.6413] ep_len:[2997]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.2396] ep_len:[897]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-96.4323] ep_len:[899]. blue health:[0.00] red health:[0.96]
#  [5/11] [expert_system] ep_ret:[100.3894] ep_len:[949]. blue health:[1.00] red health:[0.00]
#  [6/11] [spot_4g] ep_ret:[31.2412] ep_len:[3001]. blue health:[1.00] red health:[0.71]
#  [7/11] [spot_5g] ep_ret:[100.1618] ep_len:[1740]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.3656] ep_len:[1416]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[74.8694] ep_len:[3001]. blue health:[1.00] red health:[0.24]
#  [10/11] [expert_system] ep_ret:[-99.9054] ep_len:[2556]. blue health:[0.00] red health:[0.99]
# [Eval. done] time:[day:[02] 14:23:10] ep_ret_avg:[46.925].
#
# [../data/net/adt_cont_tactic/model_and_buffers_850.npz] saved.
# [855/50000] rollout:[140.0]s update:[12.7]s r_avg:[-0.0079] avg_q:[1.212].
# [860/50000] rollout:[184.5]s update:[12.7]s r_avg:[-0.0139] avg_q:[1.211].
# [865/50000] rollout:[162.1]s update:[12.7]s r_avg:[-0.0164] avg_q:[1.140].
# [870/50000] rollout:[200.7]s update:[12.8]s r_avg:[-0.0090] avg_q:[1.148].
# [875/50000] rollout:[197.5]s update:[12.8]s r_avg:[-0.0143] avg_q:[1.155].
# [880/50000] rollout:[180.3]s update:[12.8]s r_avg:[-0.0027] avg_q:[1.160].
# (pid=raylet) E0709 02:36:19.261143 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080ec4b0000 was evicted before the raylet could pin it.
# [885/50000] rollout:[191.1]s update:[12.8]s r_avg:[-0.0237] avg_q:[1.210].
# (pid=raylet) E0709 02:52:56.309072 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000804e4c0000 was evicted before the raylet could pin it.
# [890/50000] rollout:[155.6]s update:[12.7]s r_avg:[-0.0009] avg_q:[1.263].
# [895/50000] rollout:[183.7]s update:[12.9]s r_avg:[-0.0303] avg_q:[1.314].
# [900/50000] rollout:[167.7]s update:[12.8]s r_avg:[-0.0136] avg_q:[1.429].
# [Eval. start] step:[900/50000][1.8%] #step:[1.5e+07] time:[day:[02] 17:04:26] ram:[64.8%].
#  [0/11] [spot_4g] ep_ret:[100.8563] ep_len:[1169]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[8.2737] ep_len:[3001]. blue health:[1.00] red health:[0.92]
#  [2/11] [spot_random] ep_ret:[100.3419] ep_len:[230]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.6800] ep_len:[1671]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[98.2094] ep_len:[2707]. blue health:[1.00] red health:[0.00]
#  [5/11] [expert_system] ep_ret:[92.6922] ep_len:[2537]. blue health:[0.93] red health:[0.00]
#  [6/11] [spot_4g] ep_ret:[100.0224] ep_len:[1726]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[100.8596] ep_len:[2509]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.4942] ep_len:[763]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-98.1699] ep_len:[2572]. blue health:[0.00] red health:[0.97]
#  [10/11] [expert_system] ep_ret:[-75.8176] ep_len:[2032]. blue health:[0.00] red health:[0.75]
# [Eval. done] time:[day:[02] 17:09:14] ep_ret_avg:[57.131].
#
# [../data/net/adt_cont_tactic/model_and_buffers_900.npz] saved.
# [905/50000] rollout:[181.0]s update:[12.8]s r_avg:[-0.0189] avg_q:[1.430].
# (pid=raylet) E0709 03:50:21.855530 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080c04d0000 was evicted before the raylet could pin it.
# ...
#  [0/11] [spot_4g] ep_ret:[100.3479] ep_len:[379]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[99.9825] ep_len:[1145]. blue health:[1.00] red health:[0.00]
#  [2/11] [spot_random] ep_ret:[100.2250] ep_len:[366]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.4762] ep_len:[742]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-49.6696] ep_len:[3001]. blue health:[0.51] red health:[1.00]
#  [5/11] [expert_system] ep_ret:[-46.3191] ep_len:[1758]. blue health:[0.00] red health:[0.46]
#  [6/11] [spot_4g] ep_ret:[102.0462] ep_len:[2673]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[0.3631] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [8/11] [es_trial2] ep_ret:[100.1883] ep_len:[502]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[3.5284] ep_len:[3001]. blue health:[1.00] red health:[0.95]
#  [10/11] [expert_system] ep_ret:[78.6663] ep_len:[2989]. blue health:[0.79] red health:[0.00]
# [Eval. done] time:[day:[03] 17:01:52] ep_ret_avg:[53.621].
#
# [../data/net/adt_cont_tactic/model_and_buffers_1350.npz] saved.
# (pid=raylet) E0710 03:36:29.166671 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008045740000 was evicted before the raylet could pin it.
# [1355/50000] rollout:[176.2]s update:[11.7]s r_avg:[-0.0121] avg_q:[1.237].
# [1360/50000] rollout:[168.7]s update:[11.7]s r_avg:[-0.0132] avg_q:[1.309].
# (pid=raylet) E0710 04:10:08.563932 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000803d750000 was evicted before the raylet could pin it.
# [1365/50000] rollout:[177.4]s update:[11.7]s r_avg:[-0.0365] avg_q:[1.269].
# [1370/50000] rollout:[177.1]s update:[11.7]s r_avg:[-0.0409] avg_q:[1.228].
# (pid=raylet) E0710 04:31:59.338110 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080d0750000 was evicted before the raylet could pin it.
# [1375/50000] rollout:[172.4]s update:[11.7]s r_avg:[0.0018] avg_q:[1.207].
# [1380/50000] rollout:[172.8]s update:[11.7]s r_avg:[-0.0287] avg_q:[1.218].
# (pid=raylet) E0710 05:08:34.036007 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080d7760000 was evicted before the raylet could pin it.
# [1385/50000] rollout:[177.4]s update:[11.7]s r_avg:[-0.0387] avg_q:[1.178].
# (pid=raylet) E0710 05:14:46.181265 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080fe760000 was evicted before the raylet could pin it.
# (pid=raylet) E0710 05:20:56.768901 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000803b770000 was evicted before the raylet could pin it.
# [1390/50000] rollout:[182.3]s update:[11.7]s r_avg:[-0.0340] avg_q:[1.201].
# [1395/50000] rollout:[176.1]s update:[11.7]s r_avg:[-0.0065] avg_q:[1.259].
# (pid=raylet) E0710 05:45:34.215795 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080e1770000 was evicted before the raylet could pin it.
# [1400/50000] rollout:[174.5]s update:[11.7]s r_avg:[-0.0074] avg_q:[1.292].
# [Eval. start] step:[1400/50000][2.8%] #step:[2.3e+07] time:[day:[03] 19:35:39] ram:[49.3%].
#  [0/11] [spot_4g] ep_ret:[0.3260] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [1/11] [spot_5g] ep_ret:[-4.7185] ep_len:[3001]. blue health:[0.92] red health:[0.98]
#  [2/11] [spot_random] ep_ret:[1.3395] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [3/11] [es_trial2] ep_ret:[100.2436] ep_len:[596]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[-100.8263] ep_len:[648]. blue health:[0.00] red health:[1.00]
#  [5/11] [expert_system] ep_ret:[-100.8374] ep_len:[1739]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[100.1311] ep_len:[1975]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[57.5152] ep_len:[3001]. blue health:[1.00] red health:[0.43]
#  [8/11] [es_trial2] ep_ret:[100.8772] ep_len:[964]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-80.5935] ep_len:[1935]. blue health:[0.00] red health:[0.80]
#  [10/11] [expert_system] ep_ret:[-92.4572] ep_len:[2618]. blue health:[0.00] red health:[0.91]
# [Eval. done] time:[day:[03] 19:39:16] ep_ret_avg:[-1.727].
#
# [../data/net/adt_cont_tactic/model_and_buffers_1400.npz] saved.
# (pid=raylet) E0710 06:04:54.012349 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008058780000 was evicted before the raylet could pin it.
# (pid=raylet) E0710 06:17:09.087189 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080b0780000 was evicted before the raylet could pin it.
# [1405/50000] rollout:[167.6]s update:[11.7]s r_avg:[-0.0199] avg_q:[1.412].
# (pid=raylet) E0710 06:32:19.971479 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008012790000 was evicted before the raylet could pin it.
# [1410/50000] rollout:[174.1]s update:[11.7]s r_avg:[-0.0185] avg_q:[1.420].
# (pid=raylet) E0710 06:44:47.708590 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000806b790000 was evicted before the raylet could pin it.
# [1415/50000] rollout:[168.2]s update:[11.5]s r_avg:[-0.0074] avg_q:[1.439].
# [1420/50000] rollout:[172.0]s update:[11.8]s r_avg:[-0.0104] avg_q:[1.402].
# (pid=raylet) E0710 07:09:31.433171 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000801f7a0000 was evicted before the raylet could pin it.
# [1425/50000] rollout:[171.3]s update:[11.7]s r_avg:[-0.0081] avg_q:[1.436].
# (pid=raylet) E0710 07:28:30.668813 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080be7a0000 was evicted before the raylet could pin it.
# [1430/50000] rollout:[185.3]s update:[11.6]s r_avg:[-0.0129] avg_q:[1.534].
# [1435/50000] rollout:[198.9]s update:[11.6]s r_avg:[-0.0262] avg_q:[1.521].
# [1440/50000] rollout:[155.4]s update:[11.6]s r_avg:[-0.0150] avg_q:[1.516].
# (pid=raylet) E0710 08:06:34.340101 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080bf7b0000 was evicted before the raylet could pin it.
# [1445/50000] rollout:[167.2]s update:[11.6]s r_avg:[-0.0064] avg_q:[1.579].
# [1450/50000] rollout:[176.1]s update:[11.7]s r_avg:[-0.0033] avg_q:[1.590].
# [Eval. start] step:[1450/50000][2.9%] #step:[2.4e+07] time:[day:[03] 22:11:18] ram:[49.1%].
#  [0/11] [spot_4g] ep_ret:[0.1362] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [1/11] [spot_5g] ep_ret:[-2.4657] ep_len:[2544]. blue health:[0.00] red health:[1.00]
#  [2/11] [spot_random] ep_ret:[100.4457] ep_len:[525]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.2787] ep_len:[709]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[6.5408] ep_len:[3001]. blue health:[0.80] red health:[0.72]
#  [5/11] [expert_system] ep_ret:[-69.2745] ep_len:[940]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[9.5911] ep_len:[3001]. blue health:[1.00] red health:[0.91]
#  [7/11] [spot_5g] ep_ret:[26.9476] ep_len:[3001]. blue health:[1.00] red health:[0.74]
#  [8/11] [es_trial2] ep_ret:[29.2747] ep_len:[3001]. blue health:[0.98] red health:[0.69]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[-55.7416] ep_len:[3001]. blue health:[0.25] red health:[0.80]
#  [10/11] [expert_system] ep_ret:[-50.4610] ep_len:[2004]. blue health:[0.00] red health:[0.50]
# [Eval. done] time:[day:[03] 22:16:34] ep_ret_avg:[8.661].
#
# [../data/net/adt_cont_tactic/model_and_buffers_1450.npz] saved.
# (pid=raylet) E0710 08:51:36.467720 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080d77c0000 was evicted before the raylet could pin it.
# (pid=raylet) E0710 08:54:41.354066 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080f07c0000 was evicted before the raylet could pin it.
# [1455/50000] rollout:[179.4]s update:[11.6]s r_avg:[-0.0315] avg_q:[1.558].
# [1460/50000] rollout:[176.9]s update:[11.6]s r_avg:[0.0048] avg_q:[1.522].
# [1465/50000] rollout:[190.1]s update:[11.6]s r_avg:[-0.0315] avg_q:[1.425].
# (pid=raylet) E0710 09:36:07.164038 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000801c7e0000 was evicted before the raylet could pin it.
# [1470/50000] rollout:[185.3]s update:[11.6]s r_avg:[0.0017] avg_q:[1.447].
# (pid=raylet) E0710 09:48:52.330884 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080667e0000 was evicted before the raylet could pin it.
# [1475/50000] rollout:[173.3]s update:[11.7]s r_avg:[-0.0068] avg_q:[1.531].
# (pid=raylet) E0710 10:00:15.317893 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080bc7e0000 was evicted before the raylet could pin it.
# [1480/50000] rollout:[138.0]s update:[8.9]s r_avg:[-0.0293] avg_q:[1.486].
# [1485/50000] rollout:[136.1]s update:[8.8]s r_avg:[-0.0069] avg_q:[1.466].
# [1490/50000] rollout:[139.4]s update:[8.8]s r_avg:[-0.0031] avg_q:[1.452].
# [1495/50000] rollout:[143.0]s update:[8.8]s r_avg:[-0.0089] avg_q:[1.461].
# (pid=raylet) E0710 10:49:41.404296 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008079800000 was evicted before the raylet could pin it.
# [1500/50000] rollout:[140.4]s update:[8.8]s r_avg:[-0.0080] avg_q:[1.517].
# [Eval. start] step:[1500/50000][3.0%] #step:[2.5e+07] time:[day:[04] 00:36:25] ram:[42.1%].
#  [0/11] [spot_4g] ep_ret:[100.9579] ep_len:[1942]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[100.5588] ep_len:[2217]. blue health:[1.00] red health:[0.00]
#  [2/11] [spot_random] ep_ret:[100.2564] ep_len:[422]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[22.9050] ep_len:[3001]. blue health:[1.00] red health:[0.77]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[100.5060] ep_len:[1243]. blue health:[1.00] red health:[0.00]
#  [5/11] [expert_system] ep_ret:[29.2971] ep_len:[3001]. blue health:[0.57] red health:[0.27]
#  [6/11] [spot_4g] ep_ret:[101.1215] ep_len:[1161]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[0.1954] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [8/11] [es_trial2] ep_ret:[73.3010] ep_len:[3001]. blue health:[1.00] red health:[0.26]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[100.2196] ep_len:[1167]. blue health:[1.00] red health:[0.00]
#  [10/11] [expert_system] ep_ret:[85.7114] ep_len:[1105]. blue health:[0.86] red health:[0.00]
# [Eval. done] time:[day:[04] 00:40:40] ep_ret_avg:[74.094].
#
# [../data/net/adt_cont_tactic/model_and_buffers_1500.npz] saved.
# [1505/50000] rollout:[134.7]s update:[8.8]s r_avg:[-0.0269] avg_q:[1.471].
# (pid=raylet) E0710 11:22:11.267894 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff010000807f810000 was evicted before the raylet could pin it.
# [1510/50000] rollout:[145.2]s update:[8.9]s r_avg:[-0.0055] avg_q:[1.489].
# (pid=raylet) E0710 11:34:16.540467 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080ef810000 was evicted before the raylet could pin it.
# [1515/50000] rollout:[140.9]s update:[8.8]s r_avg:[-0.0155] avg_q:[1.534].
# [1520/50000] rollout:[140.0]s update:[8.8]s r_avg:[-0.0387] avg_q:[1.446].
# [1525/50000] rollout:[136.4]s update:[8.8]s r_avg:[0.0044] avg_q:[1.525].
# [1530/50000] rollout:[132.0]s update:[8.8]s r_avg:[-0.0255] avg_q:[1.573].
# [1535/50000] rollout:[137.9]s update:[8.8]s r_avg:[-0.0321] avg_q:[1.404].
# [1540/50000] rollout:[143.3]s update:[8.8]s r_avg:[-0.0211] avg_q:[1.383].
# [1545/50000] rollout:[136.8]s update:[8.8]s r_avg:[-0.0195] avg_q:[1.366].
# (pid=raylet) E0710 12:54:40.993943 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080c3840000 was evicted before the raylet could pin it.
# [1550/50000] rollout:[142.7]s update:[8.8]s r_avg:[-0.0207] avg_q:[1.372].
# [Eval. start] step:[1550/50000][3.1%] #step:[2.6e+07] time:[day:[04] 02:40:58] ram:[42.1%].
#  [0/11] [spot_4g] ep_ret:[100.3234] ep_len:[364]. blue health:[1.00] red health:[0.00]
#  [1/11] [spot_5g] ep_ret:[100.2729] ep_len:[526]. blue health:[1.00] red health:[0.00]
#  [2/11] [spot_random] ep_ret:[100.9055] ep_len:[2892]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.4357] ep_len:[728]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[100.4087] ep_len:[630]. blue health:[1.00] red health:[0.00]
#  [5/11] [expert_system] ep_ret:[-80.3515] ep_len:[3001]. blue health:[0.09] red health:[0.88]
#  [6/11] [spot_4g] ep_ret:[100.1680] ep_len:[153]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[4.7898] ep_len:[3001]. blue health:[1.00] red health:[0.95]
#  [8/11] [es_trial2] ep_ret:[100.1306] ep_len:[275]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[26.4537] ep_len:[3001]. blue health:[0.70] red health:[0.43]
#  [10/11] [expert_system] ep_ret:[42.3839] ep_len:[2905]. blue health:[0.43] red health:[0.00]
# [Eval. done] time:[day:[04] 02:44:42] ep_ret_avg:[63.266].
#
# [../data/net/adt_cont_tactic/model_and_buffers_1550.npz] saved.
# [1555/50000] rollout:[139.8]s update:[8.8]s r_avg:[-0.0125] avg_q:[1.348].
# (pid=raylet) E0710 13:24:35.902071 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080b7850000 was evicted before the raylet could pin it.
# [1560/50000] rollout:[138.6]s update:[8.8]s r_avg:[-0.0313] avg_q:[1.287].
# [1565/50000] rollout:[92.2]s update:[8.8]s r_avg:[0.0039] avg_q:[1.358].
# [1570/50000] rollout:[138.7]s update:[8.8]s r_avg:[-0.0121] avg_q:[1.303].
# (pid=raylet) E0710 13:59:48.479653 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008005870000 was evicted before the raylet could pin it.
# [1575/50000] rollout:[140.2]s update:[8.8]s r_avg:[-0.0088] avg_q:[1.333].
# [1580/50000] rollout:[138.4]s update:[8.8]s r_avg:[-0.0125] avg_q:[1.433].
# [1585/50000] rollout:[139.7]s update:[8.8]s r_avg:[0.0001] avg_q:[1.352].
# (pid=raylet) E0710 14:36:38.781862 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008050880000 was evicted before the raylet could pin it.
# [1590/50000] rollout:[100.6]s update:[8.7]s r_avg:[-0.0131] avg_q:[1.300].
# (pid=raylet) E0710 14:54:52.250838 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008000890000 was evicted before the raylet could pin it.
# [1595/50000] rollout:[140.4]s update:[8.8]s r_avg:[-0.0011] avg_q:[1.410].
# (pid=raylet) E0710 14:57:21.529739 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff0100008014890000 was evicted before the raylet could pin it.
# [1600/50000] rollout:[124.5]s update:[8.8]s r_avg:[-0.0212] avg_q:[1.427].
# [Eval. start] step:[1600/50000][3.2%] #step:[2.6e+07] time:[day:[04] 04:43:36] ram:[42.1%].
#  [0/11] [spot_4g] ep_ret:[0.2527] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [1/11] [spot_5g] ep_ret:[0.2261] ep_len:[3001]. blue health:[1.00] red health:[1.00]
#  [2/11] [spot_random] ep_ret:[101.7606] ep_len:[1940]. blue health:[1.00] red health:[0.00]
#  [3/11] [es_trial2] ep_ret:[100.5830] ep_len:[668]. blue health:[1.00] red health:[0.00]
#  [4/11] [es_trial3_scrimmage4] ep_ret:[100.2544] ep_len:[255]. blue health:[1.00] red health:[0.00]
#  [5/11] [expert_system] ep_ret:[-101.0968] ep_len:[1808]. blue health:[0.00] red health:[1.00]
#  [6/11] [spot_4g] ep_ret:[101.5912] ep_len:[1909]. blue health:[1.00] red health:[0.00]
#  [7/11] [spot_5g] ep_ret:[100.5578] ep_len:[2844]. blue health:[1.00] red health:[0.00]
#  [8/11] [es_trial2] ep_ret:[100.4655] ep_len:[601]. blue health:[1.00] red health:[0.00]
#  [9/11] [es_trial3_scrimmage4] ep_ret:[42.7336] ep_len:[999]. blue health:[0.43] red health:[0.00]
#  [10/11] [expert_system] ep_ret:[-27.1312] ep_len:[2071]. blue health:[0.00] red health:[0.26]
# [Eval. done] time:[day:[04] 04:45:46] ep_ret_avg:[47.291].
#
# [../data/net/adt_cont_tactic/model_and_buffers_1600.npz] saved.
# (pid=raylet) E0710 15:18:05.717824 22929 node_manager.cc:3118] Plasma object ffffffffffffffffffffffff01000080cd890000 was evicted before the raylet could pin it.
# [1605/50000] rollout:[101.2]s update:[8.8]s r_avg:[-0.0056] avg_q:[1.473].
# [1610/50000] rollout:[138.3]s update:[8.8]s r_avg:[-0.0217] avg_q:[1.477].
# [1615/50000] rollout:[139.1]s update:[8.8]s r_avg:[-0.0182] avg_q:[1.470].

# %% [markdown]
# ### Close

# %%
ray.shutdown()

# %% [markdown]
# ### Save model weights and replay buffers

# %%
# Path to save the npz file 
npz_path = '../data/net/adt_cont_tactic/model_and_buffers_final.npz'
save_sac_model_and_buffers(npz_path,R,replay_buffer_long,replay_buffer_short,
                           VERBOSE=False,IGNORE_BUFFERS=True)

# %% [markdown]
# ### Restore

# %%
npz_path = '../data/net/adt_cont_tactic/model_and_buffers_final.npz'
restore_sac_model_and_buffers(npz_path,R,replay_buffer_long,replay_buffer_short,
                              VERBOSE=False,IGNORE_BUFFERS=False)

# %% [markdown]
# ### Test Run

# %%
eval_env = get_eval_env()
red_list = [Agents.SPOT_4G,Agents.SPOT_5G,Agents.SPOT_RANDOM,
            Agents.EXPERT_SYSTEM_TRIAL_2,Agents.EXPERT_SYSTEM_TRIAL_3_SCRIMMAGE_4,
            Agents.EXPERT_SYSTEM]
red = red_list[0]
o,d,ep_ret,ep_len = eval_env.reset(red=red),False,0,0
while not(d or (ep_len == max_ep_len_eval)):
    a = R.get_action(o,deterministic=True)
    o,r,d,_ = eval_env.step(a)
    ep_ret += r # compute return 
    ep_len += 1
print ("[Evaluate] ep_ret:[%.4f] ep_len:[%d]"
    %(eval_idx,ep_len))
eval_env.close() # close env
