# %% [markdown]
# # ARS with ADT Continuous Env

# %%
import datetime,gym,time,os,psutil,ray
import numpy as np
import tensorflow as tf
from util import gpu_sess,suppress_tf_warning,tic,toc,open_txt,write_txt,OnlineMeanVariance
from ars import create_ars_model,get_noises_from_weights,save_ars_model,restore_ars_model
np.set_printoptions(precision=2)
suppress_tf_warning() # suppress warning 
gym.logger.set_level(40) # gym logger 

from episci.environment_wrappers.tactical_action_adt_env_continuous import CustomADTEnvContinuous
from episci.agents.utils.constants import Agents,RewardType,StateInfo
print ("Packaged loaded. TF version is [%s]."%(tf.__version__))
# Out:
# Packaged loaded. TF version is [1.15.0].

# %% [markdown]
# ### Hyperparameters

# %%
exp_name = 'ars_adt_cont'
n_cpu = 101
n_workers = 100

# %%
action_length = 5 # 50/5 = 10HZ
total_steps,evaluate_every,print_every = 5000,5,1
ep_len_rollout = 15000 # (15000 // action_length)
hdims,actv,out_actv = [64,64],tf.nn.relu,tf.nn.tanh
# alpha:stepsize / nu:exploration std / b: elite set size 
alpha,nu,b = 0.01,0.01,np.ceil(n_workers/10).astype(np.int)
USE_NZD_OBS = False
seed = 0
# Train
red_list_train = [
    Agents.ZOMBIE,
    Agents.SPOT_RANDOM,
    Agents.EXPERT_SYSTEM
]*2
# Evaluation
red_list_eval = [
    Agents.ZOMBIE,
    Agents.ROSIE, 
    Agents.BUD, 
    Agents.BUD_FSM, 
    Agents.EXPERT_SYSTEM
]*n_workers
red_list_eval = red_list_eval[:n_workers]
num_eval = len(red_list_eval) # evaluation
# Restore
npz_path = ''

# %% [markdown]
# ### Logger

# %%
txt_path = '../report/log/%s/log_%s.txt'%(
    exp_name,
    datetime.datetime.now().strftime("%b-%d-%Y-%H:%M:%S"))
f = open_txt(txt_path)
print ("[%s] created."%(txt_path))
time.sleep(1) # wait
# Out:
# [../report/log/ars_adt_cont/log_Aug-23-2020-04:13:37.txt] created.

# %% [markdown]
# ### Environment

# %%
def get_env(red_distribution=None):
    from episci.environment_wrappers.tactical_action_adt_env_continuous \
        import CustomADTEnvContinuous
    from episci.agents.utils.constants import Agents, RewardType
    env_config = {
        "red_distribution": red_distribution,
        "reward_type": RewardType.SHAPED
    }
    return CustomADTEnvContinuous(env_config,action_length=action_length)

# %% [markdown]
# ### Worker

# %%
class RolloutWorkerClass(object):
    """
    Worker without RAY (for update purposes)
    """
    def __init__(self,
                 hdims=[64]*2,actv=tf.nn.relu,out_actv=tf.nn.tanh,
                 seed=1,USE_NZD_OBS=True):
        self.seed = seed
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim,self.adim = odim,adim
        # Observation normalization
        self.obs_mu = np.zeros(self.odim)
        self.obs_std = np.ones(self.odim)
        self.USE_NZD_OBS = USE_NZD_OBS
        # ARS model 
        self.model,self.sess = create_ars_model(
            odim=self.odim,adim=self.adim,hdims=hdims,
            actv=actv,out_actv=out_actv)
        # Initialize model 
        tf.set_random_seed(self.seed)
        np.random.seed(self.seed)
        self.sess.run(tf.global_variables_initializer())
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True
    def set_observation_stats(self,obs_mu,obs_std):
        self.obs_mu = obs_mu
        self.obs_std = obs_std
    def get_action(self,o):
        obs_std = self.obs_std
        obs_std[obs_std<1e-6] = np.inf
        if self.USE_NZD_OBS:
            nzd_o = (o-self.obs_mu)/obs_std
        else:
            nzd_o = o
        return self.sess.run(
            self.model['mu'],feed_dict={self.model['o_ph']:nzd_o.reshape(1,-1)})[0]
    def get_weights(self):
        weight_vals = self.sess.run(self.model['main_vars'])
        return weight_vals
    def set_weights(self,weight_vals):
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:weight_vals[w_idx]})
            
@ray.remote
class RayRolloutWorkerClass(object):
    """
    Rollout Worker with RAY
    """
    def __init__(self,worker_id=0,
                 hdims=[128],actv=tf.nn.relu,out_actv=tf.nn.tanh,
                 ep_len_rollout=15000,USE_NZD_OBS=True):
        self.worker_id = worker_id
        self.ep_len_rollout = ep_len_rollout
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim,self.adim = odim,adim
        self.USE_NZD_OBS = USE_NZD_OBS
        # Observation normalization
        self.obs_mu = np.zeros(self.odim)
        self.obs_std = np.ones(self.odim)
        # ARS model 
        self.model,self.sess = create_ars_model(
            odim=self.odim,adim=self.adim,hdims=hdims,
            actv=actv,out_actv=out_actv)
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True        
        print ("Ray Worker [%d] Ready."%(self.worker_id))
        
    def set_observation_stats(self,obs_mu,obs_std):
        self.obs_mu = np.copy(obs_mu) # call by value
        self.obs_std = np.copy(obs_std) # call by value
    def get_action(self,o):
        obs_std = self.obs_std
        obs_std[obs_std<1e-6] = np.inf
        if self.USE_NZD_OBS:
            nzd_o = (o-self.obs_mu)/obs_std # use whitened observation 
        else:
            nzd_o = o
        return self.sess.run(
            self.model['mu'],feed_dict={self.model['o_ph']:nzd_o.reshape(1,-1)})[0]
    def set_weights(self,weight_vals,noise_vals,noise_sign=+1):
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:
                           weight_vals[w_idx]+noise_sign*noise_vals[w_idx]})
    def rollout(self,
                red_list=[Agents.SPOT_RANDOM,Agents.EXPERT_SYSTEM]):
        """
        Rollout
        """
        obs_buffer,obs_cnt = np.zeros((len(red_list)*self.ep_len_rollout,self.odim)),0
        r_sum,n_step = 0,0 # reward sum and total steps
        for r_idx,red in enumerate(red_list): # for each red policy
            # Specify red policy
            self.o = self.env.reset(red=red) # reset env 
            for t in range(self.ep_len_rollout):
                self.a = self.get_action(self.o) 
                self.o2,self.r,self.d,_ = self.env.step(self.a)
                # Save next state 
                self.o = self.o2
                # Accumulate reward
                r_sum += self.r
                n_step += 1
                # Stack observation
                obs_buffer[obs_cnt,:] = self.o
                obs_cnt += 1
                if self.d: 
                    break 
        # Compute the average return and steps 
        r_avg = r_sum / len(red_list)
        n_step_avg = n_step / len(red_list)
        obs_buffer = obs_buffer[:obs_cnt,:] # trim observation buffer 
        return r_avg,n_step_avg,obs_buffer
    def evaluate(self,red=None):
        o,d,ep_ret,ep_len = self.env.reset(red=red),False,0,0
        while not(d or (ep_len == self.ep_len_rollout)):
            a = self.get_action(o)
            o,r,d,_ = self.env.step(a)
            ep_ret += r # compute return 
            ep_len += 1
        blue_health,red_health = self.env.blue_health,self.env.red_health
        
        # Other infos
        blue_height = self.env.manager._blue.state[0]
        red_height = self.env.manager._red.state[0]
        
        # return / length / blue health / red health / blue height / red height
        eval_res = [ep_ret,ep_len,blue_health,red_health,blue_height,red_height]
        return eval_res

# %% [markdown]
# ### Initialize

# %%
env = get_env()
adim,odim = env.action_space.shape[0],env.observation_space.shape[0]
print ("Environment Ready. odim:[%d] adim:[%d]."%(odim,adim))
# Out:
# Environment Ready. odim:[55] adim:[4].

# %% [markdown]
# ### Observation normalizer

# %%
mv = OnlineMeanVariance()

# %% [markdown]
# ### Initialize Workers

# %%
ray.init(num_cpus=n_cpu)
tf.reset_default_graph()
R = RolloutWorkerClass(hdims=hdims,actv=actv,out_actv=out_actv,seed=seed,USE_NZD_OBS=USE_NZD_OBS)
workers = [RayRolloutWorkerClass.remote(
    worker_id=i,hdims=hdims,actv=actv,out_actv=out_actv,
    ep_len_rollout=ep_len_rollout,USE_NZD_OBS=USE_NZD_OBS)
           for i in range(n_workers)]
print ("RAY initialized with [%d] cpus and [%d] workers."%
       (n_cpu,n_workers))
# Out:
# 2020-08-23 04:13:38,462	INFO resource_spec.py:212 -- Starting Ray with 165.62 GiB memory available for workers and up to 74.99 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-08-23 04:13:38,700	WARNING services.py:923 -- Redis failed to start, retrying now.
# 2020-08-23 04:13:38,915	INFO services.py:1165 -- View the Ray dashboard at localhost:8265
# RAY initialized with [101] cpus and [100] workers.

# %% [markdown]
# ### Loop

# %%
npz_path_list,ep_ret_avg,ep_ret_avg_list = [],0.0,[]
start_time = time.time()
n_env_step = 0 # number of environment steps
for t in range(int(total_steps)): # for all steps 
    esec = time.time()-start_time
    
    # 1. Distribute the central weights to distributed workers
    weights = R.get_weights() # weights of the central worker 
    noises_list = []
    for _ in range(n_workers):
        noises_list.append(get_noises_from_weights(weights,nu=nu))

    # 2. Positive rollouts using distributed workers
    set_weights_list = [worker.set_weights.remote(weights,noises,noise_sign=+1) 
                        for worker,noises in zip(workers,noises_list)] # set weights
    rollout_ops = [worker.rollout.remote(red_list=red_list_train)
           for worker in workers] # do positive rollouts
    res_pos_rollout = ray.get(rollout_ops) # get positive rollout results
    pos_rets,r_idx = np.zeros(n_workers),0
    for pos_ret,ep_len,obs_buffer in res_pos_rollout:
        pos_rets[r_idx] = pos_ret # return
        r_idx = r_idx + 1
        n_env_step += ep_len # accumulate episode length
        for obs in obs_buffer: mv.include(obs) # update observation mean and std

    # 3. Negative rollouts using distributed workers
    set_weights_list = [worker.set_weights.remote(weights,noises,noise_sign=-1) 
                        for worker,noises in zip(workers,noises_list)] # set weights
    rollout_ops = [worker.rollout.remote(red_list=red_list_train)
           for worker in workers] # do negative rollouts
    res_neg_rollout = ray.get(rollout_ops) # get negative rollout results
    neg_rets,r_idx = np.zeros(n_workers),0
    for neg_ret,ep_len,obs_buffer in res_neg_rollout:
        neg_rets[r_idx] = neg_ret # return
        r_idx = r_idx + 1
        n_env_step += ep_len # accumulate episode length
        for obs in obs_buffer: mv.include(obs) # update observation mean and std

    # 4. Compute return statistics and Update
    #  'pos_rets' 'neg_rets'
    concat_rets = np.concatenate((pos_rets,neg_rets)) # concatenated returns [2*n_workers]
    ret_deltas = pos_rets - neg_rets # return difference [n_workers]
    max_rets = np.maximum(pos_rets,neg_rets) # maximum returns [n_workers]
    max_ret = np.max(max_rets) # maximum return [1]
    avg_ret = np.mean(max_rets) # average return [1]
    sort_idx = np.argsort(-max_rets) # sort for resampling
    sigma_R = np.std(concat_rets)
    weights_updated = []
    for w_idx,weight in enumerate(weights): # for each weight 
        delta_weight_sum = np.zeros_like(weight)
        for k in range(b):
            idx_k = sort_idx[k] # sorted index
            ret_delta_k,noises_k,max_ret_k = ret_deltas[idx_k],noises_list[idx_k],max_rets[idx_k]
            noise_k = (1/nu)*noises_k[w_idx] # noise for current weight
            delta_weight_sum += ret_delta_k*noise_k # weighted sum
        delta_weight = (alpha/(b*sigma_R))*delta_weight_sum
        weight = weight + delta_weight
        weights_updated.append(weight) 

    # 5. Set weights of the central worker 
    R.set_weights(weights_updated)

    # Print
    if (t == 0) or (((t+1)%print_every) == 0):
        print ("[%d/%d] time:[%s] max_ret:[%.2f] avg_ret:[%.2f] sigma_R:[%.2f] "%
               (t,total_steps,time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
               max_ret,avg_ret,sigma_R))
        write_txt(f,"%.2f, r_train:%.4f, ret_eval:%.4f"%(time.time()-start_time,avg_ret,ep_ret_avg),
                  ADD_NEWLINE=True,DO_PRINT=False)
        
    # 6. Distribute the central weights to the distributed workers
    weights = R.get_weights() # get the updated weights from the central worker
    zero_noises_list = []
    for _ in range(n_workers):
        zero_noises_list.append(get_noises_from_weights(weights,nu=0))
    set_weights_list = [worker.set_weights.remote(weights,zero_noises,noise_sign=0) 
                        for worker,zero_noises in zip(workers,zero_noises_list)] 
    
    # Evaluate
    if (t == 0) or (((t+1)%evaluate_every) == 0): 
        ram_percent = psutil.virtual_memory().percent # memory usage
        print ("[Eval. start] step:[%d/%d][%.1f%%] #step:[%.1e] time:[%s] ram:[%.1f%%]."%
               (t+1,total_steps,t/total_steps*100,n_env_step,
                time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
                ram_percent)
              )
        ops = []
        for i_idx in range(num_eval):
            worker,red = workers[i_idx],red_list_eval[i_idx]
            ops.append(worker.evaluate.remote(red=red))
        eval_vals = ray.get(ops)
        
        ep_ret_sum = 0
        for i_idx in range(num_eval):
            red,eval_val = red_list_eval[i_idx],eval_vals[i_idx]
            ep_ret,ep_len,blue_health,red_health = eval_val[0],eval_val[1],eval_val[2],eval_val[3]
            blue_height,red_height = eval_val[4],eval_val[5]
            ep_ret_sum += ep_ret
            print (" [%d/%d][%s] Ret:[%.2f] Len:[%d]. Health B:[%.2f] R:[%.2f] Height B:[%.1e] R:[%.1e]"
                %(i_idx,len(eval_vals),red,ep_ret,ep_len,blue_health,red_health,blue_height,red_height))
        ep_ret_avg = ep_ret_sum / num_eval
        print ("[Eval. done] Time:[%s] Ret_Avg:[%.3f].\n"%
               (time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
                ep_ret_avg)
              )
        
        # Save
        npz_path = '../report/net/%s/model_%d.npz'%(exp_name,t+1)
        save_ars_model(npz_path,R,mv=mv,VERBOSE=False)
        
        # If something went bad, restore
        npz_path_list.append(npz_path)
        ep_ret_avg_list.append(ep_ret_avg)
        ep_ret_avg_array = np.asanyarray(ep_ret_avg_list)
        ep_ret_avg_max = np.max(ep_ret_avg_array)
        if (ep_ret_avg < 0.5*ep_ret_avg_max) and (len(npz_path_list) >= 2) and (ep_ret_avg_max > 0):
            npz_path = npz_path_list[np.argmax(ep_ret_avg_array)] 
            restore_ars_model(npz_path=npz_path,R=R,VERBOSE=False)
            print ("Restoring [%s] as current[%.2f] is way lower than max[%.2f]"%
                   (npz_path,ep_ret_avg,ep_ret_avg_max))
            
    # 7. Distribute observation mean and std to workers (after evaluation)
    obs_mean,obs_std = mv.mean,mv.std
    sef_obs_list= [worker.set_observation_stats.remote(obs_mean,obs_std) 
                   for worker in workers] # set observation mean and std
    
    # Loop 
    # break # for debugging 
    
print ("Done.")
# Out:
# (pid=102148)
# (pid=102148)
# (pid=102148)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102159)
# (pid=102159)
# (pid=102159)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102130)
# (pid=102130)
# (pid=102130)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102139)
# (pid=102139)
# (pid=102139)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102149)
# (pid=102149)
# (pid=102149)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102081)
# (pid=102081)
# (pid=102081)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102114)
# (pid=102114)
# (pid=102114)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102121)
# (pid=102121)
# (pid=102121)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102107)
# (pid=102107)
# (pid=102107)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102116)
# (pid=102116)
# (pid=102116)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102148) Ray Worker [60] Ready.
# (pid=102154)
# (pid=102154)
# (pid=102154)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102093)
# (pid=102093)
# (pid=102093)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102153)
# (pid=102153)
# (pid=102153)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102156)
# (pid=102156)
# (pid=102156)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102159) Ray Worker [79] Ready.
# (pid=102130) Ray Worker [84] Ready.
# (pid=102088)
# (pid=102088)
# (pid=102088)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102139) Ray Worker [6] Ready.
# (pid=102169)
# (pid=102169)
# (pid=102169)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102149) Ray Worker [93] Ready.
# (pid=102173)
# (pid=102173)
# (pid=102173)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102085)
# (pid=102085)
# (pid=102085)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102081) Ray Worker [42] Ready.
# (pid=102115)
# (pid=102115)
# (pid=102115)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102099)
# (pid=102099)
# (pid=102099)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102123)
# (pid=102123)
# (pid=102123)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102138)
# (pid=102138)
# (pid=102138)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102121) Ray Worker [38] Ready.
# (pid=102126)
# (pid=102126)
# (pid=102126)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102107) Ray Worker [24] Ready.
# (pid=102125)
# (pid=102125)
# (pid=102125)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102114) Ray Worker [57] Ready.
# (pid=102133)
# (pid=102133)
# (pid=102133)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102104)
# (pid=102104)
# (pid=102104)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102134)
# (pid=102134)
# (pid=102134)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102161)
# (pid=102161)
# (pid=102161)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102155)
# (pid=102155)
# (pid=102155)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102152)
# (pid=102152)
# (pid=102152)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102166)
# (pid=102166)
# (pid=102166)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102090)
# (pid=102090)
# (pid=102090)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102146)
# (pid=102146)
# (pid=102146)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102095)
# (pid=102095)
# (pid=102095)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102082)
# (pid=102082)
# (pid=102082)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102132)
# (pid=102132)
# (pid=102132)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102141)
# (pid=102141)
# (pid=102141)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102143)
# (pid=102143)
# (pid=102143)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102096)
# (pid=102096)
# (pid=102096)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102158)
# (pid=102158)
# (pid=102158)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102086)
# (pid=102086)
# (pid=102086)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102119)
# (pid=102119)
# (pid=102119)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102175)
# (pid=102175)
# (pid=102175)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102127)
# (pid=102127)
# (pid=102127)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102154) Ray Worker [2] Ready.
# (pid=102156) Ray Worker [87] Ready.
# (pid=102093) Ray Worker [50] Ready.
# (pid=102120)
# (pid=102120)
# (pid=102120)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102151)
# (pid=102151)
# (pid=102151)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102116) Ray Worker [14] Ready.
# (pid=102177)
# (pid=102177)
# (pid=102177)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102092)
# (pid=102092)
# (pid=102092)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102100)
# (pid=102100)
# (pid=102100)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102142)
# (pid=102142)
# (pid=102142)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102103)
# (pid=102103)
# (pid=102103)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102173) Ray Worker [10] Ready.
# (pid=102131)
# (pid=102131)
# (pid=102131)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102153) Ray Worker [23] Ready.
# (pid=102179)
# (pid=102179)
# (pid=102179)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102174)
# (pid=102174)
# (pid=102174)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102108)
# (pid=102108)
# (pid=102108)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102110)
# (pid=102110)
# (pid=102110)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102172)
# (pid=102172)
# (pid=102172)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102109)
# (pid=102109)
# (pid=102109)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102164)
# (pid=102164)
# (pid=102164)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102160)
# (pid=102160)
# (pid=102160)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102085) Ray Worker [28] Ready.
# (pid=102113)
# (pid=102113)
# (pid=102113)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102094)
# (pid=102094)
# (pid=102094)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102087)
# (pid=102087)
# (pid=102087)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102118)
# (pid=102118)
# (pid=102118)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102165)
# (pid=102165)
# (pid=102165)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102101)
# (pid=102101)
# (pid=102101)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102135)
# (pid=102135)
# (pid=102135)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102115) Ray Worker [80] Ready.
# (pid=102088) Ray Worker [3] Ready.
# (pid=102098)
# (pid=102098)
# (pid=102098)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102099) Ray Worker [21] Ready.
# (pid=102111)
# (pid=102111)
# (pid=102111)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102171)
# (pid=102171)
# (pid=102171)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102124)
# (pid=102124)
# (pid=102124)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102128)
# (pid=102128)
# (pid=102128)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102112)
# (pid=102112)
# (pid=102112)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102147)
# (pid=102147)
# (pid=102147)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102122)
# (pid=102122)
# (pid=102122)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102169) Ray Worker [81] Ready.
# (pid=102150)
# (pid=102150)
# (pid=102150)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102102)
# (pid=102102)
# (pid=102102)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102140)
# (pid=102140)
# (pid=102140)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102123) Ray Worker [18] Ready.
# (pid=102145)
# (pid=102145)
# (pid=102145)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102181)
# (pid=102181)
# (pid=102181)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102168)
# (pid=102168)
# (pid=102168)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102133) Ray Worker [12] Ready.
# (pid=102105)
# (pid=102105)
# (pid=102105)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102137)
# (pid=102137)
# (pid=102137)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102134) Ray Worker [48] Ready.
# (pid=102155) Ray Worker [78] Ready.
# (pid=102104) Ray Worker [41] Ready.
# (pid=102161) Ray Worker [43] Ready.
# (pid=102084)
# (pid=102084)
# (pid=102084)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102083)
# (pid=102083)
# (pid=102083)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102126) Ray Worker [31] Ready.
# (pid=102117)
# (pid=102117)
# (pid=102117)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102089)
# (pid=102089)
# (pid=102089)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102162)
# (pid=102162)
# (pid=102162)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102106)
# (pid=102106)
# (pid=102106)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102152) Ray Worker [22] Ready.
# (pid=102167)
# (pid=102167)
# (pid=102167)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102176)
# (pid=102176)
# (pid=102176)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102170)
# (pid=102170)
# (pid=102170)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102138) Ray Worker [97] Ready.
# (pid=102125) Ray Worker [33] Ready.
# (pid=102146) Ray Worker [86] Ready.
# (pid=102166) Ray Worker [49] Ready.
# (pid=102157)
# (pid=102157)
# (pid=102157)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102091)
# (pid=102091)
# (pid=102091)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102163)
# (pid=102163)
# (pid=102163)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102180)
# (pid=102180)
# (pid=102180)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102090) Ray Worker [25] Ready.
# (pid=102129)
# (pid=102129)
# (pid=102129)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102127) Ray Worker [71] Ready.
# (pid=102095) Ray Worker [13] Ready.
# (pid=102097)
# (pid=102097)
# (pid=102097)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102136)
# (pid=102136)
# (pid=102136)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102082) Ray Worker [37] Ready.
# (pid=102132) Ray Worker [8] Ready.
# (pid=102158) Ray Worker [7] Ready.
# (pid=102086) Ray Worker [54] Ready.
# (pid=102144)
# (pid=102144)
# (pid=102144)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=102119) Ray Worker [72] Ready.
# (pid=102141) Ray Worker [69] Ready.
# (pid=102175) Ray Worker [62] Ready.
# (pid=102096) Ray Worker [51] Ready.
# (pid=102120) Ray Worker [66] Ready.
# (pid=102143) Ray Worker [95] Ready.
# (pid=102179) Ray Worker [0] Ready.
# (pid=102092) Ray Worker [45] Ready.
# (pid=102103) Ray Worker [53] Ready.
# (pid=102131) Ray Worker [36] Ready.
# (pid=102177) Ray Worker [90] Ready.
# (pid=102151) Ray Worker [89] Ready.
# (pid=102100) Ray Worker [35] Ready.
# (pid=102142) Ray Worker [52] Ready.
# (pid=102109) Ray Worker [27] Ready.
# (pid=102174) Ray Worker [83] Ready.
# (pid=102108) Ray Worker [34] Ready.
# (pid=102110) Ray Worker [20] Ready.
# (pid=102172) Ray Worker [11] Ready.
# (pid=102160) Ray Worker [58] Ready.
# (pid=102094) Ray Worker [88] Ready.
# (pid=102101) Ray Worker [4] Ready.
# (pid=102113) Ray Worker [15] Ready.
# (pid=102164) Ray Worker [29] Ready.
# (pid=102118) Ray Worker [65] Ready.
# (pid=102165) Ray Worker [92] Ready.
# (pid=102098) Ray Worker [77] Ready.
# (pid=102124) Ray Worker [44] Ready.
# (pid=102128) Ray Worker [67] Ready.
# (pid=102135) Ray Worker [16] Ready.
# (pid=102150) Ray Worker [5] Ready.
# (pid=102168) Ray Worker [1] Ready.
# (pid=102087) Ray Worker [55] Ready.
# (pid=102171) Ray Worker [39] Ready.
# (pid=102112) Ray Worker [68] Ready.
# (pid=102147) Ray Worker [75] Ready.
# (pid=102122) Ray Worker [91] Ready.
# (pid=102181) Ray Worker [99] Ready.
# (pid=102162) Ray Worker [64] Ready.
# (pid=102140) Ray Worker [73] Ready.
# (pid=102145) Ray Worker [76] Ready.
# (pid=102167) Ray Worker [40] Ready.
# (pid=102170) Ray Worker [19] Ready.
# (pid=102180) Ray Worker [98] Ready.
# (pid=102084) Ray Worker [59] Ready.
# (pid=102105) Ray Worker [74] Ready.
# (pid=102106) Ray Worker [26] Ready.
# (pid=102091) Ray Worker [46] Ready.
# (pid=102129) Ray Worker [85] Ready.
# (pid=102111) Ray Worker [30] Ready.
# (pid=102137) Ray Worker [63] Ready.
# (pid=102102) Ray Worker [17] Ready.
# (pid=102163) Ray Worker [82] Ready.
# (pid=102083) Ray Worker [70] Ready.
# (pid=102089) Ray Worker [61] Ready.
# (pid=102144) Ray Worker [32] Ready.
# (pid=102117) Ray Worker [9] Ready.
# (pid=102176) Ray Worker [94] Ready.
# (pid=102157) Ray Worker [96] Ready.
# (pid=102097) Ray Worker [47] Ready.
# (pid=102136) Ray Worker [56] Ready.
# [0/5000] time:[day:[01] 00:34:48] max_ret:[54.20] avg_ret:[15.96] sigma_R:[20.43]
# [Eval. start] step:[1/5000][0.0%] #step:[5.1e+05] time:[day:[01] 00:34:48] ram:[13.7%].
#  [0/100][zombie] Ret:[1.88] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.8e+04] R:[1.8e+04]
#  [1/100][rosie] Ret:[1.14] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.4e+04] R:[1.4e+04]
#  [2/100][bud] Ret:[-0.04] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.1e+04] R:[1.1e+04]
#  [3/100][bud_fsm] Ret:[100.76] Len:[2459]. Health B:[1.00] R:[0.00] Height B:[6.6e+03] R:[7.2e+03]
#  [4/100][expert_system] Ret:[-100.24] Len:[1409]. Health B:[0.00] R:[1.00] Height B:[3.0e+03] R:[2.1e+03]
#  [5/100][zombie] Ret:[-0.21] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.8e+04] R:[1.6e+04]
#  [6/100][rosie] Ret:[7.50] Len:[3001]. Health B:[1.00] R:[0.94] Height B:[7.3e+03] R:[7.2e+03]
#  [7/100][bud] Ret:[8.94] Len:[3001]. Health B:[1.00] R:[0.92] Height B:[1.5e+04] R:[1.4e+04]
#  [8/100][bud_fsm] Ret:[1.03] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1
Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.3e+04] R:[1.1e+04]
#  [96/100][rosie] Ret:[67.95] Len:[3001]. Health B:[1.00] R:[0.34] Height B:[1.0e+04] R:[1.0e+04]
#  [97/100][bud] Ret:[0.16] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[9.9e+03] R:[1.2e+04]
#  [98/100][bud_fsm] Ret:[0.81] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[9.9e+03] R:[9.8e+03]
#  [99/100][expert_system] Ret:[82.51] Len:[3001]. Health B:[0.86] R:[0.02] Height B:[2.7e+03] R:[2.4e+03]
# [Eval. done] Time:[day:[01] 00:37:46] Ret_Avg:[2.118].
#
# [../report/net/ars_adt_cont/model_1.npz] saved.
# [1/5000] time:[day:[01] 01:11:59] max_ret:[63.66] avg_ret:[18.64] sigma_R:[21.79]
# [2/5000] time:[day:[01] 01:44:32] max_ret:[78.15] avg_ret:[24.03] sigma_R:[22.06]
# [3/5000] time:[day:[01] 02:15:38] max_ret:[93.60] avg_ret:[30.22] sigma_R:[25.31]
# [4/5000] time:[day:[01] 02:45:35] max_ret:[99.74] avg_ret:[34.33] sigma_R:[24.09]
# [Eval. start] step:[5/5000][0.1%] #step:[2.4e+06] time:[day:[01] 02:45:35] ram:[14.4%].
#  [0/100][zombie] Ret:[100.12] Len:[91]. Health B:[1.00] R:[0.00] Height B:[5.7e+03] R:[5.7e+03]
#  [1/100][rosie] Ret:[100.60] Len:[1456]. Health B:[1.00] R:[0.00] Height B:[1.4e+04] R:[1.4e+04]
#  [2/100][bud] Ret:[0.38] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.3e+03] R:[2.7e+03]
#  [3/100][bud_fsm] Ret:[100.39] Len:[701]. Health B:[1.00] R:[0.00] Height B:[1.1e+04] R:[1.2e+04]
#  [4/100][expert_system] Ret:[-100.21] Len:[534]. Health B:[0.00] R:[1.00] Height B:[1.9e+03] R:[2.2e+03]
#  [5/100][zombie] Ret:[-0.05] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.1e+04] R:[1.5e+04]
#  [6/100][rosie] Ret:[100.98] Len:[1113]. Health B:[1.00] R:[0.00] Height B:[1.7e+04] R:[1.7e+04]
#  [7/100][bud] Ret:[100.29] Len:[2796]. Health B:[1.00] R:[0.00] Height B:[1.4e+03] R:[1.0e+03]
#  [8/100][bud_fsm] Ret:[100.41] Len:[982]. Health B:[1.00] R:[0.00] Height B:[1.4e+04] R:[1.5e+04]
#  [9/100][expert_system] Ret:[100.48] Len:[1086]. Health B:[1.00] R:[0.00] Height B:[2.1e+03] R:[1.9e+03]
#  [10/100][zombie] Ret:[0.19] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.2e+04] R:[1.3e+04]
#  [11/100][rosie] Ret:[100.63] Len:[2172]. Health B:[1.00] R:[0.00] Height B:[2.8e+03] R:[2.7e+03]
#  [12/100][bud] Ret:[0.41] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.3e+03] R:[1.1e+03]
#  [13/100][bud_fsm] Ret:[100.52] Len:[524]. Health B:[1.00] R:[0.00] Height B:[7.6e+03] R:[8.4e+03]
#  [14/100][expert_system] Ret:[82.16] Len:[348]. Health B:[0.82] R:[0.00] Height B:[1.2e+04] R:[1.1e+04]
#  [15/100][zombie] Ret:[32.87] Len:[3001]. Health B:[1.00] R:[0.68] Height B:[8.1e+03] R:[8.8e+03]
#  [16/100][rosie] Ret:[100.58] Len:[630]. Health B:[1.00] R:[0.00] Height B:[2.8e+03] R:[2.8e+03]
#  [17/100][bud] Ret:[0.10] Len:[3001]. Health B:[1.00] R:[1.00] Height B:
#  [89/100][expert_system] Ret:[-101.14] Len:[1954]. Health B:[0.00] R:[1.00] Height B:[2.3e+03] R:[4.1e+03]
#  [90/100][zombie] Ret:[100.58] Len:[666]. Health B:[1.00] R:[0.00] Height B:[1.4e+04] R:[1.4e+04]
#  [91/100][rosie] Ret:[100.66] Len:[2544]. Health B:[1.00] R:[0.00] Height B:[1.8e+04] R:[1.8e+04]
#  [92/100][bud] Ret:[100.06] Len:[874]. Health B:[1.00] R:[0.00] Height B:[1.6e+03] R:[1.0e+03]
#  [93/100][bud_fsm] Ret:[100.30] Len:[575]. Health B:[1.00] R:[0.00] Height B:[1.0e+04] R:[1.1e+04]
#  [94/100][expert_system] Ret:[-100.73] Len:[1212]. Health B:[0.00] R:[1.00] Height B:[1.8e+03] R:[2.5e+03]
#  [95/100][zombie] Ret:[101.63] Len:[2968]. Health B:[1.00] R:[0.00] Height B:[7.0e+03] R:[7.1e+03]
#  [96/100][rosie] Ret:[100.71] Len:[2317]. Health B:[1.00] R:[0.00] Height B:[1.0e+04] R:[1.1e+04]
#  [97/100][bud] Ret:[100.35] Len:[584]. Health B:[1.00] R:[0.00] Height B:[1.4e+03] R:[1.0e+03]
#  [98/100][bud_fsm] Ret:[100.23] Len:[350]. Health B:[1.00] R:[0.00] Height B:[1.5e+04] R:[1.6e+04]
#  [99/100][expert_system] Ret:[-100.21] Len:[403]. Health B:[0.00] R:[1.00] Height B:[6.0e+03] R:[6.0e+03]
# [Eval. done] Time:[day:[01] 02:47:54] Ret_Avg:[52.816].
#
# [../report/net/ars_adt_cont/model_5.npz] saved.
# [5/5000] time:[day:[01] 03:17:44] max_ret:[100.41] avg_ret:[34.22] sigma_R:[25.06]
# [6/5000] time:[day:[01] 03:47:50] max_ret:[83.68] avg_ret:[39.16] sigma_R:[26.88]
# [7/5000] time:[day:[01] 04:17:14] max_ret:[99.55] avg_ret:[38.92] sigma_R:[25.68]
# [8/5000] time:[day:[01] 04:46:56] max_ret:[84.55] avg_ret:[37.20] sigma_R:[25.46]
# [9/5000] time:[day:[01] 05:15:15] max_ret:[98.45] avg_ret:[40.28] sigma_R:[25.14]
# [Eval. start] step:[10/5000][0.2%] #step:[4.4e+06] time:[day:[01] 05:15:15] ram:[14.6%].
#  [0/100][zombie] Ret:[0.09] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[8.4e+03] R:[9.4e+03]
#  [1/100][rosie] Ret:[100.63] Len:[1426]. Health B:[1.00] R:[0.00] Height B:[9.9e+03] R:[9.9e+03]
#  [2/100][bud] Ret:[100.35] Len:[2495]. Health B:[1.00] R:[0.00] Height B:[1.5e+03] R:[1.0e+03]
#  [3/100][bud_fsm] Ret:[100.35] Len:[478]. Health B:[1.00] R:[0.00] Height B:[1.0e+04] R:[1.1e+04]
#  [4/100][expert_system] Ret:[100.05] Len:[2641]. Health B:[1.00] R:[0.00] Height B:[1.9e+03] R:[2.1e+03]
#  [5/100][zombie] Ret:[100.78] Len:[1410]. Health B:[1.00] R:[0.00] Height B:[2.0e+04] R:[2.0e+04]
#  [6/100][rosie] Ret:[100.38] Len:[1836]. Health B:[1.00] R:[0.00] Height B:[1.5e+04] R:[1.5e+04]
#  [7/100][bud] Ret:[0.28] Len:[3001]. Health B:[1.00] R:[1.00] Height B:
Len:[3001]. Health B:[1.00] R:[1.00] Height B:[8.4e+03] R:[8.3e+03]
#  [83/100][bud_fsm] Ret:[100.91] Len:[2570]. Health B:[1.00] R:[0.00] Height B:[6.9e+03] R:[7.4e+03]
#  [84/100][expert_system] Ret:[-19.77] Len:[3001]. Health B:[0.59] R:[0.79] Height B:[1.2e+03] R:[2.1e+03]
#  [85/100][zombie] Ret:[0.28] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.3e+04] R:[1.5e+04]
#  [86/100][rosie] Ret:[0.94] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.9e+04] R:[1.9e+04]
#  [87/100][bud] Ret:[58.48] Len:[3001]. Health B:[1.00] R:[0.42] Height B:[4.7e+03] R:[4.8e+03]
#  [88/100][bud_fsm] Ret:[1.57] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[3.3e+03] R:[3.4e+03]
#  [89/100][expert_system] Ret:[100.51] Len:[848]. Health B:[1.00] R:[0.00] Height B:[4.8e+03] R:[4.1e+03]
#  [90/100][zombie] Ret:[0.55] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[7.7e+03] R:[8.0e+03]
#  [91/100][rosie] Ret:[100.65] Len:[1515]. Health B:[1.00] R:[0.00] Height B:[1.5e+04] R:[1.5e+04]
#  [92/100][bud] Ret:[0.28] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[7.3e+03] R:[7.1e+03]
#  [93/100][bud_fsm] Ret:[100.34] Len:[2174]. Health B:[1.00] R:[0.00] Height B:[2.6e+03] R:[3.2e+03]
#  [94/100][expert_system] Ret:[-100.21] Len:[1014]. Health B:[0.00] R:[1.00] Height B:[2.7e+03] R:[3.1e+03]
#  [95/100][zombie] Ret:[0.17] Len:[2935]. Health B:[1.00] R:[1.00] Height B:[9.9e+03] R:[1.2e+04]
#  [96/100][rosie] Ret:[101.62] Len:[2241]. Health B:[1.00] R:[0.00] Height B:[7.3e+03] R:[7.3e+03]
#  [97/100][bud] Ret:[100.32] Len:[2634]. Health B:[1.00] R:[0.00] Height B:[1.4e+03] R:[1.0e+03]
#  [98/100][bud_fsm] Ret:[0.18] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.0e+04] R:[1.0e+04]
#  [99/100][expert_system] Ret:[100.80] Len:[2888]. Health B:[1.00] R:[0.00] Height B:[1.5e+03] R:[1.0e+03]
# [Eval. done] Time:[day:[01] 05:17:41] Ret_Avg:[39.900].
#
# [../report/net/ars_adt_cont/model_10.npz] saved.
# [10/5000] time:[day:[01] 05:46:49] max_ret:[100.53] avg_ret:[37.50] sigma_R:[23.44]
# (pid=102171) /home/schoi/.adt/venv-adt/lib/python3.6/site-packages/gym_jsbsim/visualiser.py:717: RuntimeWarning: divide by zero encountered in double_scalars
# (pid=102171)   rel_pos = 1/distance *(pos_red - pos_blue)
# (pid=102171) Exception in thread Thread-559:
# (pid=102171) Traceback (most recent call last):
# (pid=102171)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=102171)     self.run()
# (pid=102171)   File "/home/schoi/.adt/venv-adt/lib/python3.6/site-packages/adt/render_thread.py", line 34, in run
# (pid=102171)     self.render()
# (pid=102171)   File "/home/schoi/.adt/venv-adt/lib/python3.6/site-packages/adt/render_thread.py", line 50, in render
# (pid=102171)     self._env.render(mode='dis')
# (pid=102171)   File "/home/schoi/.adt/venv-adt/lib/python3.6/site-packages/gym_jsbsim/environment.py", line 286, in render
# (pid=102171)     self.dis_visualiser.send_dataPdu(self.sim)
# (pid=102171)   File "/home/schoi/.adt/venv-adt/lib/python3.6/site-packages/gym_jsbsim/visualiser.py", line 722, in send_dataPdu
# (pid=102171)     closure = int(((rel_pos.T.dot(v_blue_enu) - rel_pos.T.dot(v_red_enu))[0])[0])
# (pid=102171) ValueError: cannot convert float NaN to integer
# (pid=102171)
# [11/5000] time:[day:[01] 06:17:02] max_ret:[100.55] avg_ret:[39.67] sigma_R:[25.78]
# [12/5000] time:[day:[01] 06:45:44] max_ret:[95.85] avg_ret:[43.50] sigma_R:[26.47]
# [13/5000] time:[day:[01] 07:15:31] max_ret:[93.37] avg_ret:[40.01] sigma_R:[26.97]
# [14/5000] time:[day:[01] 07:44:13] max_ret:[84.64] avg_ret:[38.03] sigma_R:[25.67]
# [Eval. start] step:[15/5000][0.3%] #step:[6.5e+06] time:[day:[01] 07:44:13] ram:[14.8%].
#  [0/100][zombie] Ret:[0.07] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.0e+04] R:[1.1e+04]
#  [1/100][rosie] Ret:[100.56] Len:[1385]. Health B:[1.00] R:[0.00] Height B:[1.3e+04] R:[1.3e+04]
#  [2/100][bud] Ret:[46.26] Len:[3001]. Health B:[1.00] R:[0.55] Height B:[4.9e+03] R:[7.3e+03]
#  [3/100][bud_fsm] Ret:[100.30] Len:[2520]. Health B:[1.00] R:[0.00] Height B:[4.8e+03] R:[5.4e+03]
#  [4/100][expert_system] Ret:[34.44] Len:[3001]. Health B:[1.00] R:[0.66] Height B:[2.0e+03] R:[2.3e+03]
#  [5/100][zombie] Ret:[100.39] Len:[748]. Health B:[1.00] R:[0.00] Height B:[1.1e+04] R:[1.1e+04]
#  [6/100][rosie] Ret:[101.18] Len:[1195]. Health B:[1.00] R:[0.00] Height B:[7.9e+03] R:[7.9e+03]
#  [7/100][bud] Ret:[100.61] Len:[2563]. Health B:[1.00] R:[0.00] Height B:[4.2e+03] R:[4.1e+03]
# ...
#  [46/100][rosie] Ret:[100.83] Len:[1013]. Health B:[1.00] R:[0.00] Height B:[1.2e+04] R:[1.2e+04]
#  [47/100][bud] Ret:[100.04] Len:[1237]. Health B:[1.00] R:[0.00] Height B:[1.4e+03] R:[1.0e+03]
#  [48/100][bud_fsm] Ret:[100.22] Len:[440]. Health B:[1.00] R:[0.00] Height B:[1.7e+04] R:[1.7e+04]
#  [49/100][expert_system] Ret:[-63.80] Len:[3001]. Health B:[0.37] R:[1.00] Height B:[1.7e+03] R:[1.6e+03]
#  [50/100][zombie] Ret:[0.70] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.3e+04] R:[1.4e+04]
#  [51/100][rosie] Ret:[100.89] Len:[2189]. Health B:[1.00] R:[0.00] Height B:[1.5e+04] R:[1.5e+04]
#  [52/100][bud] Ret:[89.05] Len:[3001]. Health B:[1.00] R:[0.11] Height B:[5.2e+03] R:[5.0e+03]
#  [53/100][bud_fsm] Ret:[100.13] Len:[254]. Health B:[1.00] R:[0.00] Height B:[1.4e+04] R:[1.4e+04]
#  [54/100][expert_system] Ret:[-100.71] Len:[2195]. Health B:[0.00] R:[1.00] Height B:[3.8e+03] R:[3.1e+03]
#  [55/100][zombie] Ret:[-0.05] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.4e+04] R:[1.6e+04]
#  [56/100][rosie] Ret:[88.20] Len:[3001]. Health B:[1.00] R:[0.13] Height B:[1.3e+04] R:[1.4e+04]
#  [57/100][bud] Ret:[100.68] Len:[2610]. Health B:[1.00] R:[0.00] Height B:[3.8e+03] R:[3.8e+03]
#  [58/100][bud_fsm] Ret:[100.35] Len:[350]. Health B:[1.00] R:[0.00] Height B:[8.8e+03] R:[9.1e+03]
#  [59/100][expert_system] Ret:[9.44] Len:[3001]. Health B:[0.69] R:[0.59] Height B:[2.6e+03] R:[4.0e+03]
#  [60/100][zombie] Ret:[1.17] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[6.4e+03] R:[7.2e+03]
#  [61/100][rosie] Ret:[100.70] Len:[2462]. Health B:[1.00] R:[0.00] Height B:[1.8e+04] R:[1.8e+04]
#  [62/100][bud] Ret:[100.21] Len:[170]. Health B:[1.00] R:[0.00] Height B:[1.2e+04] R:[1.2e+04]
#  [63/100][bud_fsm] Ret:[100.40] Len:[596]. Health B:[1.00] R:[0.00] Height B:[8.6e+03] R:[9.3e+03]
#  [64/100][expert_system] Ret:[-69.95] Len:[2646]. Health B:[0.00] R:[0.69] Height B:[5.1e+03] R:[3.7e+03]
#  [65/100][zombie] Ret:[0.08] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[2.5e+03] R:[4.5e+03]
#  [66/100][rosie] Ret:[100.59] Len:[2134]. Health B:[1.00] R:[0.00] Height B:[2.8e+03] R:[2.7e+03]
#  [67/100][bud] Ret:[100.11] Len:[2826]. Health B:[1.00] R:[0.00] Height B:[1.3e+03] R:[1.0e+03]
#  [68/100][bud_fsm] Ret:[100.37] Len:[864]. Health B:[1.00] R:[0.00] Height B:[1.5e+04] R:[1.6e+04]
#  [69/100][expert_system] Ret:[-38.85] Len:[3001]. Health B:[0.17] R:[0.55] Height B:[1.7e+03] R:[1.2e+03]
#  [70/100][zombie] Ret:[0.21] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[4.8e+03] R:[6.0e+03]
#  [71/100][rosie] Ret:[101.15] Len:[2427]. Health B:[1.00] R:[0.00] Height B:[1.6e+04] R:[1.5e+04]
#  [72/100][bud] Ret:[0.59] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.4e+03] R:[1.8e+03]
#  [73/100][bud_fsm] Ret:[100.44] Len:[612]. Health B:[1.00] R:[0.00] Height B:[1.1e+04] R:[1.1e+04]
#  [74/100][expert_system] Ret:[34.53] Len:[3001]. Health B:[1.00] R:[0.66] Height B:[1.1e+03] R:[2.1e+03]
#  [75/100][zombie] Ret:[100.93] Len:[2272]. Health B:[1.00] R:[0.00] Height B:[1.7e+04] R:[1.7e+04]
#  [76/100][rosie] Ret:[100.87] Len:[2822]. Health B:[1.00] R:[0.00] Height B:[1.7e+04] R:[1.7e+04]
#  [77/100][bud] Ret:[100.32] Len:[2652]. Health B:[1.00] R:[0.00] Height B:[3.9e+03] R:[3.8e+03]
#  [78/100][bud_fsm] Ret:[100.53] Len:[1080]. Health B:[1.00] R:[0.00] Height B:[8.5e+03] R:[9.3e+03]
#  [79/100][expert_system] Ret:[-100.44] Len:[1260]. Health B:[0.00] R:[1.00] Height B:[4.5e+03] R:[5.5e+03]
#  [80/100][zombie] Ret:[0.67] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[8.5e+03] R:[9.0e+03]
#  [81/100][rosie] Ret:[100.68] Len:[853]. Health B:[1.00] R:[0.00] Height B:[5.0e+03] R:[5.9e+03]
#  [82/100][bud] Ret:[100.36] Len:[2647]. Health B:[1.00] R:[0.00] Height B:[2.4e+03] R:[2.3e+03]
#  [83/100][bud_fsm] Ret:[100.43] Len:[1030]. Health B:[1.00] R:[0.00] Height B:[7.3e+03] R:[7.8e+03]
#  [84/100][expert_system] Ret:[-100.45] Len:[997]. Health B:[0.00] R:[1.00] Height B:[7.6e+03] R:[8.4e+03]
#  [85/100][zombie] Ret:[100.39] Len:[2028]. Health B:[1.00] R:[0.00] Height B:[1.9e+04] R:[1.9e+04]
#  [86/100][rosie] Ret:[101.16] Len:[1389]. Health B:[1.00] R:[0.00] Height B:[7.8e+03] R:[7.8e+03]
#  [87/100][bud] Ret:[100.48] Len:[2736]. Health B:[1.00] R:[0.00] Height B:[2.5e+03] R:[2.4e+03]
#  [88/100][bud_fsm] Ret:[100.67] Len:[1169]. Health B:[1.00] R:[0.00] Height B:[9.9e+03] R:[1.0e+04]
#  [89/100][expert_system] Ret:[23.49] Len:[3001]. Health B:[1.00] R:[0.76] Height B:[3.4e+03] R:[2.0e+03]
#  [90/100][zombie] Ret:[0.04] Len:[1919]. Health B:[1.00] R:[1.00] Height B:[1.3e+04] R:[1.5e+04]
#  [91/100][rosie] Ret:[100.68] Len:[1483]. Health B:[1.00] R:[0.00] Height B:[1.8e+04] R:[1.8e+04]
#  [92/100][bud] Ret:[100.28] Len:[231]. Health B:[1.00] R:[0.00] Height B:[1.9e+04] R:[1.8e+04]
#  [93/100][bud_fsm] Ret:[100.25] Len:[491]. Health B:[1.00] R:[0.00] Height B:[1.5e+04] R:[1.5e+04]
#  [94/100][expert_system] Ret:[-92.15] Len:[1566]. Health B:[0.00] R:[0.92] Height B:[3.2e+03] R:[2.8e+03]
#  [95/100][zombie] Ret:[0.37] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.2e+04] R:[1.3e+04]
#  [96/100][rosie] Ret:[100.67] Len:[697]. Health B:[1.00] R:[0.00] Height B:[4.3e+03] R:[4.3e+03]
#  [97/100][bud] Ret:[100.27] Len:[2186]. Health B:[1.00] R:[0.00] Height B:[1.4e+03] R:[1.0e+03]
#  [98/100][bud_fsm] Ret:[100.45] Len:[774]. Health B:[1.00] R:[0.00] Height B:[1.2e+04] R:[1.3e+04]
#  [99/100][expert_system] Ret:[-100.80] Len:[1654]. Health B:[0.00] R:[1.00] Height B:[3.8e+03] R:[4.9e+03]
# [Eval. done] Time:[day:[01] 10:14:19] Ret_Avg:[52.448].
#
# [../report/net/ars_adt_cont/model_20.npz] saved.
# [20/5000] time:[day:[01] 10:43:29] max_ret:[89.57] avg_ret:[41.40] sigma_R:[24.61]
# [21/5000] time:[day:[01] 11:12:53] max_ret:[100.31] avg_ret:[43.68] sigma_R:[25.97]
# [22/5000] time:[day:[01] 11:43:14] max_ret:[100.72] avg_ret:[44.97] sigma_R:[26.13]
# [23/5000] time:[day:[01] 12:12:18] max_ret:[99.03] avg_ret:[46.97] sigma_R:[26.92]
# [24/5000] time:[day:[01] 12:41:03] max_ret:[100.91] avg_ret:[49.86] sigma_R:[26.28]
# [Eval. start] step:[25/5000][0.5%] #step:[1.1e+07] time:[day:[01] 12:41:03] ram:[14.9%].
#  [0/100][zombie] Ret:[100.70] Len:[663]. Health B:[1.00] R:[0.00] Height B:[1.2e+04] R:[1.2e+04]
#  [1/100][rosie] Ret:[100.75] Len:[1419]. Health B:[1.00] R:[0.00] Height B:[1.2e+04] R:[1.2e+04]
#  [2/100][bud] Ret:[0.35] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.3e+04] R:[1.3e+04]
#  [3/100][bud_fsm] Ret:[0.42] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.3e+04] R:[1.3e+04]
#  [4/100][expert_system] Ret:[101.24] Len:[2177]. Health B:[1.00] R:[0.00] Height B:[4.5e+03] R:[5.5e+03]
#  [5/100][zombie] Ret:[0.29] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[4.1e+03] R:[4.3e+03]
#  [6/100][rosie] Ret:[100.55] Len:[551]. Health B:[1.00] R:[0.00] Height B:[3.0e+03] R:[3.0e+03]
#  [7/100][bud] Ret:[93.66] Len:[3001]. Health B:[1.00] R:[0.07] Height B:[1.2e+03] R:[1.2e+03]
#  [8/100][bud_fsm] Ret:[100.27] Len:[2151]. Health B:[1.00] R:[0.00] Height B:[5.3e+03] R:[5.8e+03]
#  [9/100][expert_system] Ret:[99.98] Len:[2932]. Health B:[1.00] R:[0.00] Height B:[1.3e+03] R:[1.0e+03]
#  [10/100][zombie] Ret:[100.42] Len:[647]. Health B:[1.00] R:[0.00] Height B:[7.2e+03] R:[7.2e+03]
#  [11/100][rosie] Ret:[100.74] Len:[608]. Health B:[1.00] R:[0.00] Height B:[1.1e+04] R:[1.1e+04]
#  [12/100][bud] Ret:[62.99] Len:[3001]. Health B:[1.00] R:[0.40] Height B:[1.1e+04] R:[1.0e+04]
#  [13/100][bud_fsm] Ret:[100.19] Len:[319]. Health B:[1.00] R:[0.00] Height B:[9.8e+03] R:[1.0e+04]
#  [14/100][expert_system] Ret:[100.97] Len:[2239]. Health B:[1.00] R:[0.00] Height B:[1.9e+03] R:[2.0e+03]
#  [15/100][zombie] Ret:[0.23] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.8e+04] R:[1.8e+04]
#  [16/100][rosie] Ret:[100.44] Len:[411]. Health B:[1.00] R:[0.00] Height B:[4.5e+03] R:[4.5e+03]
#  [17/100][bud] Ret:[1.59] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[7.8e+03] R:[7.6e+03]
#  [18/100][bud_fsm] Ret:[100.65] Len:[1290]. Health B:[1.00] R:[0.00] Height B:[1.3e+04] R:[1.3e+04]
#  [19/100][expert_system] Ret:[-100.71] Len:[1353]. Health B:[0.00] R:[1.00] Height B:[3.8e+03] R:[3.3e+03]
#  [20/100][zombie] Ret:[0.07] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.7e+04] R:[2.0e+04]
#  [21/100][rosie] Ret:[0.91] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.6e+04] R:[2.0e+04]
#  [22/100][bud] Ret:[0.36] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[7.5e+03] R:[8.1e+03]
#  [23/100][bud_fsm] Ret:[100.26] Len:[425]. Health B:[1.00] R:[0.00] Height B:[1.8e+04] R:[1.8e+04]
#  [24/100][expert_system] Ret:[-93.22] Len:[2750]. Health B:[0.00] R:[0.92] Height B:[3.2e+03] R:[2.9e+03]
#  [25/100][zombie] Ret:[100.48] Len:[931]. Health B:[1.00] R:[0.00] Height B:[8.8e+03] R:[8.8e+03]
#  [26/100][rosie] Ret:[20.74] Len:[3001]. Health B:[1.00] R:[0.81] Height B:[3.0e+03] R:[2.9e+03]
#  [27/100][bud] Ret:[100.45] Len:[2916]. Health B:[1.00] R:[0.00] Height B:[4.1e+03] R:[3.9e+03]
#  [28/100][bud_fsm] Ret:[101.03] Len:[2682]. Health B:[1.00] R:[0.00] Height B:[9.1e+03] R:[8.9e+03]
#  [29/100][expert_system] Ret:[100.85] Len:[1342]. Health B:[1.00] R:[0.00] Height B:[1.8e+03] R:[1.6e+03]
#  [30/100][zombie] Ret:[100.37] Len:[445]. Health B:[1.00] R:[0.00] Height B:[2.8e+03] R:[2.8e+03]
#  [31/100][rosie] Ret:[21.32] Len:[3001]. Health B:[1.00] R:[0.81] Height B:[6.8e+03] R:[7.1e+03]
#  [32/100][bud] Ret:[5.97] Len:[3001]. Health B:[1.00] R:[0.94] Height B:[1.0e+04] R:[9.9e+03]
#  [33/100][bud_fsm] Ret:[100.65] Len:[1255]. Health B:[1.00] R:[0.00] Height B:[1.1e+04] R:[1.1e+04]
#  [34/100][expert_system] Ret:[-100.71] Len:[1146]. Health B:[0.00] R:[1.00] Height B:[3.1e+03] R:[2.5e+03]
#  [35/100][zombie] Ret:[-0.01] Len:[1629]. Health B:[1.00] R:[1.00] Height B:[1.7e+04] R:[2.0e+04]
#  [36/100][rosie] Ret:[101.73] Len:[2989]. Health B:[1.00] R:[0.00] Height B:[1.3e+04] R:[1.3e+04]
#  [37/100][bud] Ret:[5.97] Len:[3001]. Health B:[1.00] R:[0.95] Height B:[2.3e+03] R:[1.9e+03]
#  [38/100][bud_fsm] Ret:[100.25] Len:[216]. Health B:[1.00] R:[0.00] Height B:[1.7e+04] R:[1.7e+04]
#  [39/100][expert_system] Ret:[100.45] Len:[1091]. Health B:[1.00] R:[0.00] Height B:[4.4e+03] R:[4.5e+03]
#  [40/100][zombie] Ret:[-0.01] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.5e+04] R:[1.6e+04]
#  [41/100][rosie] Ret:[100.73] Len:[611]. Health B:[1.00] R:[0.00] Height B:[5.5e+03] R:[5.5e+03]
#  [42/100][bud] Ret:[0.28] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[8.1e+03] R:[9.0e+03]
#  [43/100][bud_fsm] Ret:[42.65] Len:[1362]. Health B:[0.42] R:[0.00] Height B:[9.9e+03] R:[1.0e+04]
#  [44/100][expert_system] Ret:[100.98] Len:[2428]. Health B:[1.00] R:[0.00] Height B:[1.3e+03] R:[1.0e+03]
#  [45/100][zombie] Ret:[100.21] Len:[280]. Health B:[1.00] R:[0.00] Height B:[2.8e+03] R:[2.7e+03]
#  [46/100][rosie] Ret:[100.59] Len:[2233]. Health B:[1.00] R:[0.00] Height B:[1.3e+04] R:[1.3e+04]
#  [47/100][bud] Ret:[1.52] Len:[3001]. Health B:[1.00] R:[0.99] Height B:[9.5e+03] R:[9.4e+03]
#  [48/100][bud_fsm] Ret:[100.77] Len:[1705]. Health B:[1.00] R:[0.00] Height B:[6.4e+03] R:[6.6e+03]
#  [49/100][expert_system] Ret:[100.29] Len:[626]. Health B:[1.00] R:[0.00] Height B:[4.5e+03] R:[5.8e+03]
#  [50/100][zombie] Ret:[0.53] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.4e+04] R:[1.5e+04]
#  [51/100][rosie] Ret:[100.82] Len:[2192]. Health B:[1.00] R:[0.00] Height B:[1.4e+04] R:[1.4e+04]
#  [52/100][bud] Ret:[0.55] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[4.3e+03] R:[4.2e+03]
#  [53/100][bud_fsm] Ret:[101.17] Len:[2812]. Health B:[1.00] R:[0.00] Height B:[8.0e+03] R:[8.0e+03]
#  [54/100][expert_system] Ret:[-100.28] Len:[1153]. Health B:[0.00] R:[1.00] Height B:[4.0e+03] R:[3.9e+03]
#  [55/100][zombie] Ret:[101.44] Len:[1275]. Health B:[1.00] R:[0.00] Height B:[1.5e+04] R:[1.5e+04]
#  [56/100][rosie] Ret:[1.04] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.9e+04] R:[2.0e+04]
#  [57/100][bud] Ret:[60.28] Len:[3001]. Health B:[1.00] R:[0.42] Height B:[6.0e+03] R:[5.9e+03]
#  [58/100][bud_fsm] Ret:[0.70] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.1e+04] R:[1.1e+04]
#  [59/100][expert_system] Ret:[-46.56] Len:[3001]. Health B:[0.17] R:[0.63] Height B:[1.4e+03] R:[2.0e+03]
#  [60/100][zombie] Ret:[101.80] Len:[1931]. Health B:[1.00] R:[0.00] Height B:[2.3e+03] R:[2.3e+03]
#  [61/100][rosie] Ret:[101.13] Len:[1499]. Health B:[1.00] R:[0.00] Height B:[8.7e+03] R:[8.7e+03]
#  [62/100][bud] Ret:[100.46] Len:[2659]. Health B:[1.00] R:[0.00] Height B:[8.1e+03] R:[8.1e+03]
#  [63/100][bud_fsm] Ret:[100.35] Len:[680]. Health B:[1.00] R:[0.00] Height B:[1.2e+04] R:[1.2e+04]
#  [64/100][expert_system] Ret:[-100.68] Len:[1001]. Health B:[0.00] R:[1.00] Height B:[8.7e+03] R:[7.4e+03]
#  [65/100][zombie] Ret:[0.22] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.1e+04] R:[1.2e+04]
#  [66/100][rosie] Ret:[84.78] Len:[3001]. Health B:[1.00] R:[0.18] Height B:[1.6e+04] R:[1.6e+04]
#  [67/100][bud] Ret:[0.16] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.2e+04] R:[1.2e+04]
#  [68/100][bud_fsm] Ret:[43.53] Len:[3001]. Health B:[1.00] R:[0.57] Height B:[1.0e+04] R:[1.0e+04]
#  [69/100][expert_system] Ret:[100.40] Len:[1784]. Health B:[1.00] R:[0.00] Height B:[2.2e+03] R:[2.5e+03]
#  [70/100][zombie] Ret:[100.39] Len:[513]. Health B:[1.00] R:[0.00] Height B:[1.1e+04] R:[1.1e+04]
#  [71/100][rosie] Ret:[100.85] Len:[1421]. Health B:[1.00] R:[0.00] Height B:[1.9e+04] R:[1.9e+04]
#  [72/100][bud] Ret:[0.22] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[8.5e+03] R:[9.7e+03]
#  [73/100][bud_fsm] Ret:[100.17] Len:[236]. Health B:[1.00] R:[0.00] Height B:[9.4e+03] R:[9.9e+03]
#  [74/100][expert_system] Ret:[70.48] Len:[2362]. Health B:[0.71] R:[0.00] Height B:[1.8e+03] R:[2.0e+03]
#  [75/100][zombie] Ret:[0.19] Len:[2312]. Health B:[1.00] R:[1.00] Height B:[9.7e+03] R:[1.2e+04]
#  [76/100][rosie] Ret:[44.50] Len:[3001]. Health B:[1.00] R:[0.57] Height B:[1.7e+04] R:[1.7e+04]
#  [77/100][bud] Ret:[0.58] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[8.6e+03] R:[8.5e+03]
#  [78/100][bud_fsm] Ret:[100.58] Len:[1247]. Health B:[1.00] R:[0.00] Height B:[8.6e+03] R:[8.9e+03]
#  [79/100][expert_system] Ret:[-100.07] Len:[83]. Health B:[0.00] R:[1.00] Height B:[3.3e+03] R:[3.9e+03]
#  [80/100][zombie] Ret:[0.36] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[1.4e+04] R:[1.5e+04]
#  [81/100][rosie] Ret:[93.97] Len:[2218]. Health B:[0.92] R:[0.00] Height B:[8.5e+03] R:[8.5e+03]
#  [82/100][bud] Ret:[0.55] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[6.8e+03] R:[6.6e+03]
#  [83/100][bud_fsm] Ret:[100.33] Len:[572]. Health B:[1.00] R:[0.00] Height B:[9.9e+03] R:[1.0e+04]
#  [84/100][expert_system] Ret:[-100.32] Len:[502]. Health B:[0.00] R:[1.00] Height B:[6.5e+03] R:[7.3e+03]
#  [85/100][zombie] Ret:[0.02] Len:[2124]. Health B:[1.00] R:[1.00] Height B:[1.3e+04] R:[1.5e+04]
#  [86/100][rosie] Ret:[101.36] Len:[2309]. Health B:[1.00] R:[0.00] Height B:[4.6e+03] R:[5.3e+03]
#  [87/100][bud] Ret:[0.32] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[9.5e+03] R:[9.3e+03]
#  [88/100][bud_fsm] Ret:[100.49] Len:[991]. Health B:[1.00] R:[0.00] Height B:[1.5e+04] R:[1.5e+04]
#  [89/100][expert_system] Ret:[-64.30] Len:[1923]. Health B:[0.00] R:[0.64] Height B:[3.4e+03] R:[2.6e+03]
#  [90/100][zombie] Ret:[101.22] Len:[2334]. Health B:[1.00] R:[0.00] Height B:[4.5e+03] R:[4.5e+03]
#  [91/100][rosie] Ret:[100.70] Len:[1420]. Health B:[1.00] R:[0.00] Height B:[1.2e+04] R:[1.2e+04]
#  [92/100][bud] Ret:[0.44] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[9.4e+03] R:[9.3e+03]
#  [93/100][bud_fsm] Ret:[0.21] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[2.2e+03] R:[2.2e+03]
#  [94/100][expert_system] Ret:[99.82] Len:[2377]. Health B:[1.00] R:[0.00] Height B:[2.2e+03] R:[2.3e+03]
#  [95/100][zombie] Ret:[0.24] Len:[2577]. Health B:[1.00] R:[1.00] Height B:[7.2e+03] R:[8.6e+03]
#  [96/100][rosie] Ret:[9.66] Len:[3001]. Health B:[1.00] R:[0.92] Height B:[1.6e+04] R:[1.6e+04]
#  [97/100][bud] Ret:[0.64] Len:[3001]. Health B:[1.00] R:[1.00] Height B:[3.9e+03] R:[3.7e+03]
#  [98/100][bud_fsm] Ret:[100.35] Len:[421]. Health B:[1.00] R:[0.00] Height B:[1.1e+04] R:[1.1e+04]
#  [99/100][expert_system] Ret:[44.37] Len:[3001]. Health B:[1.00] R:[0.55] Height B:[3.3e+03] R:[3.9e+03]
# [Eval. done] Time:[day:[01] 12:43:29] Ret_Avg:[46.418].
#
# [../report/net/ars_adt_cont/model_25.npz] saved.
