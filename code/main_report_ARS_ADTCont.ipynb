# %% [markdown]
# # ARS with ADT Continuous Env

# %%
import datetime,gym,time,os,psutil,ray
import numpy as np
import tensorflow as tf
from util import gpu_sess,suppress_tf_warning,tic,toc,open_txt,write_txt,OnlineMeanVariance
from ars import create_ars_model,get_noises_from_weights,save_ars_model,restore_ars_model
np.set_printoptions(precision=2)
suppress_tf_warning() # suppress warning 
gym.logger.set_level(40) # gym logger 

from episci.environment_wrappers.tactical_action_adt_env_continuous import CustomADTEnvContinuous
from episci.agents.utils.constants import Agents,RewardType,StateInfo
print ("Packaged loaded. TF version is [%s]."%(tf.__version__))
# Out:
# Packaged loaded. TF version is [1.15.0].

# %% [markdown]
# ### Hyperparameters

# %%
exp_name = 'ars_adt_cont'
n_cpu = 101
n_workers = 100

# %%
action_length = 5 # 50/5 = 10HZ
total_steps,evaluate_every,print_every = 5000,5,1
ep_len_rollout = 15000 // action_length
hdims,actv,out_actv = [32,32],tf.nn.relu,tf.nn.tanh
# alpha:stepsize / nu:exploration std / b: elite set size
alpha,nu,b = 0.005,0.005,np.ceil(n_workers/5).astype(np.int)
USE_NZD_OBS = False
seed = 0
# Train
red_list_train = [
    Agents.ZOMBIE,
    Agents.SPOT_RANDOM,
    Agents.EXPERT_SYSTEM
]*2
# Evaluation
red_list_eval = [
    Agents.ZOMBIE,
    Agents.ROSIE, 
    Agents.BUD, 
    Agents.BUD_FSM, 
    Agents.EXPERT_SYSTEM
]*n_workers
red_list_eval = red_list_eval[:n_workers]
num_eval = len(red_list_eval) # evaluation
# Restore
npz_path = ''

# %% [markdown]
# ### Logger

# %%
txt_path = '../report/log/%s/log_%s.txt'%(
    exp_name,
    datetime.datetime.now().strftime("%b-%d-%Y-%H:%M:%S"))
f = open_txt(txt_path)
print ("[%s] created."%(txt_path))
time.sleep(1) # wait
# Out:
# [../report/log/ars_adt_cont/log_Aug-21-2020-03:26:21.txt] created.

# %% [markdown]
# ### Environment

# %%
def get_env(red_distribution=None):
    from episci.environment_wrappers.tactical_action_adt_env_continuous \
        import CustomADTEnvContinuous
    from episci.agents.utils.constants import Agents, RewardType
    env_config = {
        "red_distribution": red_distribution,
        "reward_type": RewardType.SHAPED
    }
    return CustomADTEnvContinuous(env_config,action_length=action_length)

# %% [markdown]
# ### Worker

# %%
class RolloutWorkerClass(object):
    """
    Worker without RAY (for update purposes)
    """
    def __init__(self,
                 hdims=[64]*2,actv=tf.nn.relu,out_actv=tf.nn.tanh,
                 seed=1,USE_NZD_OBS=True):
        self.seed = seed
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim,self.adim = odim,adim
        # Observation normalization
        self.obs_mu = np.zeros(self.odim)
        self.obs_std = np.ones(self.odim)
        self.USE_NZD_OBS = USE_NZD_OBS
        # ARS model 
        self.model,self.sess = create_ars_model(
            odim=self.odim,adim=self.adim,hdims=hdims,
            actv=actv,out_actv=out_actv)
        # Initialize model 
        tf.set_random_seed(self.seed)
        np.random.seed(self.seed)
        self.sess.run(tf.global_variables_initializer())
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True
    def set_observation_stats(self,obs_mu,obs_std):
        self.obs_mu = obs_mu
        self.obs_std = obs_std
    def get_action(self,o):
        obs_std = self.obs_std
        obs_std[obs_std<1e-6] = np.inf
        if self.USE_NZD_OBS:
            nzd_o = (o-self.obs_mu)/obs_std
        else:
            nzd_o = o
        return self.sess.run(
            self.model['mu'],feed_dict={self.model['o_ph']:nzd_o.reshape(1,-1)})[0]
    def get_weights(self):
        weight_vals = self.sess.run(self.model['main_vars'])
        return weight_vals
    def set_weights(self,weight_vals):
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:weight_vals[w_idx]})
            
@ray.remote
class RayRolloutWorkerClass(object):
    """
    Rollout Worker with RAY
    """
    def __init__(self,worker_id=0,
                 hdims=[128],actv=tf.nn.relu,out_actv=tf.nn.tanh,
                 ep_len_rollout=15000,USE_NZD_OBS=True):
        self.worker_id = worker_id
        self.ep_len_rollout = ep_len_rollout
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim,self.adim = odim,adim
        self.USE_NZD_OBS = USE_NZD_OBS
        # Observation normalization
        self.obs_mu = np.zeros(self.odim)
        self.obs_std = np.ones(self.odim)
        # ARS model 
        self.model,self.sess = create_ars_model(
            odim=self.odim,adim=self.adim,hdims=hdims,
            actv=actv,out_actv=out_actv)
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True        
        print ("Ray Worker [%d] Ready."%(self.worker_id))
        
    def set_observation_stats(self,obs_mu,obs_std):
        self.obs_mu = np.copy(obs_mu) # call by value
        self.obs_std = np.copy(obs_std) # call by value
    def get_action(self,o):
        obs_std = self.obs_std
        obs_std[obs_std<1e-6] = np.inf
        if self.USE_NZD_OBS:
            nzd_o = (o-self.obs_mu)/obs_std # use whitened observation 
        else:
            nzd_o = o
        return self.sess.run(
            self.model['mu'],feed_dict={self.model['o_ph']:nzd_o.reshape(1,-1)})[0]
    def set_weights(self,weight_vals,noise_vals,noise_sign=+1):
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['main_vars']):
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:
                           weight_vals[w_idx]+noise_sign*noise_vals[w_idx]})
    def rollout(self,
                red_list=[Agents.SPOT_RANDOM,Agents.EXPERT_SYSTEM]):
        """
        Rollout
        """
        obs_buffer,obs_cnt = np.zeros((len(red_list)*self.ep_len_rollout,self.odim)),0
        r_sum,n_step = 0,0 # reward sum and total steps
        for r_idx,red in enumerate(red_list): # for each red policy
            # Specify red policy
            self.o = self.env.reset(red=red) # reset env 
            for t in range(self.ep_len_rollout):
                self.a = self.get_action(self.o) 
                self.o2,self.r,self.d,_ = self.env.step(self.a)
                # Save next state 
                self.o = self.o2
                # Accumulate reward
                r_sum += self.r
                n_step += 1
                # Stack observation
                obs_buffer[obs_cnt,:] = self.o
                obs_cnt += 1
                if self.d: 
                    break 
        # Compute the average return and steps 
        r_avg = r_sum / len(red_list)
        n_step_avg = n_step / len(red_list)
        obs_buffer = obs_buffer[:obs_cnt,:] # trim observation buffer 
        return r_avg,n_step_avg,obs_buffer
    def evaluate(self,red=None):
        o,d,ep_ret,ep_len = self.env.reset(red=red),False,0,0
        while not(d or (ep_len == self.ep_len_rollout)):
            a = self.get_action(o)
            o,r,d,_ = self.env.step(a)
            ep_ret += r # compute return 
            ep_len += 1
        blue_health,red_health = self.env.blue_health,self.env.red_health
        
        # Other infos
        blue_height = self.env.manager._blue.state[0]
        red_height = self.env.manager._red.state[0]
        
        # return / length / blue health / red health / blue height / red height
        eval_res = [ep_ret,ep_len,blue_health,red_health,blue_height,red_height]
        return eval_res

# %% [markdown]
# ### Initialize

# %%
env = get_env()
adim,odim = env.action_space.shape[0],env.observation_space.shape[0]
print ("Environment Ready. odim:[%d] adim:[%d]."%(odim,adim))
# Out:
# Environment Ready. odim:[55] adim:[4].

# %% [markdown]
# ### Observation normalizer

# %%
mv = OnlineMeanVariance()

# %% [markdown]
# ### Initialize Workers

# %%
ray.init(num_cpus=n_cpu)
tf.reset_default_graph()
R = RolloutWorkerClass(hdims=hdims,actv=actv,out_actv=out_actv,seed=seed,USE_NZD_OBS=USE_NZD_OBS)
workers = [RayRolloutWorkerClass.remote(
    worker_id=i,hdims=hdims,actv=actv,out_actv=out_actv,
    ep_len_rollout=ep_len_rollout,USE_NZD_OBS=USE_NZD_OBS)
           for i in range(n_workers)]
print ("RAY initialized with [%d] cpus and [%d] workers."%
       (n_cpu,n_workers))
# Out:
# 2020-08-21 03:26:22,319	INFO resource_spec.py:212 -- Starting Ray with 165.58 GiB memory available for workers and up to 74.96 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-08-21 03:26:22,556	WARNING services.py:923 -- Redis failed to start, retrying now.
# 2020-08-21 03:26:22,767	INFO services.py:1165 -- View the Ray dashboard at localhost:8265
# RAY initialized with [101] cpus and [100] workers.

# %% [markdown]
# ### Loop

# %%
npz_path_list,ep_ret_avg,ep_ret_avg_list = [],0.0,[]
start_time = time.time()
n_env_step = 0 # number of environment steps
for t in range(int(total_steps)): # for all steps 
    esec = time.time()-start_time
    
    # 1. Distribute the central weights to distributed workers
    weights = R.get_weights() # weights of the central worker 
    noises_list = []
    for _ in range(n_workers):
        noises_list.append(get_noises_from_weights(weights,nu=nu))
    
    # 2. Positive rollouts using distributed workers
    set_weights_list = [worker.set_weights.remote(weights,noises,noise_sign=+1) 
                        for worker,noises in zip(workers,noises_list)] # set weights
    rollout_ops = [worker.rollout.remote(red_list=red_list_train)
           for worker in workers] # do positive rollouts
    res_pos_rollout = ray.get(rollout_ops) # get positive rollout results
    pos_rets,r_idx = np.zeros(n_workers),0
    for pos_ret,ep_len,obs_buffer in res_pos_rollout:
        pos_rets[r_idx] = pos_ret # return
        r_idx = r_idx + 1
        n_env_step += ep_len # accumulate episode length
        for obs in obs_buffer: mv.include(obs) # update observation mean and std
    
    # 3. Negative rollouts using distributed workers
    set_weights_list = [worker.set_weights.remote(weights,noises,noise_sign=-1) 
                        for worker,noises in zip(workers,noises_list)] # set weights
    rollout_ops = [worker.rollout.remote(red_list=red_list_train)
           for worker in workers] # do negative rollouts
    res_neg_rollout = ray.get(rollout_ops) # get negative rollout results
    neg_rets,r_idx = np.zeros(n_workers),0
    for neg_ret,ep_len,obs_buffer in res_neg_rollout:
        neg_rets[r_idx] = neg_ret # return
        r_idx = r_idx + 1
        n_env_step += ep_len # accumulate episode length
        for obs in obs_buffer: mv.include(obs) # update observation mean and std
    
    # 4. Compute return statistics and Update
    #  'pos_rets' 'neg_rets'
    concat_rets = np.concatenate((pos_rets,neg_rets)) # concatenated returns [2*n_workers]
    ret_deltas = pos_rets - neg_rets # return difference [n_workers]
    max_rets = np.maximum(pos_rets,neg_rets) # maximum returns [n_workers]
    max_ret = np.max(max_rets) # maximum return [1]
    avg_ret = np.mean(max_rets) # average return [1]
    sort_idx = np.argsort(-max_rets) # sort for resampling
    sigma_R = np.std(concat_rets)
    weights_updated = []
    for w_idx,weight in enumerate(weights): # for each weight 
        delta_weight_sum = np.zeros_like(weight)
        for k in range(b):
            idx_k = sort_idx[k] # sorted index
            ret_delta_k,noises_k = ret_deltas[idx_k],noises_list[idx_k]
            noise_k = (1/nu)*noises_k[w_idx] # noise for current weight
            delta_weight_sum += ret_delta_k*noise_k
        delta_weight = (alpha/(b*sigma_R))*delta_weight_sum
        weight = weight + delta_weight
        weights_updated.append(weight) 
    
    # 5. Set weights of the central worker 
    R.set_weights(weights_updated)
    
    # 6. Distribute the central weights to the distributed workers
    weights = R.get_weights() # get the updated weights from the central worker
    zero_noises_list = []
    for _ in range(n_workers):
        zero_noises_list.append(get_noises_from_weights(weights,nu=0))
    set_weights_list = [worker.set_weights.remote(weights,zero_noises,noise_sign=0) 
                        for worker,zero_noises in zip(workers,zero_noises_list)] 
    
    # Print
    if (t == 0) or (((t+1)%print_every) == 0):
        print ("[%d/%d] time:[%s] max_ret:[%.2f] avg_ret:[%.2f] sigma_R:[%.2f] "%
               (t,total_steps,time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
               max_ret,avg_ret,sigma_R))
        write_txt(f,"%.2f, r_train:%.4f, ret_eval:%.4f"%(time.time()-start_time,avg_ret,ep_ret_avg),
                  ADD_NEWLINE=True,DO_PRINT=False)
    
    # Evaluate
    if (t == 0) or (((t+1)%evaluate_every) == 0): 
        ram_percent = psutil.virtual_memory().percent # memory usage
        print ("[Eval. start] step:[%d/%d][%.1f%%] #step:[%.1e] time:[%s] ram:[%.1f%%]."%
               (t+1,total_steps,t/total_steps*100,n_env_step,
                time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
                ram_percent)
              )
        ops = []
        for i_idx in range(num_eval):
            worker,red = workers[i_idx],red_list_eval[i_idx]
            ops.append(worker.evaluate.remote(red=red))
        eval_vals = ray.get(ops)
        
        ep_ret_sum = 0
        for i_idx in range(num_eval):
            red,eval_val = red_list_eval[i_idx],eval_vals[i_idx]
            ep_ret,ep_len,blue_health,red_health = eval_val[0],eval_val[1],eval_val[2],eval_val[3]
            blue_height,red_height = eval_val[4],eval_val[5]
            ep_ret_sum += ep_ret
            print (" [%d/%d][%s] Ret:[%.2f] Len:[%d]. Health B:[%.2f] R:[%.2f] Height B:[%.1e] R:[%.1e]"
                %(i_idx,len(eval_vals),red,ep_ret,ep_len,blue_health,red_health,blue_height,red_height))
        ep_ret_avg = ep_ret_sum / num_eval
        print ("[Eval. done] Time:[%s] Ret_Avg:[%.3f].\n"%
               (time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
                ep_ret_avg)
              )
        
        # Save
        npz_path = '../report/net/%s/model_%d.npz'%(exp_name,t+1)
        save_ars_model(npz_path,R,mv=mv,VERBOSE=False)
        
        # If something went bad, restore
        npz_path_list.append(npz_path)
        ep_ret_avg_list.append(ep_ret_avg)
        ep_ret_avg_array = np.asanyarray(ep_ret_avg_list)
        ep_ret_avg_max = np.max(ep_ret_avg_array)
        if (ep_ret_avg < 0.5*ep_ret_avg_max) and (len(npz_path_list) >= 2) and (ep_ret_avg_max > 0):
            npz_path = npz_path_list[np.argmax(ep_ret_avg_array)] 
            restore_ars_model(npz_path=npz_path,R=R,VERBOSE=False)
            print ("Restoring [%s] as current[%.2f] is way lower than max[%.2f]"%
                   (npz_path,ep_ret_avg,ep_ret_avg_max))
            
    
    # 7. Distribute observation mean and std to workers (after evaluation)
    obs_mean,obs_std = mv.mean,mv.std
    sef_obs_list= [worker.set_observation_stats.remote(obs_mean,obs_std) 
                   for worker in workers] # set observation mean and std
    
    # Loop 
    # break # for debugging 
    
print ("Done.")
# Out:
# (pid=33116)
# (pid=33116)
# (pid=33116)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33176)
# (pid=33176)
# (pid=33176)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33094)
# (pid=33094)
# (pid=33094)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33161)
# (pid=33161)
# (pid=33161)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33180)
# (pid=33180)
# (pid=33180)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33096)
# (pid=33096)
# (pid=33096)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33099)
# (pid=33099)
# (pid=33099)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33167)
# (pid=33167)
# (pid=33167)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33145)
# (pid=33145)
# (pid=33145)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33169)
# (pid=33169)
# (pid=33169)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33093)
# (pid=33093)
# (pid=33093)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33139)
# (pid=33139)
# (pid=33139)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33111)
# (pid=33111)
# (pid=33111)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33116) Ray Worker [5] Ready.
# (pid=33183)
# (pid=33183)
# (pid=33183)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33151)
# (pid=33151)
# (pid=33151)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33113)
# (pid=33113)
# (pid=33113)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33152)
# (pid=33152)
# (pid=33152)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33142)
# (pid=33142)
# (pid=33142)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33095)
# (pid=33095)
# (pid=33095)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33103)
# (pid=33103)
# (pid=33103)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33140)
# (pid=33140)
# (pid=33140)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33166)
# (pid=33166)
# (pid=33166)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33186)
# (pid=33186)
# (pid=33186)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33108)
# (pid=33108)
# (pid=33108)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33190)
# (pid=33190)
# (pid=33190)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33191)
# (pid=33191)
# (pid=33191)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33094) Ray Worker [55] Ready.
# (pid=33176) Ray Worker [3] Ready.
# (pid=33170)
# (pid=33170)
# (pid=33170)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33161) Ray Worker [72] Ready.
# (pid=33121)
# (pid=33121)
# (pid=33121)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33180) Ray Worker [76] Ready.
# (pid=33096) Ray Worker [6] Ready.
# (pid=33137)
# (pid=33137)
# (pid=33137)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33093) Ray Worker [14] Ready.
# (pid=33145) Ray Worker [90] Ready.
# (pid=33169) Ray Worker [0] Ready.
# (pid=33099) Ray Worker [9] Ready.
# (pid=33149)
# (pid=33149)
# (pid=33149)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33141)
# (pid=33141)
# (pid=33141)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33150)
# (pid=33150)
# (pid=33150)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33113) Ray Worker [41] Ready.
# (pid=33148)
# (pid=33148)
# (pid=33148)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33132)
# (pid=33132)
# (pid=33132)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33101)
# (pid=33101)
# (pid=33101)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33109)
# (pid=33109)
# (pid=33109)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33139) Ray Worker [7] Ready.
# (pid=33115)
# (pid=33115)
# (pid=33115)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33125)
# (pid=33125)
# (pid=33125)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33147)
# (pid=33147)
# (pid=33147)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33091)
# (pid=33091)
# (pid=33091)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33118)
# (pid=33118)
# (pid=33118)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33143)
# (pid=33143)
# (pid=33143)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33171)
# (pid=33171)
# (pid=33171)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33135)
# (pid=33135)
# (pid=33135)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33128)
# (pid=33128)
# (pid=33128)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33154)
# (pid=33154)
# (pid=33154)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33183) Ray Worker [25] Ready.
# (pid=33189)
# (pid=33189)
# (pid=33189)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33157)
# (pid=33157)
# (pid=33157)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33167) Ray Worker [94] Ready.
# (pid=33172)
# (pid=33172)
# (pid=33172)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33185)
# (pid=33185)
# (pid=33185)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33181)
# (pid=33181)
# (pid=33181)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33151) Ray Worker [84] Ready.
# (pid=33119)
# (pid=33119)
# (pid=33119)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33129)
# (pid=33129)
# (pid=33129)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33092)
# (pid=33092)
# (pid=33092)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33123)
# (pid=33123)
# (pid=33123)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33105)
# (pid=33105)
# (pid=33105)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33131)
# (pid=33131)
# (pid=33131)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33120)
# (pid=33120)
# (pid=33120)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33112)
# (pid=33112)
# (pid=33112)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33127)
# (pid=33127)
# (pid=33127)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33142) Ray Worker [30] Ready.
# (pid=33130)
# (pid=33130)
# (pid=33130)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33146)
# (pid=33146)
# (pid=33146)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33136)
# (pid=33136)
# (pid=33136)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33178)
# (pid=33178)
# (pid=33178)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33095) Ray Worker [15] Ready.
# (pid=33111) Ray Worker [12] Ready.
# (pid=33097)
# (pid=33097)
# (pid=33097)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33152) Ray Worker [21] Ready.
# (pid=33163)
# (pid=33163)
# (pid=33163)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33098)
# (pid=33098)
# (pid=33098)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33138)
# (pid=33138)
# (pid=33138)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33168)
# (pid=33168)
# (pid=33168)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33187)
# (pid=33187)
# (pid=33187)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33179)
# (pid=33179)
# (pid=33179)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33173)
# (pid=33173)
# (pid=33173)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33140) Ray Worker [43] Ready.
# (pid=33124)
# (pid=33124)
# (pid=33124)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33103) Ray Worker [31] Ready.
# (pid=33104)
# (pid=33104)
# (pid=33104)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33162)
# (pid=33162)
# (pid=33162)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33153)
# (pid=33153)
# (pid=33153)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33188)
# (pid=33188)
# (pid=33188)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33174)
# (pid=33174)
# (pid=33174)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33102)
# (pid=33102)
# (pid=33102)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33134)
# (pid=33134)
# (pid=33134)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33126)
# (pid=33126)
# (pid=33126)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33184)
# (pid=33184)
# (pid=33184)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33186) Ray Worker [1] Ready.
# (pid=33191) Ray Worker [44] Ready.
# (pid=33100)
# (pid=33100)
# (pid=33100)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33122)
# (pid=33122)
# (pid=33122)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33166) Ray Worker [4] Ready.
# (pid=33175)
# (pid=33175)
# (pid=33175)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33190) Ray Worker [16] Ready.
# (pid=33159)
# (pid=33159)
# (pid=33159)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33121) Ray Worker [66] Ready.
# (pid=33110)
# (pid=33110)
# (pid=33110)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33170) Ray Worker [10] Ready.
# (pid=33114)
# (pid=33114)
# (pid=33114)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33108) Ray Worker [19] Ready.
# (pid=33137) Ray Worker [20] Ready.
# (pid=33172) Ray Worker [86] Ready.
# (pid=33148) Ray Worker [34] Ready.
# (pid=33177)
# (pid=33177)
# (pid=33177)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33144)
# (pid=33144)
# (pid=33144)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33106)
# (pid=33106)
# (pid=33106)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33164)
# (pid=33164)
# (pid=33164)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33171) Ray Worker [65] Ready.
# (pid=33158)
# (pid=33158)
# (pid=33158)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33141) Ray Worker [2] Ready.
# (pid=33150) Ray Worker [8] Ready.
# (pid=33165)
# (pid=33165)
# (pid=33165)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33156)
# (pid=33156)
# (pid=33156)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33133)
# (pid=33133)
# (pid=33133)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33101) Ray Worker [33] Ready.
# (pid=33149) Ray Worker [11] Ready.
# (pid=33109) Ray Worker [68] Ready.
# (pid=33143) Ray Worker [64] Ready.
# (pid=33160)
# (pid=33160)
# (pid=33160)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33185) Ray Worker [81] Ready.
# (pid=33181) Ray Worker [54] Ready.
# (pid=33107)
# (pid=33107)
# (pid=33107)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33115) Ray Worker [28] Ready.
# (pid=33125) Ray Worker [47] Ready.
# (pid=33135) Ray Worker [13] Ready.
# (pid=33155)
# (pid=33155)
# (pid=33155)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33128) Ray Worker [57] Ready.
# (pid=33117)
# (pid=33117)
# (pid=33117)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=33189) Ray Worker [85] Ready.
# (pid=33157) Ray Worker [71] Ready.
# (pid=33132) Ray Worker [22] Ready.
# (pid=33119) Ray Worker [97] Ready.
# (pid=33147) Ray Worker [69] Ready.
# (pid=33091) Ray Worker [96] Ready.
# (pid=33178) Ray Worker [60] Ready.
# (pid=33118) Ray Worker [35] Ready.
# (pid=33129) Ray Worker [46] Ready.
# (pid=33138) Ray Worker [87] Ready.
# (pid=33168) Ray Worker [92] Ready.
# (pid=33187) Ray Worker [83] Ready.
# (pid=33179) Ray Worker [89] Ready.
# (pid=33092) Ray Worker [23] Ready.
# (pid=33105) Ray Worker [26] Ready.
# (pid=33131) Ray Worker [27] Ready.
# (pid=33120) Ray Worker [18] Ready.
# (pid=33112) Ray Worker [24] Ready.
# (pid=33127) Ray Worker [40] Ready.
# (pid=33130) Ray Worker [48] Ready.
# (pid=33146) Ray Worker [37] Ready.
# (pid=33097) Ray Worker [70] Ready.
# (pid=33163) Ray Worker [17] Ready.
# (pid=33098) Ray Worker [52] Ready.
# (pid=33154) Ray Worker [62] Ready.
# (pid=33124) Ray Worker [61] Ready.
# (pid=33136) Ray Worker [59] Ready.
# (pid=33173) Ray Worker [99] Ready.
# (pid=33123) Ray Worker [38] Ready.
# (pid=33188) Ray Worker [78] Ready.
# (pid=33134) Ray Worker [53] Ready.
# (pid=33184) Ray Worker [79] Ready.
# (pid=33104) Ray Worker [32] Ready.
# (pid=33162) Ray Worker [73] Ready.
# (pid=33126) Ray Worker [56] Ready.
# (pid=33102) Ray Worker [36] Ready.
# (pid=33122) Ray Worker [50] Ready.
# (pid=33175) Ray Worker [49] Ready.
# (pid=33153) Ray Worker [80] Ready.
# (pid=33174) Ray Worker [98] Ready.
# (pid=33114) Ray Worker [82] Ready.
# (pid=33100) Ray Worker [51] Ready.
# (pid=33159) Ray Worker [93] Ready.
# (pid=33110) Ray Worker [45] Ready.
# (pid=33158) Ray Worker [75] Ready.
# (pid=33165) Ray Worker [95] Ready.
# (pid=33156) Ray Worker [91] Ready.
# (pid=33107) Ray Worker [29] Ready.
# (pid=33177) Ray Worker [74] Ready.
# (pid=33144) Ray Worker [39] Ready.
# (pid=33106) Ray Worker [67] Ready.
# (pid=33164) Ray Worker [42] Ready.
# (pid=33133) Ray Worker [58] Ready.
# (pid=33155) Ray Worker [63] Ready.
# (pid=33117) Ray Worker [77] Ready.
# (pid=33160) Ray Worker [88] Ready.

# %%
pos_rets

# %%
neg_rets

# %%
max_rets

# %%
ret_deltas

# %%
delta_weight

# %%
weights_updated[0]

# %%
len(noises_list)

# %%
noises_list[0]
