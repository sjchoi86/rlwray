# %% [markdown]
# # PPO with ADT Continuous Env

# %%
import datetime,gym,time,os,psutil,ray
import numpy as np
import tensorflow as tf
from util import open_txt,write_txt
from ppo import PPOBuffer,create_ppo_model,create_ppo_graph,update_ppo,\
    save_ppo_model,restore_ppo_model
from episci.environment_wrappers.tactical_action_adt_env_continuous \
    import CustomADTEnvContinuous
from episci.agents.utils.constants import Agents,RewardType,StateInfo
print ("Packaged loaded. TF version is [%s]."%(tf.__version__))
# Out:
# Packaged loaded. TF version is [1.15.0].

# %% [markdown]
# ### Hyperparameters

# %%
# Worker
exp_name = 'ppo_adt_cont'
n_cpu = 21
n_workers = 20

# Environment
action_length = 5 # 50/5 = 10HZ
red_list_train = [
    Agents.ZOMBIE,
    Agents.SPOT_RANDOM,
    Agents.EXPERT_SYSTEM
]
# Red agent distribution for evaluation
red_list_eval = [
    Agents.ZOMBIE,
    Agents.ROSIE, 
    Agents.BUD, 
    Agents.BUD_FSM, 
    Agents.EXPERT_SYSTEM
]*n_workers
red_list_eval = red_list_eval[:n_workers]
num_eval = len(red_list_eval) # evaluation

# Steps
total_steps,evaluate_every,print_every = 5000,5,1
ep_len_rollout = 3000 # 15,000/5
buffer_size = int(3000*len(red_list_train))
batch_size = int(2**15) 

# Network configuration
hdims = [64,32,16]
clip_ratio = 0.2
pi_lr = 1e-5 # 3e-4
vf_lr = 1e-4 # 1e-3
epsilon = 1e-5 # 1e-2
# Buffer
gamma = 0.99 # 0.99
lam = 0.95 # 0.95
# Update
train_pi_iters = 1000
train_v_iters = 1000
target_kl = 0.005 # 0.01

# %% [markdown]
# ### Environment

# %%
def get_env(red_distribution=None):
    from episci.environment_wrappers.tactical_action_adt_env_continuous \
        import CustomADTEnvContinuous
    from episci.agents.utils.constants import Agents, RewardType
    env_config = {
        "red_distribution": red_distribution,
        "reward_type": RewardType.SHAPED
    }
    return CustomADTEnvContinuous(env_config,action_length=action_length)

# %% [markdown]
# ### Logger

# %%
txt_path = '../report/log/%s/log_%s.txt'%(
    exp_name,
    datetime.datetime.now().strftime("%b-%d-%Y-%H:%M:%S"))
f = open_txt(txt_path)
print ("[%s] created."%(txt_path))
time.sleep(1)
# Out:
# [../report/log/ppo_adt_cont/log_Aug-19-2020-08:15:07.txt] created.

# %% [markdown]
# ### Rollout Workers

# %%
class RolloutWorkerClass(object):
    """
    Worker without RAY (for update purposes)
    """
    def __init__(self,seed=1):
        self.seed = seed
        # Each worker should maintain its own environment
        import gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) # gym logger 
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        _ = self.env.reset(red=Agents.SPOT_RANDOM)
        
        # Initialize PPO
        self.model,self.sess = create_ppo_model(env=self.env,hdims=hdims,output_actv=tf.nn.tanh)
        self.graph = create_ppo_graph(self.model,
                                      clip_ratio=clip_ratio,pi_lr=pi_lr,vf_lr=vf_lr,epsilon=epsilon)
        # Initialize model 
        tf.set_random_seed(self.seed)
        np.random.seed(self.seed)
        self.sess.run(tf.global_variables_initializer())
        
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True
        
    def get_action(self,o,deterministic=False):
        act_op = self.model['mu'] if deterministic else self.model['pi']
        return self.sess.run(act_op, feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
    
    def get_weights(self):
        """
        Get weights
        """
        weight_vals = self.sess.run(self.model['pi_vars']+self.model['v_vars'])
        return weight_vals
    
    def set_weights(self,weight_vals):
        """
        Set weights without memory leakage
        """
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['pi_vars']+self.model['v_vars']):
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['pi_vars']+self.model['v_vars']):
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:weight_vals[w_idx]})    
    
@ray.remote
class RayRolloutWorkerClass(object):
    """
    Rollout Worker with RAY
    """
    def __init__(self,worker_id=0,ep_len_rollout=1000,buffer_size=1000):
        # Parse
        self.worker_id = worker_id
        self.ep_len_rollout = ep_len_rollout
        self.buffer_size = buffer_size
        # Each worker should maintain its own environment
        import gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) # gym logger 
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        _ = self.env.reset(red=Agents.SPOT_RANDOM)
        
        # Replay buffers to pass
        self.o_buffer = np.zeros((self.buffer_size,self.odim))
        self.a_buffer = np.zeros((self.buffer_size,self.adim))
        self.r_buffer = np.zeros((self.buffer_size))
        self.v_t_buffer = np.zeros((self.buffer_size))
        self.logp_t_buffer = np.zeros((self.buffer_size))
        # Create PPO model
        self.model,self.sess = create_ppo_model(env=self.env,hdims=hdims,output_actv=tf.nn.tanh)
        # Initialize model 
        self.sess.run(tf.global_variables_initializer())
        # Buffer
        self.buf = PPOBuffer(odim=self.odim,adim=self.adim,
                             size=buffer_size,gamma=gamma,lam=lam)
        print ("Ray Worker [%d] Ready."%(self.worker_id))
        
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True
        
        # Flag to initialize rollout
        self.FIRST_ROLLOUT_FLAG = True
        
    def get_action(self,o,deterministic=False):
        act_op = self.model['mu'] if deterministic else self.model['pi']
        return self.sess.run(act_op, feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
    
    def set_weights(self,weight_vals):
        """
        Set weights without memory leakage
        """
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['pi_vars']+self.model['v_vars']):
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['pi_vars']+self.model['v_vars']):
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:weight_vals[w_idx]})    
        
    def rollout(self,red_list=[Agents.SPOT_RANDOM,Agents.EXPERT_SYSTEM]):
        """
        Rollout
        """
        if self.FIRST_ROLLOUT_FLAG:
            self.FIRST_ROLLOUT_FLAG = False
            self.o = self.env.reset(red=Agents.SPOT_RANDOM) # reset environment
        # Loop
        r_sum,cnt = 0,0
        for r_idx,red in enumerate(red_list): # for each red policy
            self.o = self.env.reset(red=red) # reset environment
            for t in range(self.ep_len_rollout):
                a,v_t,logp_t = self.sess.run(
                    self.model['get_action_ops'],
                    feed_dict={self.model['o_ph']:self.o.reshape(1,-1)})
                o2, r, d, _ = self.env.step(a[0])
                r_sum += r
                cnt += 1
                # save and log
                self.buf.store(self.o,a,r,v_t,logp_t)
                # Update obs (critical!)
                self.o = o2
                if d:
                    self.buf.finish_path(last_val=0.0)
                    self.o = self.env.reset(red=Agents.SPOT_RANDOM) # reset when done 
            last_val = self.sess.run(self.model['v'],
                                     feed_dict={self.model['o_ph']:self.o.reshape(1,-1)})
            self.buf.finish_path(last_val) # finish path buffer
        r_avg = r_sum / cnt
        return self.buf.get(),r_avg # obs_buf, act_buf, adv_buf, ret_buf, logp_buf
    
    def evaluate(self,red=None):
        """
        Evaluate
        """
        o,d,ep_ret,ep_len = self.env.reset(red=red),False,0,0
        while not(d or (ep_len == self.ep_len_rollout)):
            a = self.get_action(o,deterministic=True)
            o,r,d,_ = self.env.step(a)
            ep_ret += r # compute return 
            ep_len += 1
        blue_health,red_health = self.env.blue_health,self.env.red_health
        eval_res = [ep_ret,ep_len,blue_health,red_health] # evaluation result 
        return eval_res

# %% [markdown]
# ### Initialize Workers

# %%
ray.init(num_cpus=n_cpu)
tf.reset_default_graph()
R = RolloutWorkerClass(seed=0)
workers = [RayRolloutWorkerClass.remote(
    worker_id=i,ep_len_rollout=ep_len_rollout,buffer_size=buffer_size) 
           for i in range(n_workers)]
print ("RAY initialized with [%d] cpus and [%d] workers."%
       (n_cpu,n_workers))
# Out:
# 2020-08-19 08:15:08,230	INFO resource_spec.py:212 -- Starting Ray with 134.23 GiB memory available for workers and up to 61.53 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-08-19 08:15:08,473	WARNING services.py:923 -- Redis failed to start, retrying now.
# 2020-08-19 08:15:08,732	INFO services.py:1165 -- View the Ray dashboard at localhost:8265
# RAY initialized with [21] cpus and [20] workers.

# %% [markdown]
# ### Loop

# %%
start_time = time.time()
n_env_step = 0 # number of environment steps
ep_ret_avg = 0
for t in range(int(total_steps)):
    esec = time.time()-start_time
    
    # 1. Synchronize worker weights
    weights = R.get_weights()
    set_weights_list = [worker.set_weights.remote(weights) for worker in workers] 
    
    # 2. Make rollout and accumulate to Buffers
    t_start = time.time()
    ops = [worker.rollout.remote(
        red_list=red_list_train # <= with the list of pre-defined red agent policies
    ) for worker in workers]
    rollout_vals = ray.get(ops)
    sec_rollout = time.time() - t_start
    
    # Get stats before update
    t_start = time.time() # tic

    # 3. Update the PPO model 
    r_sum = 0
    for r_idx,rval in enumerate(rollout_vals): # concat all buffers from workers
        obs_buf,act_buf,adv_buf,ret_buf,logp_buf,r_rollout_avg = \
            rval[0][0],rval[0][1],rval[0][2],rval[0][3],rval[0][4],rval[1]
        if r_idx == 0:
            obs_bufs,act_bufs,adv_bufs,ret_bufs,logp_bufs = \
                obs_buf,act_buf,adv_buf,ret_buf,logp_buf
        else:
            obs_bufs = np.concatenate((obs_bufs,obs_buf),axis=0)
            act_bufs = np.concatenate((act_bufs,act_buf),axis=0)
            adv_bufs = np.concatenate((adv_bufs,adv_buf),axis=0)
            ret_bufs = np.concatenate((ret_bufs,ret_buf),axis=0)
            logp_bufs = np.concatenate((logp_bufs,logp_buf),axis=0)
        r_sum += r_rollout_avg
    r_avg = r_sum / len(rollout_vals)
    n_val_total = obs_bufs.shape[0] # total buffer size 
    for pi_iter in range(train_pi_iters): # update actor
        rand_idx = np.random.permutation(n_val_total)[:batch_size]
        buf_batches = [obs_bufs[rand_idx],act_bufs[rand_idx],adv_bufs[rand_idx],
                       ret_bufs[rand_idx],logp_bufs[rand_idx]]
        feeds = {k:v for k,v in zip(R.model['all_phs'],buf_batches)}
        _,kl,pi_loss,ent = R.sess.run([R.graph['train_pi'],R.graph['approx_kl'],
                               R.graph['pi_loss'],R.graph['approx_ent']],
                           feed_dict=feeds)        
        if kl > 1.5 * target_kl:
            # print ("  pi_iter:[%d] kl(%.3f) is higher than 1.5x(%.3f)"%(pi_iter,kl,target_kl))
            break
    for _ in range(train_v_iters): # update critic
        rand_idx = np.random.permutation(n_val_total)[:batch_size]
        buf_batches = [obs_bufs[rand_idx],act_bufs[rand_idx],adv_bufs[rand_idx],
                       ret_bufs[rand_idx],logp_bufs[rand_idx]]
        feeds = {k:v for k,v in zip(R.model['all_phs'],buf_batches)}
        R.sess.run(R.graph['train_v'],feed_dict=feeds)
    sec_update = time.time() - t_start # toc
    
    # 4. Synchronize worker weights (after update)
    weights = R.get_weights()
    set_weights_list = [worker.set_weights.remote(weights) for worker in workers] 
    
    # Print
    if (t == 0) or (((t+1)%print_every) == 0): 
        print ("[%d/%d] rollout:[%.1f]s pi_iter:[%d/%d] update:[%.1f]s kl:[%.4f] target_kl:[%.4f]."%
               (t+1,total_steps,sec_rollout,pi_iter,train_pi_iters,sec_update,kl,target_kl))
        print ("   pi_loss:[%.4f], entropy:[%.4f], r_avg[%.4f]"%
               (pi_loss,ent,r_avg))
        write_txt(f,"%.2f, r_train:%.4f, ret_eval:%.4f"%(time.time()-start_time, r_avg, ep_ret_avg),
                  ADD_NEWLINE=True,DO_PRINT=False)
        
    # 5. Evaluate
    if (t == 0) or (((t+1)%evaluate_every) == 0): 
        ram_percent = psutil.virtual_memory().percent # memory usage
        print ("[Eval. start] step:[%d/%d][%.1f%%] #step:[%.1e] time:[%s] ram:[%.1f%%]."%
               (t+1,total_steps,t/total_steps*100,
                n_env_step,
                time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
                ram_percent)
              )
        ops = []
        for i_idx in range(num_eval):
            worker,red = workers[i_idx],red_list_eval[i_idx]
            ops.append(worker.evaluate.remote(red=red))
        eval_vals = ray.get(ops)
        ep_ret_sum = 0
        for i_idx in range(num_eval):
            red,eval_val = red_list_eval[i_idx],eval_vals[i_idx]
            ep_ret,ep_len,blue_health,red_health = eval_val[0],eval_val[1],eval_val[2],eval_val[3]
            ep_ret_sum += ep_ret
            print (" [%d/%d] [%s] ep_ret:[%.4f] ep_len:[%d]. blue health:[%.2f] red health:[%.2f]"
                %(i_idx,len(eval_vals),red,ep_ret,ep_len,blue_health,red_health))
        ep_ret_avg = ep_ret_sum / num_eval
        print ("[Eval. done] time:[%s] ep_ret_avg:[%.3f]."%
               (time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),ep_ret_avg))
        # Save current PPO model
        npz_path = '../report/net/%s/model_%d.npz'%(exp_name,t+1)
        save_ppo_model(npz_path,R,VERBOSE=False)
        

print ("Done.")
# Out:
# (pid=81186)
# (pid=81186)
# (pid=81186)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81193)
# (pid=81193)
# (pid=81193)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81180)
# (pid=81180)
# (pid=81180)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81178)
# (pid=81178)
# (pid=81178)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81183)
# (pid=81183)
# (pid=81183)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81182)
# (pid=81182)
# (pid=81182)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81198)
# (pid=81198)
# (pid=81198)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81184)
# (pid=81184)
# (pid=81184)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81176)
# (pid=81176)
# (pid=81176)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81187)
# (pid=81187)
# (pid=81187)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81190)
# (pid=81190)
# (pid=81190)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81188)
# (pid=81188)
# (pid=81188)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81199)
# (pid=81199)
# (pid=81199)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81181)
# (pid=81181)
# (pid=81181)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81179)
# (pid=81179)
# (pid=81179)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81177)
# (pid=81177)
# (pid=81177)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81197)
# (pid=81197)
# (pid=81197)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81175)
# (pid=81175)
# (pid=81175)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81185)
# (pid=81185)
# (pid=81185)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81189)
# (pid=81189)
# (pid=81189)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=81186) Ray Worker [9] Ready.
# (pid=81193) Ray Worker [11] Ready.
# (pid=81180) Ray Worker [19] Ready.
# (pid=81182) Ray Worker [7] Ready.
# (pid=81198) Ray Worker [6] Ready.
# (pid=81183) Ray Worker [3] Ready.
# (pid=81184) Ray Worker [5] Ready.
# (pid=81178) Ray Worker [14] Ready.
# (pid=81188) Ray Worker [16] Ready.
# (pid=81176) Ray Worker [0] Ready.
# (pid=81187) Ray Worker [15] Ready.
# (pid=81179) Ray Worker [4] Ready.
# (pid=81190) Ray Worker [18] Ready.
# (pid=81199) Ray Worker [10] Ready.
# (pid=81181) Ray Worker [13] Ready.
# (pid=81177) Ray Worker [1] Ready.
# (pid=81197) Ray Worker [2] Ready.
# (pid=81175) Ray Worker [8] Ready.
# (pid=81185) Ray Worker [12] Ready.
# (pid=81189) Ray Worker [17] Ready.
# [1/5000] rollout:[468.0]s pi_iter:[999/1000] update:[77.7]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[-0.0011], entropy:[3.6809], r_avg[-0.0107]
# [Eval. start] step:[1/5000][0.0%] #step:[0.0e+00] time:[day:[01] 00:09:05] ram:[22.9%].
#  [0/20] [zombie] ep_ret:[-0.5287] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[5.2987] ep_len:[3000]. blue health:[1.00] red health:[0.95]
#  [2/20] [bud] ep_ret:[-0.5376] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [3/20] [bud_fsm] ep_ret:[-2.4210] ep_len:[1290]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-100.9814] ep_len:[1863]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[73.8990] ep_len:[3000]. blue health:[1.00] red health:[0.30]
#  [6/20] [rosie] ep_ret:[0.7765] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[-0.5591] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [8/20] [bud_fsm] ep_ret:[0.5919] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-100.6056] ep_len:[505]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-0.4605] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[0.5446] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[-0.2792] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [13/20] [bud_fsm] ep_ret:[8.8550] ep_len:[3000]. blue health:[1.00] red health:[0.92]
#  [14/20] [expert_system] ep_ret:[-100.8153] ep_len:[1361]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.5441] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[1.0740] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[-0.3738] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[-0.5916] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-100.9978] ep_len:[1074]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 00:11:16] ep_ret_avg:[-15.933].
# [../report/net/ppo_adt_cont/model_1.npz] saved.
# [2/5000] rollout:[480.5]s pi_iter:[999/1000] update:[49.3]s kl:[0.0034] target_kl:[0.0050].
#    pi_loss:[-0.0055], entropy:[3.6780], r_avg[-0.0110]
# [3/5000] rollout:[476.1]s pi_iter:[999/1000] update:[77.9]s kl:[0.0046] target_kl:[0.0050].
#    pi_loss:[0.0014], entropy:[3.6738], r_avg[-0.0103]
# [4/5000] rollout:[428.8]s pi_iter:[999/1000] update:[73.3]s kl:[0.0029] target_kl:[0.0050].
#    pi_loss:[0.0085], entropy:[3.6630], r_avg[-0.0097]
# [5/5000] rollout:[435.8]s pi_iter:[999/1000] update:[51.4]s kl:[0.0037] target_kl:[0.0050].
#    pi_loss:[-0.0025], entropy:[3.6362], r_avg[-0.0103]
# [Eval. start] step:[5/5000][0.1%] #step:[0.0e+00] time:[day:[01] 00:45:49] ram:[18.2%].
#  [0/20] [zombie] ep_ret:[-0.1606] ep_len:[1786]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.1082] ep_len:[1999]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[-0.1919] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [3/20] [bud_fsm] ep_ret:[54.8981] ep_len:[3000]. blue health:[1.00] red health:[0.46]
#  [4/20] [expert_system] ep_ret:[-90.0191] ep_len:[1278]. blue health:[0.00] red health:[0.89]
#  [5/20] [zombie] ep_ret:[-0.3168] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[42.7914] ep_len:[3000]. blue health:[1.00] red health:[0.59]
#  [7/20] [bud] ep_ret:[-0.1273] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [8/20] [bud_fsm] ep_ret:[-14.5221] ep_len:[3000]. blue health:[0.84] red health:[0.99]
#  [9/20] [expert_system] ep_ret:[-100.7395] ep_len:[1723]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[11.6542] ep_len:[3000]. blue health:[1.00] red health:[0.90]
#  [11/20] [rosie] ep_ret:[28.3292] ep_len:[3000]. blue health:[1.00] red health:[0.74]
#  [12/20] [bud] ep_ret:[-0.0780] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [13/20] [bud_fsm] ep_ret:[25.3197] ep_len:[3000]. blue health:[1.00] red health:[0.75]
#  [14/20] [expert_system] ep_ret:[-100.5311] ep_len:[767]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.1491] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[27.1854] ep_len:[3000]. blue health:[1.00] red health:[0.75]
#  [17/20] [bud] ep_ret:[-0.1998] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[0.9208] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-101.3970] ep_len:[1114]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 00:47:51] ep_ret_avg:[-5.861].
# [../report/net/ppo_adt_cont/model_5.npz] saved.
# [6/5000] rollout:[436.7]s pi_iter:[999/1000] update:[69.1]s kl:[0.0042] target_kl:[0.0050].
#    pi_loss:[0.0019], entropy:[3.6359], r_avg[-0.0102]
# [7/5000] rollout:[413.6]s pi_iter:[999/1000] update:[65.4]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[-0.0004], entropy:[3.6338], r_avg[-0.0109]
# [8/5000] rollout:[407.2]s pi_iter:[999/1000] update:[57.5]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[-0.0027], entropy:[3.6134], r_avg[-0.0092]
# [9/5000] rollout:[444.8]s pi_iter:[999/1000] update:[56.4]s kl:[0.0029] target_kl:[0.0050].
#    pi_loss:[-0.0100], entropy:[3.6010], r_avg[-0.0113]
# [10/5000] rollout:[422.9]s pi_iter:[999/1000] update:[51.6]s kl:[0.0039] target_kl:[0.0050].
#    pi_loss:[-0.0018], entropy:[3.6074], r_avg[-0.0098]
# [Eval. start] step:[10/5000][0.2%] #step:[0.0e+00] time:[day:[01] 01:28:17] ram:[19.8%].
#  [0/20] [zombie] ep_ret:[0.0213] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[94.9187] ep_len:[3000]. blue health:[1.00] red health:[0.06]
#  [2/20] [bud] ep_ret:[100.1287] ep_len:[1227]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[12.5498] ep_len:[3000]. blue health:[1.00] red health:[0.89]
#  [4/20] [expert_system] ep_ret:[-100.3462] ep_len:[382]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.1519] ep_len:[1754]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[3.0615] ep_len:[3000]. blue health:[1.00] red health:[0.99]
#  [7/20] [bud] ep_ret:[100.2553] ep_len:[1778]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.9387] ep_len:[2521]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-101.7718] ep_len:[1516]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[0.7892] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[48.4839] ep_len:[3000]. blue health:[1.00] red health:[0.52]
#  [12/20] [bud] ep_ret:[0.1084] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [13/20] [bud_fsm] ep_ret:[100.8759] ep_len:[2572]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-100.3826] ep_len:[347]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.0466] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.8242] ep_len:[2664]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[0.0893] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[0.1760] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-80.2210] ep_len:[2858]. blue health:[0.00] red health:[0.79]
# [Eval. done] time:[day:[01] 01:31:07] ep_ret_avg:[14.015].
# [../report/net/ppo_adt_cont/model_10.npz] saved.
# [11/5000] rollout:[434.5]s pi_iter:[999/1000] update:[58.6]s kl:[0.0054] target_kl:[0.0050].
#    pi_loss:[-0.0029], entropy:[3.6068], r_avg[-0.0107]
# [12/5000] rollout:[433.7]s pi_iter:[999/1000] update:[53.4]s kl:[0.0034] target_kl:[0.0050].
#    pi_loss:[0.0015], entropy:[3.6042], r_avg[-0.0101]
# [13/5000] rollout:[397.3]s pi_iter:[999/1000] update:[58.9]s kl:[0.0034] target_kl:[0.0050].
#    pi_loss:[0.0019], entropy:[3.5994], r_avg[-0.0104]
# [14/5000] rollout:[431.1]s pi_iter:[999/1000] update:[59.7]s kl:[0.0035] target_kl:[0.0050].
#    pi_loss:[-0.0005], entropy:[3.5873], r_avg[-0.0089]
# [15/5000] rollout:[431.2]s pi_iter:[999/1000] update:[57.6]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0082], entropy:[3.5790], r_avg[-0.0093]
# [Eval. start] step:[15/5000][0.3%] #step:[0.0e+00] time:[day:[01] 02:11:23] ram:[20.4%].
#  [0/20] [zombie] ep_ret:[-2.5484] ep_len:[1502]. blue health:[0.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.1876] ep_len:[2218]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0929] ep_len:[883]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.2964] ep_len:[1595]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-100.8050] ep_len:[1168]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.1066] ep_len:[2858]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[78.3561] ep_len:[3000]. blue health:[1.00] red health:[0.23]
#  [7/20] [bud] ep_ret:[100.1168] ep_len:[1587]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[4.3639] ep_len:[3000]. blue health:[1.00] red health:[0.97]
#  [9/20] [expert_system] ep_ret:[-100.3303] ep_len:[503]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-2.6269] ep_len:[1681]. blue health:[0.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.3949] ep_len:[1996]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.0883] ep_len:[2043]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[32.4361] ep_len:[3000]. blue health:[1.00] red health:[0.69]
#  [14/20] [expert_system] ep_ret:[-100.9325] ep_len:[1473]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.0844] ep_len:[2024]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[101.1785] ep_len:[2080]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0914] ep_len:[1027]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[60.3678] ep_len:[3000]. blue health:[1.00] red health:[0.41]
#  [19/20] [expert_system] ep_ret:[-100.6092] ep_len:[988]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 02:13:31] ep_ret_avg:[23.367].
# [../report/net/ppo_adt_cont/model_15.npz] saved.
# [16/5000] rollout:[445.1]s pi_iter:[999/1000] update:[60.3]s kl:[0.0032] target_kl:[0.0050].
#    pi_loss:[0.0002], entropy:[3.5701], r_avg[-0.0092]
# [17/5000] rollout:[442.9]s pi_iter:[999/1000] update:[52.7]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0023], entropy:[3.5711], r_avg[-0.0105]
# [18/5000] rollout:[435.3]s pi_iter:[999/1000] update:[53.4]s kl:[0.0028] target_kl:[0.0050].
#    pi_loss:[0.0070], entropy:[3.5408], r_avg[-0.0099]
# [19/5000] rollout:[447.7]s pi_iter:[999/1000] update:[58.8]s kl:[0.0042] target_kl:[0.0050].
#    pi_loss:[0.0007], entropy:[3.5258], r_avg[-0.0095]
# [20/5000] rollout:[430.2]s pi_iter:[999/1000] update:[56.9]s kl:[0.0029] target_kl:[0.0050].
#    pi_loss:[-0.0170], entropy:[3.5331], r_avg[-0.0089]
# [Eval. start] step:[20/5000][0.4%] #step:[0.0e+00] time:[day:[01] 02:54:54] ram:[20.7%].
#  [0/20] [zombie] ep_ret:[-0.4637] ep_len:[2137]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[1.5894] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[100.0126] ep_len:[1263]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.0546] ep_len:[1220]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-100.4441] ep_len:[416]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[2.1207] ep_len:[3000]. blue health:[1.00] red health:[0.98]
#  [6/20] [rosie] ep_ret:[0.7841] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.7589] ep_len:[1115]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-2.5698] ep_len:[2228]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-49.9769] ep_len:[3000]. blue health:[0.51] red health:[1.00]
#  [10/20] [zombie] ep_ret:[0.2968] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-0.2836] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.7766] ep_len:[966]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[4.5027] ep_len:[3000]. blue health:[0.97] red health:[0.94]
#  [14/20] [expert_system] ep_ret:[-101.4504] ep_len:[2028]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-2.4158] ep_len:[343]. blue health:[0.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[0.7274] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.8634] ep_len:[597]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[1.0933] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-101.1967] ep_len:[1887]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 02:57:44] ep_ret_avg:[2.484].
# [../report/net/ppo_adt_cont/model_20.npz] saved.
# [21/5000] rollout:[428.7]s pi_iter:[999/1000] update:[57.5]s kl:[0.0028] target_kl:[0.0050].
#    pi_loss:[-0.0074], entropy:[3.5098], r_avg[-0.0063]
# [22/5000] rollout:[435.4]s pi_iter:[999/1000] update:[53.2]s kl:[0.0032] target_kl:[0.0050].
#    pi_loss:[0.0032], entropy:[3.5130], r_avg[-0.0076]
# [23/5000] rollout:[437.7]s pi_iter:[999/1000] update:[58.5]s kl:[0.0034] target_kl:[0.0050].
#    pi_loss:[-0.0003], entropy:[3.5002], r_avg[-0.0066]
# [24/5000] rollout:[440.1]s pi_iter:[999/1000] update:[59.6]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0045], entropy:[3.4755], r_avg[-0.0088]
# [25/5000] rollout:[446.4]s pi_iter:[999/1000] update:[53.6]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0032], entropy:[3.4742], r_avg[-0.0085]
# [Eval. start] step:[25/5000][0.5%] #step:[0.0e+00] time:[day:[01] 03:38:55] ram:[20.9%].
#  [0/20] [zombie] ep_ret:[-0.5462] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-0.3308] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[100.1368] ep_len:[738]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-1.6515] ep_len:[2655]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-101.6514] ep_len:[2523]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[1.3198] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[0.5244] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.9645] ep_len:[567]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[31.7725] ep_len:[2336]. blue health:[0.00] red health:[0.66]
#  [9/20] [expert_system] ep_ret:[-74.2363] ep_len:[3000]. blue health:[0.27] red health:[1.00]
#  [10/20] [zombie] ep_ret:[0.4146] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[0.0016] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[100.2083] ep_len:[904]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-0.1484] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-101.5457] ep_len:[2465]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-2.9518] ep_len:[2175]. blue health:[0.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[0.2144] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.9178] ep_len:[1206]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[14.2131] ep_len:[3000]. blue health:[1.00] red health:[0.86]
#  [19/20] [expert_system] ep_ret:[-0.3767] ep_len:[3000]. blue health:[1.00] red health:[1.00]
# [Eval. done] time:[day:[01] 03:41:52] ep_ret_avg:[8.262].
# [../report/net/ppo_adt_cont/model_25.npz] saved.
# [26/5000] rollout:[454.8]s pi_iter:[999/1000] update:[50.9]s kl:[0.0043] target_kl:[0.0050].
#    pi_loss:[0.0015], entropy:[3.4618], r_avg[-0.0085]
# [27/5000] rollout:[432.9]s pi_iter:[999/1000] update:[54.6]s kl:[0.0030] target_kl:[0.0050].
#    pi_loss:[-0.0074], entropy:[3.4335], r_avg[-0.0103]
# [28/5000] rollout:[449.4]s pi_iter:[999/1000] update:[61.3]s kl:[0.0027] target_kl:[0.0050].
#    pi_loss:[0.0019], entropy:[3.4273], r_avg[-0.0100]
# [29/5000] rollout:[443.8]s pi_iter:[999/1000] update:[51.9]s kl:[0.0028] target_kl:[0.0050].
#    pi_loss:[0.0009], entropy:[3.4214], r_avg[-0.0081]
# [30/5000] rollout:[452.1]s pi_iter:[999/1000] update:[51.5]s kl:[0.0041] target_kl:[0.0050].
#    pi_loss:[-0.0032], entropy:[3.4174], r_avg[-0.0076]
# [Eval. start] step:[30/5000][0.6%] #step:[0.0e+00] time:[day:[01] 04:23:35] ram:[21.1%].
#  [0/20] [zombie] ep_ret:[-0.9748] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-0.0433] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.9447] ep_len:[890]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.4891] ep_len:[1557]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-102.1812] ep_len:[2549]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.2591] ep_len:[1046]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-0.9950] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.7473] ep_len:[999]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-0.2720] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-59.6651] ep_len:[3000]. blue health:[0.44] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-0.1511] ep_len:[1594]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-0.5178] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.7440] ep_len:[1109]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[48.6855] ep_len:[3000]. blue health:[0.63] red health:[0.14]
#  [14/20] [expert_system] ep_ret:[-101.7115] ep_len:[2156]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.7948] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-0.9540] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.6724] ep_len:[1076]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-0.1907] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-100.4166] ep_len:[544]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 04:26:25] ep_ret_avg:[3.809].
# [../report/net/ppo_adt_cont/model_30.npz] saved.
# [31/5000] rollout:[445.3]s pi_iter:[999/1000] update:[56.2]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[-0.0002], entropy:[3.4063], r_avg[-0.0079]
# [32/5000] rollout:[445.4]s pi_iter:[999/1000] update:[58.4]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[0.0034], entropy:[3.4078], r_avg[-0.0059]
# [33/5000] rollout:[444.5]s pi_iter:[999/1000] update:[57.9]s kl:[0.0032] target_kl:[0.0050].
#    pi_loss:[-0.0021], entropy:[3.4036], r_avg[-0.0111]
# [34/5000] rollout:[440.3]s pi_iter:[999/1000] update:[63.3]s kl:[0.0034] target_kl:[0.0050].
#    pi_loss:[-0.0061], entropy:[3.4172], r_avg[-0.0082]
# [35/5000] rollout:[442.6]s pi_iter:[999/1000] update:[58.3]s kl:[0.0030] target_kl:[0.0050].
#    pi_loss:[-0.0060], entropy:[3.3983], r_avg[-0.0076]
# [Eval. start] step:[35/5000][0.7%] #step:[0.0e+00] time:[day:[01] 05:08:17] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[-0.7541] ep_len:[2670]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-0.5964] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.9711] ep_len:[676]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-0.4609] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-101.4634] ep_len:[2242]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.1550] ep_len:[1225]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-0.1155] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[-2.4900] ep_len:[607]. blue health:[0.00] red health:[1.00]
#  [8/20] [bud_fsm] ep_ret:[100.0770] ep_len:[918]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-30.0193] ep_len:[3000]. blue health:[0.70] red health:[0.97]
#  [10/20] [zombie] ep_ret:[-0.4071] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-0.5471] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[100.0359] ep_len:[783]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.4443] ep_len:[1150]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-3.0174] ep_len:[867]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.2582] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-0.1648] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.9222] ep_len:[871]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.4427] ep_len:[1471]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-2.3603] ep_len:[3000]. blue health:[1.00] red health:[1.00]
# [Eval. done] time:[day:[01] 05:11:00] ep_ret_avg:[22.904].
# [../report/net/ppo_adt_cont/model_35.npz] saved.
# [36/5000] rollout:[438.4]s pi_iter:[999/1000] update:[56.3]s kl:[0.0043] target_kl:[0.0050].
#    pi_loss:[-0.0037], entropy:[3.3798], r_avg[-0.0084]
# [37/5000] rollout:[410.1]s pi_iter:[999/1000] update:[54.6]s kl:[0.0032] target_kl:[0.0050].
#    pi_loss:[0.0010], entropy:[3.3760], r_avg[-0.0072]
# [38/5000] rollout:[433.7]s pi_iter:[999/1000] update:[59.7]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[-0.0013], entropy:[3.3587], r_avg[-0.0056]
# [39/5000] rollout:[427.9]s pi_iter:[999/1000] update:[54.7]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0022], entropy:[3.3400], r_avg[-0.0090]
# [40/5000] rollout:[429.2]s pi_iter:[999/1000] update:[53.7]s kl:[0.0032] target_kl:[0.0050].
#    pi_loss:[-0.0054], entropy:[3.3348], r_avg[-0.0073]
# [Eval. start] step:[40/5000][0.8%] #step:[0.0e+00] time:[day:[01] 05:51:18] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[-0.1829] ep_len:[1033]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-2.8398] ep_len:[794]. blue health:[0.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.7946] ep_len:[787]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.6342] ep_len:[1264]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-11.8948] ep_len:[1017]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.5096] ep_len:[2582]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-0.7502] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.8387] ep_len:[495]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-2.9031] ep_len:[1938]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-72.1363] ep_len:[1318]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-2.9967] ep_len:[1620]. blue health:[0.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-0.8126] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.8098] ep_len:[959]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-17.0329] ep_len:[3000]. blue health:[0.81] red health:[0.98]
#  [14/20] [expert_system] ep_ret:[-100.9943] ep_len:[1352]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.5169] ep_len:[1372]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-3.0825] ep_len:[1972]. blue health:[0.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.9004] ep_len:[592]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-2.5879] ep_len:[1425]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-100.8969] ep_len:[1177]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 05:53:26] ep_ret_avg:[3.829].
# [../report/net/ppo_adt_cont/model_40.npz] saved.
# [41/5000] rollout:[417.4]s pi_iter:[999/1000] update:[52.1]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[0.0092], entropy:[3.3243], r_avg[-0.0070]
# [42/5000] rollout:[425.8]s pi_iter:[999/1000] update:[58.3]s kl:[0.0047] target_kl:[0.0050].
#    pi_loss:[-0.0133], entropy:[3.3235], r_avg[-0.0083]
# [43/5000] rollout:[422.7]s pi_iter:[999/1000] update:[57.9]s kl:[0.0040] target_kl:[0.0050].
#    pi_loss:[0.0017], entropy:[3.3036], r_avg[-0.0065]
# [44/5000] rollout:[414.1]s pi_iter:[999/1000] update:[55.4]s kl:[0.0036] target_kl:[0.0050].
#    pi_loss:[-0.0053], entropy:[3.3021], r_avg[-0.0072]
# [45/5000] rollout:[427.7]s pi_iter:[999/1000] update:[60.8]s kl:[0.0022] target_kl:[0.0050].
#    pi_loss:[-0.0073], entropy:[3.2799], r_avg[-0.0069]
# [Eval. start] step:[45/5000][0.9%] #step:[0.0e+00] time:[day:[01] 06:33:19] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[-2.8821] ep_len:[1117]. blue health:[0.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-1.1537] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.9183] ep_len:[558]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.8964] ep_len:[680]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-17.2749] ep_len:[1495]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.3653] ep_len:[1295]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-1.2360] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.7950] ep_len:[533]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-11.4774] ep_len:[2200]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-100.3762] ep_len:[508]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-1.7369] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-1.1797] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.4927] ep_len:[1101]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-2.5891] ep_len:[673]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-80.0900] ep_len:[1767]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-2.4251] ep_len:[1529]. blue health:[0.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-1.1200] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.8859] ep_len:[736]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-2.6458] ep_len:[719]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-20.8881] ep_len:[563]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 06:35:03] ep_ret_avg:[7.438].
# [../report/net/ppo_adt_cont/model_45.npz] saved.
# [46/5000] rollout:[421.9]s pi_iter:[999/1000] update:[61.2]s kl:[0.0034] target_kl:[0.0050].
#    pi_loss:[-0.0007], entropy:[3.2808], r_avg[-0.0027]
# [47/5000] rollout:[426.3]s pi_iter:[999/1000] update:[56.2]s kl:[0.0036] target_kl:[0.0050].
#    pi_loss:[0.0031], entropy:[3.2425], r_avg[-0.0041]
# [48/5000] rollout:[413.5]s pi_iter:[999/1000] update:[54.1]s kl:[0.0030] target_kl:[0.0050].
#    pi_loss:[0.0006], entropy:[3.2419], r_avg[-0.0096]
# [49/5000] rollout:[422.6]s pi_iter:[999/1000] update:[52.6]s kl:[0.0037] target_kl:[0.0050].
#    pi_loss:[-0.0038], entropy:[3.2391], r_avg[-0.0061]
# [50/5000] rollout:[414.3]s pi_iter:[999/1000] update:[54.7]s kl:[0.0041] target_kl:[0.0050].
#    pi_loss:[-0.0067], entropy:[3.2284], r_avg[-0.0072]
# [Eval. start] step:[50/5000][1.0%] #step:[0.0e+00] time:[day:[01] 07:14:40] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[-0.7957] ep_len:[1789]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-2.2927] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.6079] ep_len:[818]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-0.9173] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-3.6381] ep_len:[1205]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-3.7367] ep_len:[2103]. blue health:[0.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-3.3967] ep_len:[1838]. blue health:[0.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.6121] ep_len:[650]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-3.3628] ep_len:[2717]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-3.7630] ep_len:[1560]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[29.5928] ep_len:[3000]. blue health:[1.00] red health:[0.70]
#  [11/20] [rosie] ep_ret:[-1.5482] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.6457] ep_len:[886]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-0.7329] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-101.3105] ep_len:[1730]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-4.1709] ep_len:[2376]. blue health:[0.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-1.5063] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.5231] ep_len:[1149]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-1.9598] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-74.6979] ep_len:[1593]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 07:16:48] ep_ret_avg:[11.008].
# [../report/net/ppo_adt_cont/model_50.npz] saved.
# [51/5000] rollout:[430.1]s pi_iter:[999/1000] update:[58.2]s kl:[0.0041] target_kl:[0.0050].
#    pi_loss:[-0.0084], entropy:[3.2003], r_avg[-0.0047]
# [52/5000] rollout:[431.7]s pi_iter:[999/1000] update:[55.6]s kl:[0.0026] target_kl:[0.0050].
#    pi_loss:[0.0040], entropy:[3.1890], r_avg[-0.0069]
# [53/5000] rollout:[407.0]s pi_iter:[999/1000] update:[53.4]s kl:[0.0032] target_kl:[0.0050].
#    pi_loss:[-0.0063], entropy:[3.1790], r_avg[-0.0087]
# [54/5000] rollout:[411.2]s pi_iter:[999/1000] update:[56.6]s kl:[0.0036] target_kl:[0.0050].
#    pi_loss:[-0.0083], entropy:[3.1512], r_avg[-0.0047]
# [55/5000] rollout:[412.4]s pi_iter:[999/1000] update:[57.5]s kl:[0.0035] target_kl:[0.0050].
#    pi_loss:[-0.0042], entropy:[3.1620], r_avg[-0.0034]
# [Eval. start] step:[55/5000][1.1%] #step:[0.0e+00] time:[day:[01] 07:56:22] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[-3.4435] ep_len:[1416]. blue health:[0.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-1.6984] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.9058] ep_len:[537]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.6792] ep_len:[1286]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-101.1396] ep_len:[1109]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.3681] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-1.5730] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.5937] ep_len:[819]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-2.9539] ep_len:[1133]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-3.9635] ep_len:[1362]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-4.1207] ep_len:[2192]. blue health:[0.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-2.5288] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[-3.1009] ep_len:[868]. blue health:[0.00] red health:[1.00]
#  [13/20] [bud_fsm] ep_ret:[-0.9515] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[57.8709] ep_len:[874]. blue health:[0.59] red health:[0.00]
#  [15/20] [zombie] ep_ret:[-3.8170] ep_len:[2529]. blue health:[0.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-1.1741] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.5692] ep_len:[779]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-3.0850] ep_len:[2079]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-3.0730] ep_len:[641]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 07:58:26] ep_ret_avg:[10.863].
# [../report/net/ppo_adt_cont/model_55.npz] saved.
# [56/5000] rollout:[427.5]s pi_iter:[999/1000] update:[51.5]s kl:[0.0028] target_kl:[0.0050].
#    pi_loss:[-0.0018], entropy:[3.1422], r_avg[-0.0041]
# [57/5000] rollout:[428.9]s pi_iter:[999/1000] update:[51.5]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[0.0069], entropy:[3.1210], r_avg[-0.0023]
# [58/5000] rollout:[427.5]s pi_iter:[999/1000] update:[65.7]s kl:[0.0035] target_kl:[0.0050].
#    pi_loss:[-0.0046], entropy:[3.1091], r_avg[-0.0020]
# [59/5000] rollout:[433.9]s pi_iter:[999/1000] update:[53.8]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0016], entropy:[3.0922], r_avg[-0.0065]
# [60/5000] rollout:[427.7]s pi_iter:[999/1000] update:[49.3]s kl:[0.0041] target_kl:[0.0050].
#    pi_loss:[-0.0084], entropy:[3.0869], r_avg[-0.0054]
# [Eval. start] step:[60/5000][1.2%] #step:[0.0e+00] time:[day:[01] 08:38:44] ram:[21.3%].
#  [0/20] [zombie] ep_ret:[-1.6325] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-1.0278] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.4603] ep_len:[964]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.0685] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-23.6618] ep_len:[1103]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-2.4535] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-1.7489] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.4261] ep_len:[816]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-3.0487] ep_len:[841]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-23.9607] ep_len:[1325]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-1.2975] ep_len:[2257]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-2.8206] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.1602] ep_len:[1248]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[4.2496] ep_len:[3000]. blue health:[1.00] red health:[0.95]
#  [14/20] [expert_system] ep_ret:[-101.5752] ep_len:[1299]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.6136] ep_len:[1205]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-2.0592] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.7087] ep_len:[1247]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-1.0823] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-3.0748] ep_len:[704]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 08:40:51] ep_ret_avg:[11.494].
# [../report/net/ppo_adt_cont/model_60.npz] saved.
# [61/5000] rollout:[432.5]s pi_iter:[999/1000] update:[59.7]s kl:[0.0034] target_kl:[0.0050].
#    pi_loss:[-0.0048], entropy:[3.0881], r_avg[-0.0042]
# [62/5000] rollout:[424.2]s pi_iter:[999/1000] update:[54.4]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[-0.0071], entropy:[3.0535], r_avg[-0.0068]
# [63/5000] rollout:[423.2]s pi_iter:[999/1000] update:[59.4]s kl:[0.0032] target_kl:[0.0050].
#    pi_loss:[-0.0005], entropy:[3.0378], r_avg[-0.0063]
# [64/5000] rollout:[454.5]s pi_iter:[999/1000] update:[52.4]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0128], entropy:[3.0216], r_avg[-0.0029]
# [65/5000] rollout:[431.2]s pi_iter:[999/1000] update:[56.6]s kl:[0.0027] target_kl:[0.0050].
#    pi_loss:[-0.0101], entropy:[3.0094], r_avg[-0.0059]
# [Eval. start] step:[65/5000][1.3%] #step:[0.0e+00] time:[day:[01] 09:21:40] ram:[19.6%].
#  [0/20] [zombie] ep_ret:[-2.7279] ep_len:[343]. blue health:[0.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-1.9811] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.7269] ep_len:[551]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-3.2831] ep_len:[1230]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-7.3583] ep_len:[2066]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-2.6593] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-3.2458] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.2328] ep_len:[1398]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-3.0250] ep_len:[1877]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-7.3323] ep_len:[1166]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-2.8251] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-4.0754] ep_len:[2237]. blue health:[0.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.8886] ep_len:[368]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-3.1093] ep_len:[2076]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-3.4025] ep_len:[815]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-2.1681] ep_len:[2592]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-2.2746] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.5237] ep_len:[733]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-3.2452] ep_len:[1367]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-100.0912] ep_len:[152]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 09:23:31] ep_ret_avg:[12.278].
# [../report/net/ppo_adt_cont/model_65.npz] saved.
# [66/5000] rollout:[439.7]s pi_iter:[999/1000] update:[62.2]s kl:[0.0034] target_kl:[0.0050].
#    pi_loss:[-0.0027], entropy:[3.0093], r_avg[-0.0045]
# [67/5000] rollout:[432.7]s pi_iter:[999/1000] update:[53.1]s kl:[0.0035] target_kl:[0.0050].
#    pi_loss:[-0.0034], entropy:[3.0095], r_avg[-0.0020]
# [68/5000] rollout:[419.8]s pi_iter:[999/1000] update:[60.5]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0062], entropy:[2.9866], r_avg[-0.0050]
# [69/5000] rollout:[447.3]s pi_iter:[999/1000] update:[58.2]s kl:[0.0034] target_kl:[0.0050].
#    pi_loss:[-0.0054], entropy:[2.9857], r_avg[-0.0035]
# [70/5000] rollout:[449.4]s pi_iter:[999/1000] update:[54.3]s kl:[0.0038] target_kl:[0.0050].
#    pi_loss:[0.0001], entropy:[2.9838], r_avg[-0.0016]
# [Eval. start] step:[70/5000][1.4%] #step:[0.0e+00] time:[day:[01] 10:04:49] ram:[20.5%].
#  [0/20] [zombie] ep_ret:[-1.0118] ep_len:[2145]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-2.1002] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[98.9298] ep_len:[1197]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-3.2815] ep_len:[1083]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-3.2258] ep_len:[759]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[99.3605] ep_len:[1821]. blue health:[1.00] red health:[0.00]
#  [6/20] [rosie] ep_ret:[-3.2002] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.3846] ep_len:[1270]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-3.2108] ep_len:[1386]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-3.3005] ep_len:[803]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-1.2139] ep_len:[1560]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-3.3945] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.4479] ep_len:[643]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-3.4045] ep_len:[1065]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-3.3034] ep_len:[658]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[98.2490] ep_len:[2397]. blue health:[1.00] red health:[0.00]
#  [16/20] [rosie] ep_ret:[-3.0332] ep_len:[897]. blue health:[0.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[-2.8452] ep_len:[884]. blue health:[0.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[-1.5562] ep_len:[1218]. blue health:[0.00] red health:[0.99]
#  [19/20] [expert_system] ep_ret:[-83.4798] ep_len:[1258]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 10:06:36] ep_ret_avg:[18.691].
# [../report/net/ppo_adt_cont/model_70.npz] saved.
# [71/5000] rollout:[428.5]s pi_iter:[999/1000] update:[61.0]s kl:[0.0036] target_kl:[0.0050].
#    pi_loss:[-0.0061], entropy:[2.9719], r_avg[-0.0024]
# [72/5000] rollout:[439.1]s pi_iter:[999/1000] update:[60.5]s kl:[0.0048] target_kl:[0.0050].
#    pi_loss:[-0.0012], entropy:[2.9613], r_avg[0.0040]
# [73/5000] rollout:[452.0]s pi_iter:[999/1000] update:[55.7]s kl:[0.0037] target_kl:[0.0050].
#    pi_loss:[-0.0120], entropy:[2.9355], r_avg[-0.0020]
# [74/5000] rollout:[434.6]s pi_iter:[999/1000] update:[58.6]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[-0.0048], entropy:[2.9418], r_avg[-0.0010]
# [75/5000] rollout:[434.4]s pi_iter:[999/1000] update:[58.2]s kl:[0.0041] target_kl:[0.0050].
#    pi_loss:[0.0060], entropy:[2.9278], r_avg[-0.0044]
# [Eval. start] step:[75/5000][1.5%] #step:[0.0e+00] time:[day:[01] 10:47:59] ram:[20.8%].
#  [0/20] [zombie] ep_ret:[-1.1004] ep_len:[2103]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-2.3775] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.7812] ep_len:[360]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-3.2543] ep_len:[1133]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-3.0962] ep_len:[448]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.6981] ep_len:[1607]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-4.3049] ep_len:[2358]. blue health:[0.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.2616] ep_len:[903]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-2.9735] ep_len:[1388]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-3.5694] ep_len:[934]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-2.1923] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-3.3074] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.2940] ep_len:[913]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[12.3804] ep_len:[2142]. blue health:[0.00] red health:[0.84]
#  [14/20] [expert_system] ep_ret:[-22.8174] ep_len:[1086]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.3158] ep_len:[1020]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-2.4246] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[-2.5193] ep_len:[240]. blue health:[0.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[-2.7454] ep_len:[730]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-3.4829] ep_len:[867]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 10:50:18] ep_ret_avg:[12.477].
# [../report/net/ppo_adt_cont/model_75.npz] saved.
# [76/5000] rollout:[434.8]s pi_iter:[999/1000] update:[61.5]s kl:[0.0045] target_kl:[0.0050].
#    pi_loss:[0.0017], entropy:[2.9298], r_avg[-0.0036]
# [77/5000] rollout:[442.0]s pi_iter:[999/1000] update:[58.5]s kl:[0.0038] target_kl:[0.0050].
#    pi_loss:[-0.0036], entropy:[2.9171], r_avg[-0.0037]
# [78/5000] rollout:[429.8]s pi_iter:[999/1000] update:[56.6]s kl:[0.0041] target_kl:[0.0050].
#    pi_loss:[-0.0034], entropy:[2.9058], r_avg[0.0020]
# [79/5000] rollout:[432.7]s pi_iter:[999/1000] update:[66.1]s kl:[0.0029] target_kl:[0.0050].
#    pi_loss:[-0.0001], entropy:[2.8903], r_avg[-0.0036]
# [80/5000] rollout:[434.3]s pi_iter:[999/1000] update:[55.2]s kl:[0.0038] target_kl:[0.0050].
#    pi_loss:[-0.0049], entropy:[2.8490], r_avg[-0.0012]
# [Eval. start] step:[80/5000][1.6%] #step:[0.0e+00] time:[day:[01] 11:31:29] ram:[21.0%].
#  [0/20] [zombie] ep_ret:[-0.3857] ep_len:[957]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-2.6896] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[-2.8189] ep_len:[490]. blue health:[0.00] red health:[1.00]
#  [3/20] [bud_fsm] ep_ret:[-3.5189] ep_len:[1567]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-14.0126] ep_len:[714]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.4785] ep_len:[1016]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-1.5336] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.3229] ep_len:[1262]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-3.5387] ep_len:[1793]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-3.8181] ep_len:[1199]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-1.1915] ep_len:[1882]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-1.2207] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.3389] ep_len:[1373]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-3.1754] ep_len:[908]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-36.0801] ep_len:[2289]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-1.2409] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-1.5601] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.4121] ep_len:[1337]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[48.7153] ep_len:[2567]. blue health:[0.00] red health:[0.48]
#  [19/20] [expert_system] ep_ret:[1.9703] ep_len:[1140]. blue health:[0.00] red health:[0.95]
# [Eval. done] time:[day:[01] 11:33:23] ep_ret_avg:[13.575].
# [../report/net/ppo_adt_cont/model_80.npz] saved.
# [81/5000] rollout:[444.5]s pi_iter:[999/1000] update:[65.2]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0042], entropy:[2.8509], r_avg[-0.0043]
# [82/5000] rollout:[444.6]s pi_iter:[999/1000] update:[56.1]s kl:[0.0037] target_kl:[0.0050].
#    pi_loss:[-0.0082], entropy:[2.8349], r_avg[-0.0020]
# ...
#    pi_loss:[0.0065], entropy:[2.1108], r_avg[0.0014]
# [143/5000] rollout:[463.2]s pi_iter:[999/1000] update:[61.6]s kl:[0.0038] target_kl:[0.0050].
#    pi_loss:[-0.0085], entropy:[2.1019], r_avg[0.0030]
# [144/5000] rollout:[456.0]s pi_iter:[999/1000] update:[57.8]s kl:[0.0030] target_kl:[0.0050].
#    pi_loss:[-0.0021], entropy:[2.0970], r_avg[0.0005]
# [145/5000] rollout:[469.2]s pi_iter:[999/1000] update:[55.6]s kl:[0.0041] target_kl:[0.0050].
#    pi_loss:[0.0014], entropy:[2.0892], r_avg[0.0019]
# [Eval. start] step:[145/5000][2.9%] #step:[0.0e+00] time:[day:[01] 21:07:38] ram:[21.6%].
#  [0/20] [zombie] ep_ret:[-1.1992] ep_len:[2529]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-2.7497] ep_len:[823]. blue health:[0.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[98.9796] ep_len:[1085]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.8822] ep_len:[649]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-24.5965] ep_len:[954]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.6877] ep_len:[1089]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-3.6006] ep_len:[1536]. blue health:[0.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.8005] ep_len:[391]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-2.5272] ep_len:[1075]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-40.7357] ep_len:[969]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-2.6480] ep_len:[366]. blue health:[0.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-2.7706] ep_len:[940]. blue health:[0.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.5199] ep_len:[664]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-3.2483] ep_len:[2575]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-3.0501] ep_len:[439]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-1.0103] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-1.8912] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.6588] ep_len:[687]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-2.9525] ep_len:[920]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-3.1665] ep_len:[589]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 21:09:30] ep_ret_avg:[14.912].
# [../report/net/ppo_adt_cont/model_145.npz] saved.
# [146/5000] rollout:[467.4]s pi_iter:[999/1000] update:[62.5]s kl:[0.0036] target_kl:[0.0050].
#    pi_loss:[-0.0066], entropy:[2.0665], r_avg[0.0028]
# [147/5000] rollout:[471.8]s pi_iter:[999/1000] update:[55.3]s kl:[0.0032] target_kl:[0.0050].
#    pi_loss:[-0.0100], entropy:[2.0733], r_avg[0.0045]
# [148/5000] rollout:[473.7]s pi_iter:[999/1000] update:[65.0]s kl:[0.0032] target_kl:[0.0050].
#    pi_loss:[-0.0001], entropy:[2.0442], r_avg[-0.0016]
# [149/5000] rollout:[453.6]s pi_iter:[999/1000] update:[60.7]s kl:[0.0036] target_kl:[0.0050].
#    pi_loss:[0.0021], entropy:[2.0248], r_avg[-0.0001]
# [150/5000] rollout:[462.6]s pi_iter:[999/1000] update:[53.0]s kl:[0.0043] target_kl:[0.0050].
#    pi_loss:[-0.0163], entropy:[2.0228], r_avg[0.0026]
# [Eval. start] step:[150/5000][3.0%] #step:[0.0e+00] time:[day:[01] 21:53:16] ram:[21.7%].
#  [0/20] [zombie] ep_ret:[-0.8817] ep_len:[2130]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-1.3180] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.4932] ep_len:[927]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-3.1558] ep_len:[2070]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-16.2217] ep_len:[618]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-4.3754] ep_len:[2480]. blue health:[0.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-4.1597] ep_len:[2132]. blue health:[0.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.8196] ep_len:[1790]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-3.6873] ep_len:[2607]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-3.2306] ep_len:[686]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-1.1079] ep_len:[2211]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-1.8648] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.3763] ep_len:[818]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-3.2202] ep_len:[1014]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-3.3482] ep_len:[734]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.8661] ep_len:[1819]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-3.3275] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.4777] ep_len:[845]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-0.8843] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-11.0798] ep_len:[1864]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 21:55:47] ep_ret_avg:[16.772].
# [../report/net/ppo_adt_cont/model_150.npz] saved.
# [151/5000] rollout:[475.3]s pi_iter:[999/1000] update:[57.7]s kl:[0.0028] target_kl:[0.0050].
#    pi_loss:[0.0014], entropy:[2.0014], r_avg[-0.0007]
# [152/5000] rollout:[453.3]s pi_iter:[999/1000] update:[54.3]s kl:[0.0036] target_kl:[0.0050].
#    pi_loss:[-0.0078], entropy:[2.0014], r_avg[0.0011]
# [153/5000] rollout:[463.4]s pi_iter:[999/1000] update:[55.2]s kl:[0.0029] target_kl:[0.0050].
#    pi_loss:[-0.0088], entropy:[1.9780], r_avg[0.0026]
# [154/5000] rollout:[467.5]s pi_iter:[999/1000] update:[57.8]s kl:[0.0033] target_kl:[0.0050].
#    pi_loss:[-0.0050], entropy:[1.9779], r_avg[0.0007]
# [155/5000] rollout:[464.9]s pi_iter:[999/1000] update:[53.9]s kl:[0.0049] target_kl:[0.0050].
#    pi_loss:[0.0012], entropy:[1.9767], r_avg[0.0020]
# [Eval. start] step:[155/5000][3.1%] #step:[0.0e+00] time:[day:[01] 22:39:11] ram:[21.6%].
#  [0/20] [zombie] ep_ret:[-3.2812] ep_len:[1715]. blue health:[0.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-2.9901] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[98.9678] ep_len:[1066]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-3.5870] ep_len:[1326]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-101.1639] ep_len:[1544]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.5259] ep_len:[1517]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-2.8187] ep_len:[986]. blue health:[0.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.3526] ep_len:[645]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-2.1805] ep_len:[1581]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-3.7155] ep_len:[768]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-0.7279] ep_len:[2027]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-3.1090] ep_len:[781]. blue health:[0.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.4402] ep_len:[655]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-3.1012] ep_len:[948]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-3.1242] ep_len:[1054]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.3923] ep_len:[943]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-2.8449] ep_len:[831]. blue health:[0.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.9156] ep_len:[386]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-2.6859] ep_len:[297]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-3.1197] ep_len:[916]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 22:41:04] ep_ret_avg:[12.915].
# [../report/net/ppo_adt_cont/model_155.npz] saved.
# [156/5000] rollout:[460.3]s pi_iter:[999/1000] update:[59.0]s kl:[0.0043] target_kl:[0.0050].
#    pi_loss:[-0.0052], entropy:[1.9631], r_avg[0.0015]
# [157/5000] rollout:[477.3]s pi_iter:[999/1000] update:[60.1]s kl:[0.0040] target_kl:[0.0050].
#    pi_loss:[-0.0005], entropy:[1.9576], r_avg[0.0014]
# [158/5000] rollout:[478.3]s pi_iter:[999/1000] update:[54.4]s kl:[0.0036] target_kl:[0.0050].
#    pi_loss:[-0.0102], entropy:[1.9421], r_avg[0.0013]
# [159/5000] rollout:[475.2]s pi_iter:[999/1000] update:[65.4]s kl:[0.0043] target_kl:[0.0050].
#    pi_loss:[-0.0096], entropy:[1.9418], r_avg[0.0021]
# [160/5000] rollout:[462.4]s pi_iter:[999/1000] update:[63.6]s kl:[0.0039] target_kl:[0.0050].
#    pi_loss:[-0.0030], entropy:[1.9350], r_avg[-0.0012]
# [Eval. start] step:[160/5000][3.2%] #step:[0.0e+00] time:[day:[01] 23:25:20] ram:[21.6%].
#  [0/20] [zombie] ep_ret:[-1.6389] ep_len:[2538]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-3.1464] ep_len:[2180]. blue health:[0.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.1603] ep_len:[910]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-3.0150] ep_len:[1496]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-100.3035] ep_len:[414]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-1.0052] ep_len:[1873]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-4.3616] ep_len:[1956]. blue health:[0.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.5825] ep_len:[561]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-3.5539] ep_len:[2772]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-43.3378] ep_len:[3000]. blue health:[0.59] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-0.4773] ep_len:[983]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-3.5486] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[99.2213] ep_len:[738]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-3.2570] ep_len:[1423]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-21.0557] ep_len:[513]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.4663] ep_len:[1182]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-4.6799] ep_len:[2071]. blue health:[0.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[-2.9972] ep_len:[784]. blue health:[0.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[-3.7907] ep_len:[1544]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-3.2997] ep_len:[762]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 23:28:39] ep_ret_avg:[4.701].
# [../report/net/ppo_adt_cont/model_160.npz] saved.
# [161/5000] rollout:[440.2]s pi_iter:[999/1000] update:[56.6]s kl:[0.0031] target_kl:[0.0050].
#    pi_loss:[-0.0000], entropy:[1.8897], r_avg[-0.0017]
# [162/5000] rollout:[470.8]s pi_iter:[999/1000] update:[59.7]s kl:[0.0041] target_kl:[0.0050].
#    pi_loss:[-0.0050], entropy:[1.9067], r_avg[0.0010]
# [163/5000] rollout:[462.4]s pi_iter:[999/1000] update:[58.4]s kl:[0.0051] target_kl:[0.0050].
#    pi_loss:[-0.0040], entropy:[1.9029], r_avg[0.0036]
# [164/5000] rollout:[463.0]s pi_iter:[999/1000] update:[60.7]s kl:[0.0045] target_kl:[0.0050].
#    pi_loss:[-0.0042], entropy:[1.8895], r_avg[-0.0001]
# [165/5000] rollout:[484.0]s pi_iter:[999/1000] update:[58.8]s kl:[0.0040] target_kl:[0.0050].
#    pi_loss:[0.0010], entropy:[1.8899], r_avg[-0.0011]
# [Eval. start] step:[165/5000][3.3%] #step:[0.0e+00] time:[day:[02] 00:12:14] ram:[21.7%].
#  [0/20] [zombie] ep_ret:[-1.2536] ep_len:[1772]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-3.7806] ep_len:[2100]. blue health:[0.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[-2.9513] ep_len:[771]. blue health:[0.00] red health:[1.00]
#  [3/20] [bud_fsm] ep_ret:[-3.3960] ep_len:[1197]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-100.7261] ep_len:[792]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.9445] ep_len:[1857]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-3.1990] ep_len:[1738]. blue health:[0.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[99.7720] ep_len:[263]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.5514] ep_len:[2056]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-3.3658] ep_len:[807]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-0.7320] ep_len:[1833]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-3.5289] ep_len:[2115]. blue health:[0.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[-3.1610] ep_len:[890]. blue health:[0.00] red health:[1.00]
#  [13/20] [bud_fsm] ep_ret:[-2.9554] ep_len:[664]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[99.2024] ep_len:[592]. blue health:[1.00] red health:[0.00]
#  [15/20] [zombie] ep_ret:[-0.6540] ep_len:[2194]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-3.0273] ep_len:[1244]. blue health:[0.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[99.3908] ep_len:[903]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-3.8049] ep_len:[1540]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-96.1985] ep_len:[1615]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[02] 00:13:49] ep_ret_avg:[8.262].
# [../report/net/ppo_adt_cont/model_165.npz] saved.
# [166/5000] rollout:[459.0]s pi_iter:[999/1000] update:[58.7]s kl:[0.0043] target_kl:[0.0050].
#    pi_loss:[-0.0088], entropy:[1.8837], r_avg[0.0015]
# [167/5000] rollout:[447.6]s pi_iter:[999/1000] update:[59.2]s kl:[0.0042] target_kl:[0.0050].
#    pi_loss:[0.0026], entropy:[1.8547], r_avg[0.0044]
# [168/5000] rollout:[436.2]s pi_iter:[999/1000] update:[54.8]s kl:[0.0036] target_kl:[0.0050].
#    pi_loss:[-0.0084], entropy:[1.8569], r_avg[-0.0017]
# [169/5000] rollout:[459.4]s pi_iter:[999/1000] update:[63.3]s kl:[0.0040] target_kl:[0.0050].
#    pi_loss:[-0.0052], entropy:[1.8357], r_avg[0.0020]
# [170/5000] rollout:[470.7]s pi_iter:[999/1000] update:[52.7]s kl:[0.0042] target_kl:[0.0050].
#    pi_loss:[-0.0034], entropy:[1.8350], r_avg[0.0028]
# [Eval. start] step:[170/5000][3.4%] #step:[0.0e+00] time:[day:[02] 00:56:30] ram:[21.7%].
#  [0/20] [zombie] ep_ret:[-0.9655] ep_len:[1412]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[-3.8382] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[99.4368] ep_len:[706]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-4.0224] ep_len:[1297]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-3.0385] ep_len:[558]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-1.4460] ep_len:[2260]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-3.8839] ep_len:[1887]. blue health:[0.00] red health:[1.00]
#  [7/20] [bud] ep_ret:[-2.9329] ep_len:[663]. blue health:[0.00] red health:[1.00]
#  [8/20] [bud_fsm] ep_ret:[-2.8603] ep_len:[597]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-67.8033] ep_len:[868]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-0.4567] ep_len:[1095]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[-3.3118] ep_len:[1126]. blue health:[0.00] red health:[1.00]
#  [12/20] [bud] ep_ret:[98.8798] ep_len:[1497]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-3.2867] ep_len:[1860]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-3.0588] ep_len:[455]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-1.7798] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[-3.8312] ep_len:[3000]. blue health:[1.00] red health:[1.00]
#  [17/20] [bud] ep_ret:[98.9899] ep_len:[1112]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-3.2605] ep_len:[870]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-2.8409] ep_len:[682]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[02] 00:58:29] ep_ret_avg:[9.234].
# [../report/net/ppo_adt_cont/model_170.npz] saved.
# [171/5000] rollout:[451.0]s pi_iter:[999/1000] update:[56.7]s kl:[0.0039] target_kl:[0.0050].
#    pi_loss:[0.0046], entropy:[1.8080], r_avg[-0.0001]
