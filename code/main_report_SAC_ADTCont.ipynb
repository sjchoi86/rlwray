# %% [markdown]
# # SAC with ADT Continuous Env

# %%
import datetime,gym,time,os,psutil,ray
import numpy as np
import tensorflow as tf
from util import open_txt,write_txt
from sac import ReplayBuffer,create_sac_model,create_sac_graph,\
    save_sac_model_and_buffers,restore_sac_model_and_buffers
from episci.environment_wrappers.tactical_action_adt_env_continuous \
    import CustomADTEnvContinuous
from episci.agents.utils.constants import Agents,RewardType,StateInfo
print ("Packaged loaded. TF version is [%s]."%(tf.__version__))
# Out:
# Packaged loaded. TF version is [1.15.0].

# %% [markdown]
# ### Hyperparameters

# %%
# Worker
exp_name = 'sac_adt_cont_04'
n_cpu = 21
n_workers = 20

# %%
# Environment
action_length = 10 # 50/? HZ
# Red agent distribution for training
red_list_train = [
    Agents.ZOMBIE,
    Agents.SPOT_RANDOM,
    Agents.EXPERT_SYSTEM
]
# Red agent distribution for evaluation
red_list_eval = [
    Agents.ZOMBIE,
    Agents.ROSIE, 
    Agents.BUD, 
    Agents.BUD_FSM, 
    Agents.EXPERT_SYSTEM
]*n_workers
red_list_eval = red_list_eval[:n_workers]
num_eval = len(red_list_eval) # evaluation

# Steps
total_steps,evaluate_every,print_every = 5000,5,1
ep_len_rollout = 15000 // action_length 
buffer_size = int(3000*len(red_list_train)) 

# Network configuration
hdims = [32,32]
actv = tf.nn.relu
batch_size,update_count = int(2**15),500 # batchsize / number of updates
lr = 1e-6 # 1e-5
epsilon = 1e-1 # 1e-5
# SAC
gamma = 0.999 #
alpha_q,alpha_pi = 0.01,0.01 # 0.5,0.5
polyak = 0.995 
# Buffer
buffer_sz_long,buffer_sz_short = 1e6,1e5 # 1e5,1e5
# Temperature
temp_min,temp_max = 1.0,1.0 # 0.0,0.5
# Reward Offset
r_offset = 0.0

# %% [markdown]
# ### Environment

# %%
def get_env(red_distribution=None):
    from episci.environment_wrappers.tactical_action_adt_env_continuous \
        import CustomADTEnvContinuous
    from episci.agents.utils.constants import Agents, RewardType
    env_config = {
        "red_distribution": red_distribution,
        "reward_type": RewardType.SHAPED
    }
    return CustomADTEnvContinuous(env_config,action_length=action_length)

# %% [markdown]
# ### Logger

# %%
txt_path = '../report/log/%s/log_%s.txt'%(
    exp_name,
    datetime.datetime.now().strftime("%b-%d-%Y-%H:%M:%S"))
f = open_txt(txt_path)
print ("[%s] created."%(txt_path))
time.sleep(1)
# Out:
# [../report/log/sac_adt_cont_04/log_Aug-19-2020-08:44:55.txt] created.

# %% [markdown]
# ### Rollout Workers

# %%
class RolloutWorkerClass(object):
    """
    Worker without RAY (for update purposes)
    """
    def __init__(self,hdims=[256,256],actv=tf.nn.relu,
                 lr=1e-3,gamma=0.99,alpha_q=0.1,alpha_pi=0.1,polyak=0.995,epsilon=1e-2,
                 seed=1):
        self.seed = seed
        # Each worker should maintain its own environment
        import gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) 
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        _ = self.env.reset(red=Agents.SPOT_RANDOM)
        
        # Create SAC model and computational graph 
        self.model,self.sess = create_sac_model(
            odim=self.odim,adim=self.adim,hdims=hdims,actv=actv)
        self.step_ops,self.target_init = \
            create_sac_graph(self.model,lr=lr,gamma=gamma,alpha_q=alpha_q,alpha_pi=alpha_pi,
                             polyak=polyak,epsilon=epsilon)
        
        # Initialize model 
        tf.set_random_seed(self.seed)
        np.random.seed(self.seed)
        self.sess.run(tf.global_variables_initializer())
        self.sess.run(self.target_init)
        
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True
    
    def get_action(self,o,deterministic=False):
        act_op = self.model['mu'] if deterministic else self.model['pi']
        return self.sess.run(act_op, feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
    
    def set_weights(self,weight_vals):
        """
        Set weights without memory leakage
        """
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['main_vars']): #+self.model['target_vars']:
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['main_vars']): #+self.model['target_vars']:
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:weight_vals[w_idx]})

    def get_weights(self):
        """
        Get weights
        """
        weight_vals = self.sess.run(self.model['main_vars']) #+self.model['target_vars']
        return weight_vals
    
@ray.remote
class RayRolloutWorkerClass(object):
    """
    Rollout Worker with RAY
    """
    def __init__(self,worker_id=0,hdims=[256,256],actv=tf.nn.relu,
                 ep_len_rollout=1000,buffer_size=1000):
        # Parse
        self.worker_id = worker_id
        self.ep_len_rollout = ep_len_rollout
        self.buffer_size = buffer_size
        # Each worker should maintain its own environment
        import gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) 
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        _ = self.env.reset(red=Agents.SPOT_RANDOM)
        
        # Replay buffers to pass
        self.o_buffer = np.zeros((self.buffer_size,self.odim))
        self.a_buffer = np.zeros((self.buffer_size,self.adim))
        self.r_buffer = np.zeros((self.buffer_size))
        self.o2_buffer = np.zeros((self.buffer_size,self.odim))
        self.d_buffer = np.zeros((self.buffer_size))
        
        # Create SAC model
        self.model,self.sess = create_sac_model(
            odim=self.odim,adim=self.adim,hdims=hdims,actv=actv)
        self.sess.run(tf.global_variables_initializer())
        print ("Ray Worker [%d] Ready."%(self.worker_id))
        
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True
        
        # Flag to initialize rollout
        self.FIRST_ROLLOUT_FLAG = True
        
    def get_action(self,o,deterministic=False,temperature=1.0):
        """
        Get action (if temperature is 0, it becomes deterministic)
        """
        a_mu = self.sess.run(self.model['mu'],
                             feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
        a_pi = self.sess.run(self.model['pi'],
                             feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
        if deterministic:
            a = a_mu
        else:
            a = temperature*a_pi + (1-temperature)*a_mu
        return a
    
    def set_weights(self,weight_vals):
        """
        Set weights without memory leakage
        """
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['main_vars']): #+self.model['target_vars']:
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['main_vars']): #+self.model['target_vars']:
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:weight_vals[w_idx]})
            
    def rollout(self,temperature=1.0,
                red_list=[Agents.SPOT_RANDOM,Agents.EXPERT_SYSTEM]):
        """
        Rollout
        """
        if self.FIRST_ROLLOUT_FLAG:
            self.FIRST_ROLLOUT_FLAG = False
            self.o = self.env.reset(red=Agents.SPOT_RANDOM) # reset environment
        # Loop
        r_sum,cnt = 0,0
        for r_idx,red in enumerate(red_list): # for each red policy
            self.o = self.env.reset(red=red) # reset environment
            for t in range(self.ep_len_rollout):
                self.a = self.get_action(self.o,deterministic=False,temperature=temperature)
                self.o2,self.r,self.d,_ = self.env.step(self.a)
                r_sum += (self.r+r_offset)
                # Append
                self.o_buffer[cnt,:] = self.o
                self.a_buffer[cnt,:] = self.a
                self.r_buffer[cnt] = self.r
                self.o2_buffer[cnt,:] = self.o2
                self.d_buffer[cnt] = self.d
                cnt += 1
                # Save next state 
                self.o = self.o2
                if self.d: 
                    # self.o = self.env.reset(red=Agents.SPOT_RANDOM) # reset when done 
                    break
        o_buffer = self.o_buffer[:cnt,:]
        a_buffer = self.a_buffer[:cnt,:]
        r_buffer = self.r_buffer[:cnt]
        o2_buffer = self.o2_buffer[:cnt,:]
        d_buffer = self.d_buffer[:cnt]
        r_avg = r_sum / cnt
        return o_buffer,a_buffer,r_buffer,o2_buffer,d_buffer,r_avg
    
    def evaluate(self,red=None):
        """
        Evaluate
        """
        o,d,ep_ret,ep_len = self.env.reset(red=red),False,0,0
        while not(d or (ep_len == self.ep_len_rollout)):
            a = self.get_action(o,deterministic=True)
            o,r,d,_ = self.env.step(a)
            ep_ret += r # compute return 
            ep_len += 1
        blue_health,red_health = self.env.blue_health,self.env.red_health
        eval_res = [ep_ret,ep_len,blue_health,red_health] # evaluation result 
        return eval_res

# %% [markdown]
# ### Initialize Workers

# %%
ray.init(num_cpus=n_cpu)
tf.reset_default_graph()
R = RolloutWorkerClass(hdims=hdims,actv=actv,
                       lr=lr,gamma=gamma,alpha_q=alpha_q,alpha_pi=alpha_pi,
                       polyak=polyak,epsilon=epsilon,
                       seed=0)
workers = [RayRolloutWorkerClass.remote(
    worker_id=i,hdims=hdims,actv=actv,
    ep_len_rollout=ep_len_rollout,buffer_size=buffer_size) 
           for i in range(n_workers)]
print ("RAY initialized with [%d] cpus and [%d] workers."%
       (n_cpu,n_workers))
# Out:
# 2020-08-19 08:44:56,893	INFO resource_spec.py:212 -- Starting Ray with 148.44 GiB memory available for workers and up to 67.62 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-08-19 08:44:57,020	WARNING services.py:923 -- Redis failed to start, retrying now.
# 2020-08-19 08:44:57,272	WARNING services.py:923 -- Redis failed to start, retrying now.
# 2020-08-19 08:44:57,558	INFO services.py:1165 -- View the Ray dashboard at localhost:8269
# RAY initialized with [21] cpus and [20] workers.

# %% [markdown]
# ### Replay Buffers

# %%
replay_buffer_long = ReplayBuffer(odim=R.odim,adim=R.adim,size=int(buffer_sz_long))
replay_buffer_short = ReplayBuffer(odim=R.odim,adim=R.adim,size=int(buffer_sz_short))

# %% [markdown]
# ### Loop

# %%
npz_path = ''
if npz_path:
    restore_sac_model_and_buffers(npz_path=npz_path,R=R,
                                  replay_buffer_long=replay_buffer_long,
                                  replay_buffer_short=replay_buffer_short,
                                  VERBOSE=False,IGNORE_BUFFERS=True)

# %%
npz_path_list,ep_ret_avg_list = [],[]
start_time = time.time()
n_env_step = 0 # number of environment steps
ep_ret_avg = 0
for t in range(int(total_steps)):
    esec = time.time()-start_time
    
    # 1. Synchronize worker weights
    weights = R.get_weights()
    set_weights_list = [worker.set_weights.remote(weights) for worker in workers] 
    
    # 2. Make rollout and accumulate to Buffers
    t_start = time.time()
    ops = [worker.rollout.remote(
        temperature=temp_min+(temp_max-temp_min)*np.random.rand(),
        red_list=red_list_train # <= with the list of pre-defined red agent policies
    )
           for worker in workers]
    rollout_vals = ray.get(ops)
    r_sum = 0
    for rollout_val in rollout_vals:
        o_buffer,a_buffer,r_buffer,o2_buffer,d_buffer,r_rollout_avg = rollout_val
        r_sum += r_rollout_avg
        for i in range(o_buffer.shape[0]):
            o,a,r,o2,d = o_buffer[i,:],a_buffer[i,:],r_buffer[i],o2_buffer[i,:],d_buffer[i]
            replay_buffer_long.store(o, a, r, o2, d) 
            replay_buffer_short.store(o, a, r, o2, d) 
            n_env_step += 1
    r_avg = r_sum / len(rollout_vals)
    sec_rollout = time.time() - t_start
    
    # 3. Update the SAC model
    t_start = time.time()
    avg_qs = np.zeros(int(update_count))
    for c_idx in range(int(update_count)):
        batch_long = replay_buffer_long.sample_batch(batch_size//2) 
        batch_short = replay_buffer_short.sample_batch(batch_size//2) 
        feed_dict = {R.model['o_ph']: np.concatenate((batch_long['obs1'],batch_short['obs1'])),
                     R.model['o2_ph']: np.concatenate((batch_long['obs2'],batch_short['obs2'])),
                     R.model['a_ph']: np.concatenate((batch_long['acts'],batch_short['acts'])),
                     R.model['r_ph']: np.concatenate((batch_long['rews'],batch_short['rews'])),
                     R.model['d_ph']: np.concatenate((batch_long['done'],batch_short['done']))
                    }
        outs = R.sess.run(R.step_ops, feed_dict) # update 
        q1_vals,q2_vals = outs[3],outs[4]
        avg_q = 0.5*np.mean(q1_vals)+0.5*np.mean(q2_vals)
        avg_qs[c_idx] = avg_q
    sec_update = time.time() - t_start
    
    # 4. Synchronize worker weights (after update)
    weights = R.get_weights()
    set_weights_list = [worker.set_weights.remote(weights) for worker in workers] 
    
    # Print
    if (t == 0) or (((t+1)%print_every) == 0): 
        print ("[%d/%d] n_env_step:[%.1e] rollout:[%.1f]s update:[%.1f]s r_avg:[%.4f] avg_q:[%.3f]."%
               (t+1,total_steps,n_env_step,sec_rollout,sec_update,r_avg,np.mean(avg_qs)))
        write_txt(f,"%.2f, r_train:%.4f, ret_eval:%.4f"%(time.time()-start_time,r_avg,ep_ret_avg),
                  ADD_NEWLINE=True,DO_PRINT=False)
        
    # 5. Evaluate
    if (t == 0) or (((t+1)%evaluate_every) == 0): 
        ram_percent = psutil.virtual_memory().percent # memory usage
        print ("[Eval. start] step:[%d/%d][%.1f%%] #step:[%.1e] time:[%s] ram:[%.1f%%]."%
               (t+1,total_steps,t/total_steps*100,
                n_env_step,
                time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),
                ram_percent)
              )
        ops = []
        for i_idx in range(num_eval):
            worker,red = workers[i_idx],red_list_eval[i_idx]
            ops.append(worker.evaluate.remote(red=red))
        eval_vals = ray.get(ops)
        ep_ret_sum = 0
        for i_idx in range(num_eval):
            red,eval_val = red_list_eval[i_idx],eval_vals[i_idx]
            ep_ret,ep_len,blue_health,red_health = eval_val[0],eval_val[1],eval_val[2],eval_val[3]
            ep_ret_sum += ep_ret
            print (" [%d/%d] [%s] ep_ret:[%.4f] ep_len:[%d]. blue health:[%.2f] red health:[%.2f]"
                %(i_idx,len(eval_vals),red,ep_ret,ep_len,blue_health,red_health))
        ep_ret_avg = ep_ret_sum / num_eval
        print ("[Eval. done] time:[%s] ep_ret_avg:[%.3f].\n"%
               (time.strftime("day:[%d] %H:%M:%S", time.gmtime(time.time()-start_time)),ep_ret_avg))
        # Save current SAC model and replay buffers 
        npz_path = '../report/net/%s/model_and_buffers_%d.npz'%(exp_name,t+1)
        save_sac_model_and_buffers(npz_path,R,replay_buffer_long,replay_buffer_short,
                                   VERBOSE=False,IGNORE_BUFFERS=True)
        
        # If something went bad, restore 
        npz_path_list.append(npz_path)
        ep_ret_avg_list.append(ep_ret_avg)
        """
        ep_ret_avg_array = np.asanyarray(ep_ret_avg_list)
        ep_ret_avg_max = np.max(ep_ret_avg_array)
        if (ep_ret_avg < 0.5*ep_ret_avg_max) and (len(npz_path_list) >= 2) and (ep_ret_avg_max > 0):
            npz_path = npz_path_list[np.argmax(ep_ret_avg_array)] 
            restore_sac_model_and_buffers(npz_path=npz_path,R=R,
                                          replay_buffer_long=replay_buffer_long,
                                          replay_buffer_short=replay_buffer_short,
                                          VERBOSE=False,IGNORE_BUFFERS=True)
            print ("Restoring [%s] as current[%.2f] is way lower than max[%.2f]"%
                   (npz_path,ep_ret_avg,ep_ret_avg_max))
        """
print ("Done.")
# Out:
# (pid=125427)
# (pid=125427)
# (pid=125427)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125413)
# (pid=125413)
# (pid=125413)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125416)
# (pid=125416)
# (pid=125416)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125414)
# (pid=125414)
# (pid=125414)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125431)
# (pid=125431)
# (pid=125431)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125418)
# (pid=125418)
# (pid=125418)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125432)
# (pid=125432)
# (pid=125432)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125422)
# (pid=125422)
# (pid=125422)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125420)
# (pid=125420)
# (pid=125420)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125421)
# (pid=125421)
# (pid=125421)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125424)
# (pid=125424)
# (pid=125424)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125428)
# (pid=125428)
# (pid=125428)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125411)
# (pid=125411)
# (pid=125411)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125423)
# (pid=125423)
# (pid=125423)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125430)
# (pid=125430)
# (pid=125430)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125425)
# (pid=125425)
# (pid=125425)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125426)
# (pid=125426)
# (pid=125426)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125417)
# (pid=125417)
# (pid=125417)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125415)
# (pid=125415)
# (pid=125415)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125429)
# (pid=125429)
# (pid=125429)      JSBSim Flight Dynamics Model v1.1.0.dev1 Jul 11 2020 05:35:14
# (pid=125427) Ray Worker [11] Ready.
# (pid=125431) Ray Worker [7] Ready.
# (pid=125418) Ray Worker [13] Ready.
# (pid=125413) Ray Worker [16] Ready.
# (pid=125414) Ray Worker [5] Ready.
# (pid=125420) Ray Worker [0] Ready.
# (pid=125424) Ray Worker [19] Ready.
# (pid=125416) Ray Worker [18] Ready.
# (pid=125422) Ray Worker [4] Ready.
# (pid=125425) Ray Worker [2] Ready.
# (pid=125426) Ray Worker [3] Ready.
# (pid=125415) Ray Worker [1] Ready.
# (pid=125421) Ray Worker [10] Ready.
# (pid=125428) Ray Worker [9] Ready.
# (pid=125411) Ray Worker [15] Ready.
# (pid=125423) Ray Worker [17] Ready.
# (pid=125430) Ray Worker [8] Ready.
# (pid=125432) Ray Worker [6] Ready.
# (pid=125429) Ray Worker [14] Ready.
# (pid=125417) Ray Worker [12] Ready.
# [1/5000] n_env_step:[6.9e+04] rollout:[409.6]s update:[30.7]s r_avg:[-0.0253] avg_q:[0.025].
# [Eval. start] step:[1/5000][0.0%] #step:[6.9e+04] time:[day:[01] 00:07:20] ram:[16.4%].
#  [0/20] [zombie] ep_ret:[100.4627] ep_len:[586]. blue health:[1.00] red health:[0.00]
#  [1/20] [rosie] ep_ret:[0.6283] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [2/20] [bud] ep_ret:[100.1110] ep_len:[1014]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.2101] ep_len:[273]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.1729] ep_len:[338]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0557] ep_len:[1002]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.4752] ep_len:[1114]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[0.1485] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [8/20] [bud_fsm] ep_ret:[100.1726] ep_len:[138]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-64.5703] ep_len:[924]. blue health:[0.00] red health:[0.64]
#  [10/20] [zombie] ep_ret:[0.1285] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.1195] ep_len:[974]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.0814] ep_len:[524]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1988] ep_len:[470]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-60.0980] ep_len:[499]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.0522] ep_len:[843]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.4113] ep_len:[668]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.1077] ep_len:[1016]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.1814] ep_len:[212]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-86.0179] ep_len:[1458]. blue health:[0.00] red health:[0.86]
# [Eval. done] time:[day:[01] 00:10:03] ep_ret_avg:[39.624].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_1.npz] saved.
# [2/5000] n_env_step:[1.4e+05] rollout:[392.8]s update:[23.3]s r_avg:[-0.0216] avg_q:[0.025].
# [3/5000] n_env_step:[2.1e+05] rollout:[413.7]s update:[23.6]s r_avg:[-0.0291] avg_q:[0.025].
# [4/5000] n_env_step:[2.7e+05] rollout:[387.5]s update:[25.6]s r_avg:[-0.0251] avg_q:[0.025].
# [5/5000] n_env_step:[3.4e+05] rollout:[416.8]s update:[26.5]s r_avg:[-0.0262] avg_q:[0.025].
# [Eval. start] step:[5/5000][0.1%] #step:[3.4e+05] time:[day:[01] 00:38:33] ram:[19.3%].
#  [0/20] [zombie] ep_ret:[0.0572] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.2396] ep_len:[975]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0748] ep_len:[1144]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1406] ep_len:[124]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-90.4494] ep_len:[1500]. blue health:[0.10] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0385] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.1157] ep_len:[1003]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0969] ep_len:[910]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.2005] ep_len:[452]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-100.2081] ep_len:[601]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[0.2683] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.1155] ep_len:[978]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.0325] ep_len:[831]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.0809] ep_len:[319]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-100.1933] ep_len:[800]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.0805] ep_len:[1228]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.3926] ep_len:[1355]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.1212] ep_len:[1197]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.2753] ep_len:[528]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-31.9460] ep_len:[1500]. blue health:[0.60] red health:[0.92]
# [Eval. done] time:[day:[01] 00:41:07] ep_ret_avg:[43.965].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_5.npz] saved.
# [6/5000] n_env_step:[4.1e+05] rollout:[418.6]s update:[26.5]s r_avg:[-0.0217] avg_q:[0.025].
# [7/5000] n_env_step:[4.8e+05] rollout:[411.7]s update:[26.4]s r_avg:[-0.0244] avg_q:[0.025].
# [8/5000] n_env_step:[5.4e+05] rollout:[342.6]s update:[29.0]s r_avg:[-0.0195] avg_q:[0.025].
# [9/5000] n_env_step:[6.0e+05] rollout:[353.5]s update:[26.6]s r_avg:[-0.0287] avg_q:[0.025].
# [10/5000] n_env_step:[6.7e+05] rollout:[359.4]s update:[29.5]s r_avg:[-0.0279] avg_q:[0.025].
# [Eval. start] step:[10/5000][0.2%] #step:[6.7e+05] time:[day:[01] 01:14:50] ram:[20.1%].
#  [0/20] [zombie] ep_ret:[-0.0011] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.5082] ep_len:[1038]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.1483] ep_len:[1038]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1581] ep_len:[193]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-75.9070] ep_len:[675]. blue health:[0.00] red health:[0.76]
#  [5/20] [zombie] ep_ret:[-0.0740] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.2095] ep_len:[929]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[99.9900] ep_len:[1209]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.1155] ep_len:[172]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-10.8056] ep_len:[1500]. blue health:[0.66] red health:[0.77]
#  [10/20] [zombie] ep_ret:[-0.1375] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.4645] ep_len:[567]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.0547] ep_len:[108]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.2018] ep_len:[237]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-65.6593] ep_len:[1500]. blue health:[0.02] red health:[0.67]
#  [15/20] [zombie] ep_ret:[0.9752] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.1042] ep_len:[1028]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0185] ep_len:[466]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.0371] ep_len:[29]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[21.8950] ep_len:[1500]. blue health:[1.00] red health:[0.78]
# [Eval. done] time:[day:[01] 01:17:44] ep_ret_avg:[53.615].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_10.npz] saved.
# [11/5000] n_env_step:[7.4e+05] rollout:[368.5]s update:[25.5]s r_avg:[-0.0242] avg_q:[0.025].
# [12/5000] n_env_step:[8.0e+05] rollout:[408.8]s update:[27.0]s r_avg:[-0.0241] avg_q:[0.024].
# [13/5000] n_env_step:[8.7e+05] rollout:[421.8]s update:[26.7]s r_avg:[-0.0196] avg_q:[0.024].
# [14/5000] n_env_step:[9.4e+05] rollout:[352.2]s update:[32.0]s r_avg:[-0.0210] avg_q:[0.024].
# [15/5000] n_env_step:[1.0e+06] rollout:[379.9]s update:[27.7]s r_avg:[-0.0235] avg_q:[0.024].
# [Eval. start] step:[15/5000][0.3%] #step:[1.0e+06] time:[day:[01] 01:52:15] ram:[20.5%].
#  [0/20] [zombie] ep_ret:[100.6970] ep_len:[807]. blue health:[1.00] red health:[0.00]
#  [1/20] [rosie] ep_ret:[100.1526] ep_len:[986]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.6979] ep_len:[885]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1172] ep_len:[287]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.2042] ep_len:[773]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[0.6054] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.6082] ep_len:[1247]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0097] ep_len:[1201]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.1303] ep_len:[120]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-88.4158] ep_len:[642]. blue health:[0.00] red health:[0.88]
#  [10/20] [zombie] ep_ret:[-0.1291] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.3995] ep_len:[1118]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.0906] ep_len:[1045]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.0843] ep_len:[152]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-100.3996] ep_len:[870]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[100.0432] ep_len:[92]. blue health:[1.00] red health:[0.00]
#  [16/20] [rosie] ep_ret:[47.6701] ep_len:[1500]. blue health:[1.00] red health:[0.53]
#  [17/20] [bud] ep_ret:[99.9829] ep_len:[687]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.0952] ep_len:[347]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-30.4048] ep_len:[1500]. blue health:[0.70] red health:[1.00]
# [Eval. done] time:[day:[01] 01:55:01] ep_ret_avg:[51.592].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_15.npz] saved.
# [16/5000] n_env_step:[1.1e+06] rollout:[368.9]s update:[28.5]s r_avg:[-0.0243] avg_q:[0.025].
# [17/5000] n_env_step:[1.1e+06] rollout:[402.0]s update:[26.8]s r_avg:[-0.0232] avg_q:[0.025].
# [18/5000] n_env_step:[1.2e+06] rollout:[385.0]s update:[26.0]s r_avg:[-0.0274] avg_q:[0.024].
# [19/5000] n_env_step:[1.3e+06] rollout:[396.9]s update:[26.9]s r_avg:[-0.0299] avg_q:[0.024].
# [20/5000] n_env_step:[1.3e+06] rollout:[405.2]s update:[27.2]s r_avg:[-0.0249] avg_q:[0.024].
# [Eval. start] step:[20/5000][0.4%] #step:[1.3e+06] time:[day:[01] 02:29:54] ram:[20.7%].
#  [0/20] [zombie] ep_ret:[100.3414] ep_len:[583]. blue health:[1.00] red health:[0.00]
#  [1/20] [rosie] ep_ret:[100.3109] ep_len:[651]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[0.1399] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [3/20] [bud_fsm] ep_ret:[100.2376] ep_len:[419]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.0472] ep_len:[147]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[0.0051] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.4510] ep_len:[1108]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[99.9607] ep_len:[1177]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.2412] ep_len:[438]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[72.0787] ep_len:[1500]. blue health:[1.00] red health:[0.28]
#  [10/20] [zombie] ep_ret:[100.0967] ep_len:[118]. blue health:[1.00] red health:[0.00]
#  [11/20] [rosie] ep_ret:[100.4030] ep_len:[699]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.1131] ep_len:[691]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1652] ep_len:[287]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-100.2507] ep_len:[422]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.0604] ep_len:[857]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.3338] ep_len:[702]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0312] ep_len:[904]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.2610] ep_len:[1442]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[63.1336] ep_len:[1500]. blue health:[0.95] red health:[0.32]
# [Eval. done] time:[day:[01] 02:32:34] ep_ret_avg:[61.897].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_20.npz] saved.
# [21/5000] n_env_step:[1.4e+06] rollout:[385.2]s update:[26.0]s r_avg:[-0.0299] avg_q:[0.024].
# [22/5000] n_env_step:[1.5e+06] rollout:[386.1]s update:[27.6]s r_avg:[-0.0211] avg_q:[0.024].
# [23/5000] n_env_step:[1.5e+06] rollout:[417.1]s update:[26.6]s r_avg:[-0.0248] avg_q:[0.024].
# [24/5000] n_env_step:[1.6e+06] rollout:[382.6]s update:[29.8]s r_avg:[-0.0279] avg_q:[0.024].
# [25/5000] n_env_step:[1.7e+06] rollout:[378.9]s update:[32.9]s r_avg:[-0.0222] avg_q:[0.024].
# [Eval. start] step:[25/5000][0.5%] #step:[1.7e+06] time:[day:[01] 03:07:27] ram:[20.9%].
#  [0/20] [zombie] ep_ret:[0.0541] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.5111] ep_len:[1400]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0531] ep_len:[1015]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.2309] ep_len:[506]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.4276] ep_len:[742]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[0.4958] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.4058] ep_len:[551]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.2342] ep_len:[1085]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.2377] ep_len:[494]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-99.9835] ep_len:[442]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[-0.0949] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.1642] ep_len:[948]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.1001] ep_len:[1048]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1318] ep_len:[219]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[28.2869] ep_len:[1500]. blue health:[1.00] red health:[0.72]
#  [15/20] [zombie] ep_ret:[-0.0038] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.4149] ep_len:[604]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[4.2649] ep_len:[1500]. blue health:[1.00] red health:[0.96]
#  [18/20] [bud_fsm] ep_ret:[100.1848] ep_len:[438]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-100.3635] ep_len:[384]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 03:10:12] ep_ret_avg:[41.745].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_25.npz] saved.
# [26/5000] n_env_step:[1.7e+06] rollout:[328.8]s update:[26.8]s r_avg:[-0.0235] avg_q:[0.024].
# [27/5000] n_env_step:[1.8e+06] rollout:[360.3]s update:[32.6]s r_avg:[-0.0227] avg_q:[0.024].
# [28/5000] n_env_step:[1.9e+06] rollout:[399.4]s update:[27.0]s r_avg:[-0.0237] avg_q:[0.024].
# [29/5000] n_env_step:[1.9e+06] rollout:[383.2]s update:[30.8]s r_avg:[-0.0260] avg_q:[0.024].
# [30/5000] n_env_step:[2.0e+06] rollout:[403.4]s update:[29.0]s r_avg:[-0.0246] avg_q:[0.024].
# [Eval. start] step:[30/5000][0.6%] #step:[2.0e+06] time:[day:[01] 03:43:53] ram:[21.0%].
#  [0/20] [zombie] ep_ret:[0.1087] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.4655] ep_len:[1000]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0061] ep_len:[1425]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1338] ep_len:[202]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.2603] ep_len:[323]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0933] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.2915] ep_len:[732]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[0.2382] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [8/20] [bud_fsm] ep_ret:[100.1552] ep_len:[168]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-100.1629] ep_len:[647]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[0.1352] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.5490] ep_len:[1120]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.1270] ep_len:[575]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1781] ep_len:[220]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[98.5695] ep_len:[256]. blue health:[0.99] red health:[0.00]
#  [15/20] [zombie] ep_ret:[-0.0715] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.3256] ep_len:[653]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.1671] ep_len:[644]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[-2.4482] ep_len:[786]. blue health:[0.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[-100.4235] ep_len:[1111]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 03:45:51] ep_ret_avg:[39.900].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_30.npz] saved.
# [31/5000] n_env_step:[2.1e+06] rollout:[371.3]s update:[27.0]s r_avg:[-0.0275] avg_q:[0.023].
# [32/5000] n_env_step:[2.2e+06] rollout:[335.0]s update:[28.7]s r_avg:[-0.0235] avg_q:[0.023].
# [33/5000] n_env_step:[2.2e+06] rollout:[356.2]s update:[27.5]s r_avg:[-0.0265] avg_q:[0.024].
# [34/5000] n_env_step:[2.3e+06] rollout:[413.9]s update:[24.4]s r_avg:[-0.0255] avg_q:[0.023].
# [35/5000] n_env_step:[2.4e+06] rollout:[385.6]s update:[26.9]s r_avg:[-0.0265] avg_q:[0.024].
# [Eval. start] step:[35/5000][0.7%] #step:[2.4e+06] time:[day:[01] 04:19:07] ram:[21.1%].
#  [0/20] [zombie] ep_ret:[0.1147] ep_len:[1430]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.2789] ep_len:[236]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[62.0911] ep_len:[1500]. blue health:[1.00] red health:[0.38]
#  [3/20] [bud_fsm] ep_ret:[100.2151] ep_len:[389]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-42.3388] ep_len:[835]. blue health:[0.00] red health:[0.86]
#  [5/20] [zombie] ep_ret:[100.1684] ep_len:[181]. blue health:[1.00] red health:[0.00]
#  [6/20] [rosie] ep_ret:[100.6358] ep_len:[1029]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0511] ep_len:[851]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-2.2211] ep_len:[1129]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-64.4812] ep_len:[951]. blue health:[0.00] red health:[0.64]
#  [10/20] [zombie] ep_ret:[-0.0636] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.5872] ep_len:[1421]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[0.1823] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [13/20] [bud_fsm] ep_ret:[100.1935] ep_len:[337]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[99.9818] ep_len:[375]. blue health:[1.00] red health:[0.00]
#  [15/20] [zombie] ep_ret:[100.1339] ep_len:[140]. blue health:[1.00] red health:[0.00]
#  [16/20] [rosie] ep_ret:[100.1281] ep_len:[979]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0701] ep_len:[816]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.1257] ep_len:[142]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[100.3176] ep_len:[532]. blue health:[1.00] red health:[0.00]
# [Eval. done] time:[day:[01] 04:21:02] ep_ret_avg:[62.809].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_35.npz] saved.
# [36/5000] n_env_step:[2.4e+06] rollout:[391.0]s update:[30.6]s r_avg:[-0.0281] avg_q:[0.023].
# [37/5000] n_env_step:[2.5e+06] rollout:[348.6]s update:[27.6]s r_avg:[-0.0291] avg_q:[0.023].
# [38/5000] n_env_step:[2.6e+06] rollout:[355.1]s update:[25.4]s r_avg:[-0.0227] avg_q:[0.023].
# [39/5000] n_env_step:[2.6e+06] rollout:[347.1]s update:[32.1]s r_avg:[-0.0231] avg_q:[0.023].
# [40/5000] n_env_step:[2.7e+06] rollout:[355.3]s update:[31.7]s r_avg:[-0.0256] avg_q:[0.023].
# [Eval. start] step:[40/5000][0.8%] #step:[2.7e+06] time:[day:[01] 04:53:27] ram:[21.1%].
#  [0/20] [zombie] ep_ret:[0.0792] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.2914] ep_len:[519]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0125] ep_len:[771]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.0906] ep_len:[74]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.0561] ep_len:[248]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0519] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.4666] ep_len:[608]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.2459] ep_len:[223]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[98.7145] ep_len:[257]. blue health:[0.99] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-100.2679] ep_len:[1001]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[100.1916] ep_len:[272]. blue health:[1.00] red health:[0.00]
#  [11/20] [rosie] ep_ret:[100.1162] ep_len:[977]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.1717] ep_len:[1164]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1309] ep_len:[1248]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-46.6360] ep_len:[1500]. blue health:[0.54] red health:[1.00]
#  [15/20] [zombie] ep_ret:[9.0625] ep_len:[1500]. blue health:[1.00] red health:[0.91]
#  [16/20] [rosie] ep_ret:[100.5538] ep_len:[539]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[0.1100] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[100.1287] ep_len:[142]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-100.2841] ep_len:[667]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 04:56:12] ep_ret_avg:[43.153].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_40.npz] saved.
# [41/5000] n_env_step:[2.7e+06] rollout:[350.0]s update:[28.8]s r_avg:[-0.0233] avg_q:[0.023].
# [42/5000] n_env_step:[2.8e+06] rollout:[343.2]s update:[29.5]s r_avg:[-0.0252] avg_q:[0.023].
# [43/5000] n_env_step:[2.9e+06] rollout:[319.0]s update:[25.0]s r_avg:[-0.0276] avg_q:[0.023].
# [44/5000] n_env_step:[2.9e+06] rollout:[410.0]s update:[27.8]s r_avg:[-0.0257] avg_q:[0.023].
# [45/5000] n_env_step:[3.0e+06] rollout:[309.1]s update:[26.5]s r_avg:[-0.0292] avg_q:[0.023].
# [Eval. start] step:[45/5000][0.9%] #step:[3.0e+06] time:[day:[01] 05:27:21] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[100.0853] ep_len:[145]. blue health:[1.00] red health:[0.00]
#  [1/20] [rosie] ep_ret:[100.1169] ep_len:[920]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0671] ep_len:[1025]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1487] ep_len:[178]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.0148] ep_len:[955]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0679] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.4414] ep_len:[402]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0999] ep_len:[1361]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.1080] ep_len:[406]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[100.2276] ep_len:[577]. blue health:[1.00] red health:[0.00]
#  [10/20] [zombie] ep_ret:[-0.0973] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.4617] ep_len:[829]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.0649] ep_len:[874]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[-2.4018] ep_len:[968]. blue health:[0.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-100.2759] ep_len:[416]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[0.0756] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.3838] ep_len:[734]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0755] ep_len:[1324]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.2696] ep_len:[439]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-74.8636] ep_len:[1049]. blue health:[0.00] red health:[0.75]
# [Eval. done] time:[day:[01] 05:29:30] ep_ret_avg:[51.245].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_45.npz] saved.
# [46/5000] n_env_step:[3.1e+06] rollout:[372.8]s update:[28.8]s r_avg:[-0.0247] avg_q:[0.023].
# [47/5000] n_env_step:[3.1e+06] rollout:[376.4]s update:[28.8]s r_avg:[-0.0229] avg_q:[0.023].
# [48/5000] n_env_step:[3.2e+06] rollout:[363.0]s update:[29.6]s r_avg:[-0.0276] avg_q:[0.023].
# [49/5000] n_env_step:[3.3e+06] rollout:[400.6]s update:[29.5]s r_avg:[-0.0235] avg_q:[0.023].
# [50/5000] n_env_step:[3.3e+06] rollout:[361.0]s update:[30.6]s r_avg:[-0.0261] avg_q:[0.023].
# [Eval. start] step:[50/5000][1.0%] #step:[3.3e+06] time:[day:[01] 06:03:12] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[0.2765] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.7938] ep_len:[837]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0809] ep_len:[1309]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[0.3345] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-70.3978] ep_len:[524]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0810] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.3158] ep_len:[263]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.1189] ep_len:[1184]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.0594] ep_len:[104]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-100.5990] ep_len:[1379]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[0.0766] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.1023] ep_len:[972]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.2714] ep_len:[213]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1354] ep_len:[129]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[100.2119] ep_len:[297]. blue health:[1.00] red health:[0.00]
#  [15/20] [zombie] ep_ret:[100.3748] ep_len:[1314]. blue health:[1.00] red health:[0.00]
#  [16/20] [rosie] ep_ret:[100.6384] ep_len:[569]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0319] ep_len:[1085]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.1640] ep_len:[332]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-100.3029] ep_len:[693]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 06:05:32] ep_ret_avg:[51.630].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_50.npz] saved.
# [51/5000] n_env_step:[3.4e+06] rollout:[344.8]s update:[25.9]s r_avg:[-0.0231] avg_q:[0.023].
# [52/5000] n_env_step:[3.5e+06] rollout:[365.3]s update:[25.4]s r_avg:[-0.0251] avg_q:[0.023].
# [53/5000] n_env_step:[3.5e+06] rollout:[403.5]s update:[25.2]s r_avg:[-0.0268] avg_q:[0.023].
# [54/5000] n_env_step:[3.6e+06] rollout:[369.3]s update:[26.0]s r_avg:[-0.0291] avg_q:[0.023].
# [55/5000] n_env_step:[3.7e+06] rollout:[372.1]s update:[26.0]s r_avg:[-0.0238] avg_q:[0.023].
# [Eval. start] step:[55/5000][1.1%] #step:[3.7e+06] time:[day:[01] 06:38:35] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[0.3709] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.5883] ep_len:[1347]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0944] ep_len:[1022]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[8.6988] ep_len:[1500]. blue health:[1.00] red health:[0.92]
#  [4/20] [expert_system] ep_ret:[-100.3896] ep_len:[444]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0340] ep_len:[832]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.4600] ep_len:[1075]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[99.9925] ep_len:[859]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.1034] ep_len:[260]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-100.5403] ep_len:[801]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[100.0526] ep_len:[1391]. blue health:[1.00] red health:[0.00]
#  [11/20] [rosie] ep_ret:[100.1171] ep_len:[993]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.2253] ep_len:[212]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[0.3453] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-100.1721] ep_len:[352]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[0.2095] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.5050] ep_len:[564]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[0.1130] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[100.2117] ep_len:[309]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-100.1111] ep_len:[251]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 06:40:48] ep_ret_avg:[30.542].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_55.npz] saved.
# [56/5000] n_env_step:[3.7e+06] rollout:[376.4]s update:[29.0]s r_avg:[-0.0270] avg_q:[0.023].
# [57/5000] n_env_step:[3.8e+06] rollout:[330.7]s update:[29.2]s r_avg:[-0.0266] avg_q:[0.023].
# [58/5000] n_env_step:[3.9e+06] rollout:[311.5]s update:[26.6]s r_avg:[-0.0224] avg_q:[0.023].
# [59/5000] n_env_step:[3.9e+06] rollout:[377.2]s update:[32.0]s r_avg:[-0.0240] avg_q:[0.022].
# [60/5000] n_env_step:[4.0e+06] rollout:[376.7]s update:[26.2]s r_avg:[-0.0222] avg_q:[0.022].
# [Eval. start] step:[60/5000][1.2%] #step:[4.0e+06] time:[day:[01] 07:12:44] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[-0.0033] ep_len:[1032]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.3573] ep_len:[710]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0739] ep_len:[780]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1325] ep_len:[300]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-61.0011] ep_len:[1500]. blue health:[0.26] red health:[0.86]
#  [5/20] [zombie] ep_ret:[100.1067] ep_len:[196]. blue health:[1.00] red health:[0.00]
#  [6/20] [rosie] ep_ret:[100.1025] ep_len:[1070]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.2488] ep_len:[1040]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.0349] ep_len:[89]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[7.5631] ep_len:[1500]. blue health:[0.53] red health:[0.45]
#  [10/20] [zombie] ep_ret:[-0.0228] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.3358] ep_len:[299]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.2095] ep_len:[1096]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.2362] ep_len:[612]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[37.4778] ep_len:[1500]. blue health:[0.74] red health:[0.36]
#  [15/20] [zombie] ep_ret:[0.0123] ep_len:[1299]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.1629] ep_len:[1052]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.1046] ep_len:[995]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[0.0791] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [19/20] [expert_system] ep_ret:[51.3875] ep_len:[1500]. blue health:[1.00] red health:[0.49]
# [Eval. done] time:[day:[01] 07:15:30] ep_ret_avg:[61.880].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_60.npz] saved.
# [61/5000] n_env_step:[4.1e+06] rollout:[379.9]s update:[24.3]s r_avg:[-0.0265] avg_q:[0.023].
# [62/5000] n_env_step:[4.1e+06] rollout:[362.2]s update:[24.0]s r_avg:[-0.0224] avg_q:[0.022].
# [63/5000] n_env_step:[4.2e+06] rollout:[411.2]s update:[24.9]s r_avg:[-0.0200] avg_q:[0.022].
# [64/5000] n_env_step:[4.3e+06] rollout:[395.0]s update:[26.3]s r_avg:[-0.0266] avg_q:[0.022].
# [65/5000] n_env_step:[4.3e+06] rollout:[331.9]s update:[27.8]s r_avg:[-0.0236] avg_q:[0.022].
# [Eval. start] step:[65/5000][1.3%] #step:[4.3e+06] time:[day:[01] 07:48:58] ram:[21.2%].
#  [0/20] [zombie] ep_ret:[-0.0193] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.4103] ep_len:[696]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0161] ep_len:[1186]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.5063] ep_len:[718]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[-100.2999] ep_len:[550]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0396] ep_len:[1298]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.1335] ep_len:[1030]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.1570] ep_len:[1117]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.1049] ep_len:[168]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-100.1227] ep_len:[597]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[0.3529] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.4001] ep_len:[563]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.1089] ep_len:[674]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.2303] ep_len:[507]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-100.1248] ep_len:[123]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.0605] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.1758] ep_len:[968]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0880] ep_len:[1204]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.0896] ep_len:[257]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[13.6539] ep_len:[1500]. blue health:[0.85] red health:[0.71]
# [Eval. done] time:[day:[01] 07:51:35] ep_ret_avg:[40.637].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_65.npz] saved.
# [66/5000] n_env_step:[4.4e+06] rollout:[341.8]s update:[28.1]s r_avg:[-0.0262] avg_q:[0.022].
# [67/5000] n_env_step:[4.5e+06] rollout:[385.4]s update:[29.3]s r_avg:[-0.0280] avg_q:[0.022].
# [68/5000] n_env_step:[4.5e+06] rollout:[365.9]s update:[27.5]s r_avg:[-0.0269] avg_q:[0.022].
# [69/5000] n_env_step:[4.6e+06] rollout:[398.4]s update:[27.4]s r_avg:[-0.0252] avg_q:[0.022].
# [70/5000] n_env_step:[4.7e+06] rollout:[332.4]s update:[23.6]s r_avg:[-0.0237] avg_q:[0.022].
# [Eval. start] step:[70/5000][1.4%] #step:[4.7e+06] time:[day:[01] 08:24:15] ram:[21.3%].
#  [0/20] [zombie] ep_ret:[0.0747] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.1752] ep_len:[986]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.1242] ep_len:[988]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1040] ep_len:[133]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.1683] ep_len:[218]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0456] ep_len:[1278]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.5088] ep_len:[1149]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.1680] ep_len:[739]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[65.0774] ep_len:[1500]. blue health:[1.00] red health:[0.35]
#  [9/20] [expert_system] ep_ret:[-21.0182] ep_len:[1451]. blue health:[0.00] red health:[0.21]
#  [10/20] [zombie] ep_ret:[100.4074] ep_len:[643]. blue health:[1.00] red health:[0.00]
#  [11/20] [rosie] ep_ret:[100.3981] ep_len:[422]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.0332] ep_len:[1148]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.2284] ep_len:[507]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-76.3733] ep_len:[1439]. blue health:[0.00] red health:[0.76]
#  [15/20] [zombie] ep_ret:[0.1866] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.8321] ep_len:[1204]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0767] ep_len:[1162]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.2535] ep_len:[496]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-17.0770] ep_len:[639]. blue health:[0.00] red health:[0.17]
# [Eval. done] time:[day:[01] 08:27:02] ep_ret_avg:[52.698].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_70.npz] saved.
# [71/5000] n_env_step:[4.7e+06] rollout:[404.6]s update:[25.8]s r_avg:[-0.0251] avg_q:[0.022].
# [72/5000] n_env_step:[4.8e+06] rollout:[381.9]s update:[29.0]s r_avg:[-0.0300] avg_q:[0.022].
# [73/5000] n_env_step:[4.9e+06] rollout:[399.7]s update:[27.2]s r_avg:[-0.0181] avg_q:[0.022].
# [74/5000] n_env_step:[4.9e+06] rollout:[413.3]s update:[27.8]s r_avg:[-0.0260] avg_q:[0.022].
# [75/5000] n_env_step:[5.0e+06] rollout:[334.2]s update:[31.4]s r_avg:[-0.0252] avg_q:[0.022].
# [Eval. start] step:[75/5000][1.5%] #step:[5.0e+06] time:[day:[01] 09:01:37] ram:[20.0%].
#  [0/20] [zombie] ep_ret:[100.1962] ep_len:[446]. blue health:[1.00] red health:[0.00]
#  [1/20] [rosie] ep_ret:[100.1654] ep_len:[1016]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.1505] ep_len:[176]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1973] ep_len:[1348]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.2730] ep_len:[846]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0400] ep_len:[1002]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.3732] ep_len:[634]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0914] ep_len:[1080]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.2394] ep_len:[326]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[24.8947] ep_len:[1500]. blue health:[0.92] red health:[0.67]
#  [10/20] [zombie] ep_ret:[-2.5263] ep_len:[987]. blue health:[0.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.1270] ep_len:[993]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.1115] ep_len:[980]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[0.3210] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [14/20] [expert_system] ep_ret:[-65.3115] ep_len:[779]. blue health:[0.00] red health:[0.65]
#  [15/20] [zombie] ep_ret:[-0.0662] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.7072] ep_len:[615]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.1079] ep_len:[730]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.1171] ep_len:[244]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[62.4483] ep_len:[1500]. blue health:[1.00] red health:[0.38]
# [Eval. done] time:[day:[01] 09:04:18] ep_ret_avg:[56.102].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_75.npz] saved.
# [76/5000] n_env_step:[5.1e+06] rollout:[372.1]s update:[25.4]s r_avg:[-0.0264] avg_q:[0.022].
# [77/5000] n_env_step:[5.1e+06] rollout:[371.5]s update:[29.1]s r_avg:[-0.0242] avg_q:[0.022].
# [78/5000] n_env_step:[5.2e+06] rollout:[343.8]s update:[29.3]s r_avg:[-0.0299] avg_q:[0.022].
# [79/5000] n_env_step:[5.3e+06] rollout:[344.5]s update:[34.3]s r_avg:[-0.0238] avg_q:[0.022].
# [80/5000] n_env_step:[5.3e+06] rollout:[361.4]s update:[29.6]s r_avg:[-0.0306] avg_q:[0.022].
# [Eval. start] step:[80/5000][1.6%] #step:[5.3e+06] time:[day:[01] 09:36:39] ram:[20.6%].
#  [0/20] [zombie] ep_ret:[0.0296] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.1368] ep_len:[1002]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.0793] ep_len:[140]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1769] ep_len:[316]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.1261] ep_len:[148]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[0.4391] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.3503] ep_len:[1137]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0718] ep_len:[92]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.2158] ep_len:[402]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[100.1612] ep_len:[237]. blue health:[1.00] red health:[0.00]
#  [10/20] [zombie] ep_ret:[-0.0551] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.4030] ep_len:[684]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.0896] ep_len:[571]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1404] ep_len:[240]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-63.5377] ep_len:[1500]. blue health:[0.34] red health:[0.97]
#  [15/20] [zombie] ep_ret:[0.1901] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.4021] ep_len:[422]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0966] ep_len:[415]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.2323] ep_len:[494]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[25.7207] ep_len:[1500]. blue health:[1.00] red health:[0.75]
# [Eval. done] time:[day:[01] 09:39:28] ep_ret_avg:[58.261].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_80.npz] saved.
# [81/5000] n_env_step:[5.4e+06] rollout:[368.9]s update:[28.2]s r_avg:[-0.0288] avg_q:[0.021].
# [82/5000] n_env_step:[5.5e+06] rollout:[365.8]s update:[29.2]s r_avg:[-0.0239] avg_q:[0.021].
# [83/5000] n_env_step:[5.5e+06] rollout:[354.8]s update:[25.6]s r_avg:[-0.0234] avg_q:[0.022].
# [84/5000] n_env_step:[5.6e+06] rollout:[389.1]s update:[30.3]s r_avg:[-0.0203] avg_q:[0.022].
# [85/5000] n_env_step:[5.7e+06] rollout:[384.9]s update:[29.5]s r_avg:[-0.0235] avg_q:[0.021].
# [Eval. start] step:[85/5000][1.7%] #step:[5.7e+06] time:[day:[01] 10:12:55] ram:[20.7%].
#  [0/20] [zombie] ep_ret:[100.2009] ep_len:[314]. blue health:[1.00] red health:[0.00]
#  [1/20] [rosie] ep_ret:[100.1237] ep_len:[1043]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.1372] ep_len:[894]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.3583] ep_len:[815]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[65.9635] ep_len:[1500]. blue health:[1.00] red health:[0.34]
#  [5/20] [zombie] ep_ret:[-0.0444] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.1565] ep_len:[1030]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0780] ep_len:[101]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.3364] ep_len:[695]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-100.2158] ep_len:[358]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[0.0076] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.5816] ep_len:[1138]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.1541] ep_len:[1459]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1662] ep_len:[248]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-101.1633] ep_len:[1461]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[-0.0446] ep_len:[889]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.3170] ep_len:[549]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0705] ep_len:[900]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.1134] ep_len:[156]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-30.4905] ep_len:[1500]. blue health:[0.71] red health:[1.00]
# [Eval. done] time:[day:[01] 10:15:45] ep_ret_avg:[51.704].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_85.npz] saved.
# [86/5000] n_env_step:[5.7e+06] rollout:[355.1]s update:[26.4]s r_avg:[-0.0255] avg_q:[0.021].
# [87/5000] n_env_step:[5.8e+06] rollout:[324.9]s update:[28.5]s r_avg:[-0.0214] avg_q:[0.021].
# [88/5000] n_env_step:[5.9e+06] rollout:[320.5]s update:[33.7]s r_avg:[-0.0263] avg_q:[0.021].
# [89/5000] n_env_step:[5.9e+06] rollout:[386.5]s update:[34.2]s r_avg:[-0.0253] avg_q:[0.021].
# [90/5000] n_env_step:[6.0e+06] rollout:[367.9]s update:[29.4]s r_avg:[-0.0195] avg_q:[0.021].
# [Eval. start] step:[90/5000][1.8%] #step:[6.0e+06] time:[day:[01] 10:47:33] ram:[21.0%].
#  [0/20] [zombie] ep_ret:[0.2244] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.3498] ep_len:[529]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.4190] ep_len:[855]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1212] ep_len:[182]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-91.6948] ep_len:[705]. blue health:[0.00] red health:[0.91]
#  [5/20] [zombie] ep_ret:[1.0752] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.1349] ep_len:[922]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.1357] ep_len:[1093]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.1072] ep_len:[109]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[100.0574] ep_len:[199]. blue health:[1.00] red health:[0.00]
#  [10/20] [zombie] ep_ret:[4.1380] ep_len:[1500]. blue health:[1.00] red health:[0.96]
#  [11/20] [rosie] ep_ret:[100.2803] ep_len:[711]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[99.9638] ep_len:[1271]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1839] ep_len:[227]. blue health:[1.00] red health:[0.00]
# ...
#  [7/20] [bud] ep_ret:[100.0918] ep_len:[855]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.2530] ep_len:[460]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-76.0456] ep_len:[860]. blue health:[0.00] red health:[0.76]
#  [10/20] [zombie] ep_ret:[0.1242] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.4536] ep_len:[577]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[71.7292] ep_len:[1500]. blue health:[1.00] red health:[0.28]
#  [13/20] [bud_fsm] ep_ret:[100.2454] ep_len:[479]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-100.6606] ep_len:[1101]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[100.1805] ep_len:[147]. blue health:[1.00] red health:[0.00]
#  [16/20] [rosie] ep_ret:[100.3102] ep_len:[511]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[0.3483] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[100.2044] ep_len:[424]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[83.3410] ep_len:[541]. blue health:[0.83] red health:[0.00]
# [Eval. done] time:[day:[01] 20:43:31] ep_ret_avg:[59.117].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_170.npz] saved.
# [171/5000] n_env_step:[1.1e+07] rollout:[417.3]s update:[28.2]s r_avg:[-0.0232] avg_q:[0.020].
# [172/5000] n_env_step:[1.1e+07] rollout:[386.6]s update:[29.7]s r_avg:[-0.0247] avg_q:[0.020].
# [173/5000] n_env_step:[1.2e+07] rollout:[417.4]s update:[29.6]s r_avg:[-0.0195] avg_q:[0.020].
# [174/5000] n_env_step:[1.2e+07] rollout:[442.6]s update:[33.5]s r_avg:[-0.0214] avg_q:[0.020].
# [175/5000] n_env_step:[1.2e+07] rollout:[402.2]s update:[25.4]s r_avg:[-0.0266] avg_q:[0.019].
# [Eval. start] step:[175/5000][3.5%] #step:[1.2e+07] time:[day:[01] 21:20:24] ram:[21.6%].
#  [0/20] [zombie] ep_ret:[0.0627] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.5989] ep_len:[504]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.1785] ep_len:[1390]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1433] ep_len:[272]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.1794] ep_len:[464]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[0.0902] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.4396] ep_len:[1246]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.1099] ep_len:[1154]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.3129] ep_len:[510]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-93.6043] ep_len:[966]. blue health:[0.00] red health:[0.93]
#  [10/20] [zombie] ep_ret:[0.2157] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.4650] ep_len:[777]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[0.0760] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [13/20] [bud_fsm] ep_ret:[100.1910] ep_len:[395]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-78.9977] ep_len:[1500]. blue health:[0.21] red health:[1.00]
#  [15/20] [zombie] ep_ret:[0.1493] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.8298] ep_len:[1016]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.1091] ep_len:[939]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.0838] ep_len:[146]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-68.8626] ep_len:[459]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[01] 21:23:17] ep_ret_avg:[38.121].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_175.npz] saved.
# [176/5000] n_env_step:[1.2e+07] rollout:[385.0]s update:[24.6]s r_avg:[-0.0264] avg_q:[0.019].
# [177/5000] n_env_step:[1.2e+07] rollout:[388.8]s update:[28.2]s r_avg:[-0.0221] avg_q:[0.019].
# [178/5000] n_env_step:[1.2e+07] rollout:[371.7]s update:[27.7]s r_avg:[-0.0264] avg_q:[0.020].
# [179/5000] n_env_step:[1.2e+07] rollout:[404.9]s update:[25.4]s r_avg:[-0.0249] avg_q:[0.019].
# [180/5000] n_env_step:[1.2e+07] rollout:[363.1]s update:[28.9]s r_avg:[-0.0266] avg_q:[0.019].
# [Eval. start] step:[180/5000][3.6%] #step:[1.2e+07] time:[day:[01] 21:57:26] ram:[21.6%].
#  [0/20] [zombie] ep_ret:[-0.0111] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[32.8184] ep_len:[1500]. blue health:[1.00] red health:[0.68]
#  [2/20] [bud] ep_ret:[100.1833] ep_len:[1392]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1400] ep_len:[362]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.5141] ep_len:[714]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[101.0096] ep_len:[1109]. blue health:[1.00] red health:[0.00]
#  [6/20] [rosie] ep_ret:[100.2999] ep_len:[630]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0105] ep_len:[1178]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[-2.4355] ep_len:[573]. blue health:[0.00] red health:[1.00]
#  [9/20] [expert_system] ep_ret:[-100.2237] ep_len:[397]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[19.2626] ep_len:[1500]. blue health:[1.00] red health:[0.81]
#  [11/20] [rosie] ep_ret:[100.6229] ep_len:[695]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[16.7270] ep_len:[1500]. blue health:[0.99] red health:[0.83]
#  [13/20] [bud_fsm] ep_ret:[100.2206] ep_len:[367]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-100.3200] ep_len:[1222]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[0.1884] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.4288] ep_len:[404]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[99.9702] ep_len:[1138]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.1062] ep_len:[145]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-80.4206] ep_len:[1050]. blue health:[0.00] red health:[0.80]
# [Eval. done] time:[day:[01] 21:59:53] ep_ret_avg:[34.403].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_180.npz] saved.
# [181/5000] n_env_step:[1.2e+07] rollout:[367.6]s update:[26.7]s r_avg:[-0.0255] avg_q:[0.019].
# [182/5000] n_env_step:[1.2e+07] rollout:[412.4]s update:[28.7]s r_avg:[-0.0251] avg_q:[0.019].
# [183/5000] n_env_step:[1.2e+07] rollout:[365.0]s update:[29.6]s r_avg:[-0.0205] avg_q:[0.019].
# [184/5000] n_env_step:[1.2e+07] rollout:[464.6]s update:[29.8]s r_avg:[-0.0244] avg_q:[0.019].
# [185/5000] n_env_step:[1.2e+07] rollout:[414.2]s update:[28.2]s r_avg:[-0.0257] avg_q:[0.019].
# [Eval. start] step:[185/5000][3.7%] #step:[1.2e+07] time:[day:[01] 22:36:00] ram:[21.7%].
#  [0/20] [zombie] ep_ret:[0.1695] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.3177] ep_len:[663]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[99.9723] ep_len:[926]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.1676] ep_len:[214]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[-100.1056] ep_len:[338]. blue health:[0.00] red health:[1.00]
#  [5/20] [zombie] ep_ret:[-0.0100] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[-14.1161] ep_len:[1500]. blue health:[0.84] red health:[0.98]
#  [7/20] [bud] ep_ret:[99.9995] ep_len:[646]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[9.0503] ep_len:[1500]. blue health:[1.00] red health:[0.91]
#  [9/20] [expert_system] ep_ret:[-0.1644] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[100.1725] ep_len:[170]. blue health:[1.00] red health:[0.00]
#  [11/20] [rosie] ep_ret:[100.3970] ep_len:[740]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.1347] ep_len:[267]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.2403] ep_len:[410]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-100.0934] ep_len:[560]. blue health:[0.00] red health:[1.00]
#  [15/20] [zombie] ep_ret:[100.3089] ep_len:[275]. blue health:[1.00] red health:[0.00]
#  [16/20] [rosie] ep_ret:[100.4948] ep_len:[647]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.0988] ep_len:[1286]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.1172] ep_len:[169]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[27.6928] ep_len:[1500]. blue health:[1.00] red health:[0.73]
# [Eval. done] time:[day:[01] 22:38:43] ep_ret_avg:[51.242].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_185.npz] saved.
# [186/5000] n_env_step:[1.2e+07] rollout:[430.9]s update:[31.8]s r_avg:[-0.0189] avg_q:[0.019].
# [187/5000] n_env_step:[1.2e+07] rollout:[453.0]s update:[25.6]s r_avg:[-0.0171] avg_q:[0.019].
# [188/5000] n_env_step:[1.3e+07] rollout:[419.6]s update:[27.7]s r_avg:[-0.0261] avg_q:[0.019].
# [189/5000] n_env_step:[1.3e+07] rollout:[352.3]s update:[33.5]s r_avg:[-0.0220] avg_q:[0.019].
# [190/5000] n_env_step:[1.3e+07] rollout:[386.9]s update:[31.2]s r_avg:[-0.0246] avg_q:[0.019].
# [Eval. start] step:[190/5000][3.8%] #step:[1.3e+07] time:[day:[01] 23:15:15] ram:[21.7%].
#  [0/20] [zombie] ep_ret:[-0.0785] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.1360] ep_len:[1098]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.1278] ep_len:[880]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.3564] ep_len:[705]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[15.2215] ep_len:[1500]. blue health:[0.87] red health:[0.72]
#  [5/20] [zombie] ep_ret:[-0.0250] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [6/20] [rosie] ep_ret:[100.1225] ep_len:[1089]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0714] ep_len:[938]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.1174] ep_len:[188]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-57.7092] ep_len:[1500]. blue health:[0.08] red health:[0.65]
#  [10/20] [zombie] ep_ret:[-0.0374] ep_len:[631]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.3232] ep_len:[741]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[0.0480] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [13/20] [bud_fsm] ep_ret:[100.0577] ep_len:[82]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-68.9858] ep_len:[808]. blue health:[0.00] red health:[0.69]
#  [15/20] [zombie] ep_ret:[0.0040] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.3656] ep_len:[507]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[100.1150] ep_len:[412]. blue health:[1.00] red health:[0.00]
#  [18/20] [bud_fsm] ep_ret:[100.0896] ep_len:[133]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-94.1705] ep_len:[678]. blue health:[0.00] red health:[0.94]
# [Eval. done] time:[day:[01] 23:18:15] ep_ret_avg:[44.807].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_190.npz] saved.
# [191/5000] n_env_step:[1.3e+07] rollout:[407.2]s update:[28.5]s r_avg:[-0.0235] avg_q:[0.019].
# [192/5000] n_env_step:[1.3e+07] rollout:[409.3]s update:[29.3]s r_avg:[-0.0236] avg_q:[0.019].
# [193/5000] n_env_step:[1.3e+07] rollout:[366.2]s update:[27.4]s r_avg:[-0.0237] avg_q:[0.019].
# [194/5000] n_env_step:[1.3e+07] rollout:[403.1]s update:[26.2]s r_avg:[-0.0260] avg_q:[0.019].
# [195/5000] n_env_step:[1.3e+07] rollout:[416.9]s update:[25.9]s r_avg:[-0.0276] avg_q:[0.019].
# [Eval. start] step:[195/5000][3.9%] #step:[1.3e+07] time:[day:[01] 23:53:55] ram:[21.7%].
#  [0/20] [zombie] ep_ret:[0.5321] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.4163] ep_len:[724]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.1324] ep_len:[598]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[-2.4793] ep_len:[1178]. blue health:[0.00] red health:[1.00]
#  [4/20] [expert_system] ep_ret:[92.3077] ep_len:[76]. blue health:[0.92] red health:[0.00]
#  [5/20] [zombie] ep_ret:[1.2036] ep_len:[1500]. blue health:[1.00] red health:[0.99]
#  [6/20] [rosie] ep_ret:[100.8091] ep_len:[1340]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[100.0464] ep_len:[1272]. blue health:[1.00] red health:[0.00]
#  [8/20] [bud_fsm] ep_ret:[100.0825] ep_len:[135]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-59.3968] ep_len:[1500]. blue health:[0.28] red health:[0.88]
#  [10/20] [zombie] ep_ret:[0.1719] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.2807] ep_len:[613]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.1765] ep_len:[922]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.1644] ep_len:[163]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[29.8717] ep_len:[1500]. blue health:[0.92] red health:[0.62]
#  [15/20] [zombie] ep_ret:[0.0114] ep_len:[812]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[100.2031] ep_len:[941]. blue health:[1.00] red health:[0.00]
#  [17/20] [bud] ep_ret:[2.0582] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [18/20] [bud_fsm] ep_ret:[100.1947] ep_len:[291]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[77.5964] ep_len:[1500]. blue health:[1.00] red health:[0.23]
# [Eval. done] time:[day:[01] 23:56:51] ep_ret_avg:[57.219].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_195.npz] saved.
# [196/5000] n_env_step:[1.3e+07] rollout:[404.6]s update:[28.6]s r_avg:[-0.0224] avg_q:[0.019].
# [197/5000] n_env_step:[1.3e+07] rollout:[348.6]s update:[24.5]s r_avg:[-0.0275] avg_q:[0.019].
# [198/5000] n_env_step:[1.3e+07] rollout:[401.2]s update:[29.5]s r_avg:[-0.0252] avg_q:[0.019].
# [199/5000] n_env_step:[1.3e+07] rollout:[377.1]s update:[26.4]s r_avg:[-0.0238] avg_q:[0.019].
# [200/5000] n_env_step:[1.3e+07] rollout:[338.3]s update:[26.6]s r_avg:[-0.0227] avg_q:[0.019].
# [Eval. start] step:[200/5000][4.0%] #step:[1.3e+07] time:[day:[02] 00:30:17] ram:[21.7%].
#  [0/20] [zombie] ep_ret:[0.1730] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [1/20] [rosie] ep_ret:[100.4601] ep_len:[555]. blue health:[1.00] red health:[0.00]
#  [2/20] [bud] ep_ret:[100.1059] ep_len:[849]. blue health:[1.00] red health:[0.00]
#  [3/20] [bud_fsm] ep_ret:[100.0517] ep_len:[81]. blue health:[1.00] red health:[0.00]
#  [4/20] [expert_system] ep_ret:[24.9664] ep_len:[1500]. blue health:[1.00] red health:[0.75]
#  [5/20] [zombie] ep_ret:[28.2042] ep_len:[1500]. blue health:[1.00] red health:[0.73]
#  [6/20] [rosie] ep_ret:[100.3109] ep_len:[294]. blue health:[1.00] red health:[0.00]
#  [7/20] [bud] ep_ret:[30.2752] ep_len:[1500]. blue health:[1.00] red health:[0.72]
#  [8/20] [bud_fsm] ep_ret:[100.3341] ep_len:[402]. blue health:[1.00] red health:[0.00]
#  [9/20] [expert_system] ep_ret:[-100.2321] ep_len:[692]. blue health:[0.00] red health:[1.00]
#  [10/20] [zombie] ep_ret:[0.1741] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [11/20] [rosie] ep_ret:[100.6652] ep_len:[500]. blue health:[1.00] red health:[0.00]
#  [12/20] [bud] ep_ret:[100.0954] ep_len:[1359]. blue health:[1.00] red health:[0.00]
#  [13/20] [bud_fsm] ep_ret:[100.3126] ep_len:[648]. blue health:[1.00] red health:[0.00]
#  [14/20] [expert_system] ep_ret:[-75.0270] ep_len:[686]. blue health:[0.00] red health:[0.75]
#  [15/20] [zombie] ep_ret:[0.8780] ep_len:[1500]. blue health:[1.00] red health:[1.00]
#  [16/20] [rosie] ep_ret:[33.2201] ep_len:[1500]. blue health:[1.00] red health:[0.67]
#  [17/20] [bud] ep_ret:[23.3106] ep_len:[1500]. blue health:[1.00] red health:[0.77]
#  [18/20] [bud_fsm] ep_ret:[100.1356] ep_len:[252]. blue health:[1.00] red health:[0.00]
#  [19/20] [expert_system] ep_ret:[-100.1517] ep_len:[931]. blue health:[0.00] red health:[1.00]
# [Eval. done] time:[day:[02] 00:33:28] ep_ret_avg:[38.413].
#
# [../report/net/sac_adt_cont_04/model_and_buffers_200.npz] saved.
# [201/5000] n_env_step:[1.3e+07] rollout:[397.3]s update:[29.7]s r_avg:[-0.0237] avg_q:[0.019].
