# %% [markdown]
# # Synchronous PPO with PyBullet Ant

# %%
import datetime,gym,os,pybullet_envs,time,os,psutil,ray
import numpy as np
import tensorflow as tf
from util import gpu_sess,suppress_tf_warning
from ppo import PPOBuffer,create_ppo_model,create_ppo_graph,update_ppo
np.set_printoptions(precision=2)
suppress_tf_warning() # suppress warning 
gym.logger.set_level(40) # gym logger 
print ("Packaged loaded. TF version is [%s]."%(tf.__version__))
# Out:
# Packaged loaded. TF version is [1.14.0].

# %% [markdown]
# ### Rollout Worker

# %%
def get_env():
    import pybullet_envs,gym
    gym.logger.set_level(40) # gym logger 
    return gym.make('AntBulletEnv-v0')

def get_eval_env():
    import pybullet_envs,gym
    gym.logger.set_level(40) # gym logger
    eval_env = gym.make('AntBulletEnv-v0')
    _ = eval_env.render(mode='human') # enable rendering
    _ = eval_env.reset()
    for _ in range(3): # dummy run for proper rendering 
        a = eval_env.action_space.sample()
        o,r,d,_ = eval_env.step(a)
        time.sleep(0.01)
    return eval_env

# %%
# Model
hdims = [256,256]
# Graph
clip_ratio = 0.2
pi_lr = 3e-4
vf_lr = 1e-3
# Buffer
steps_per_epoch = 5000
gamma = 0.99
lam = 0.95
# Update
train_pi_iters = 100
train_v_iters = 100
target_kl = 0.01
epochs = 1000
max_ep_len = 1000

# %%
class RolloutWorkerClass(object):
    """
    Worker without RAY (for update purposes)
    """
    def __init__(self,seed=1):
        self.seed = seed
        # Each worker should maintain its own environment
        import pybullet_envs,gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) # gym logger 
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        # Initialize PPO
        self.model,self.sess = create_ppo_model(env=self.env,hdims=hdims)
        self.graph = create_ppo_graph(self.model,
                                      clip_ratio=clip_ratio,pi_lr=pi_lr,vf_lr=vf_lr)
        # Initialize model 
        tf.set_random_seed(self.seed)
        np.random.seed(self.seed)
        self.sess.run(tf.global_variables_initializer())
        
    def get_action(self,o,deterministic=False):
        act_op = self.model['mu'] if deterministic else self.model['pi']
        return self.sess.run(act_op, feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
    
    def get_weights(self):
        """
        Get weights
        """
        weight_vals = self.sess.run(self.model['pi_vars']+self.model['v_vars'])
        return weight_vals
    
@ray.remote
class RayRolloutWorkerClass(object):
    """
    Rollout Worker with RAY
    """
    def __init__(self,worker_id=0,ep_len_rollout=1000):
        # Parse
        self.worker_id = worker_id
        self.ep_len_rollout = ep_len_rollout
        # Each worker should maintain its own environment
        import pybullet_envs,gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) # gym logger 
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        # Replay buffers to pass
        self.o_buffer = np.zeros((self.ep_len_rollout,self.odim))
        self.a_buffer = np.zeros((self.ep_len_rollout,self.adim))
        self.r_buffer = np.zeros((self.ep_len_rollout))
        self.v_t_buffer = np.zeros((self.ep_len_rollout))
        self.logp_t_buffer = np.zeros((self.ep_len_rollout))
        # Create PPO model
        self.model,self.sess = create_ppo_model(env=self.env,hdims=hdims)
        # Initialize model 
        self.sess.run(tf.global_variables_initializer())
        # Buffer
        self.buf = PPOBuffer(odim=self.odim,adim=self.adim,
                             size=ep_len_rollout,gamma=gamma,lam=lam)
        
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True
        
        # Flag to initialize rollout
        self.FIRST_ROLLOUT_FLAG = True
        
    def get_action(self,o,deterministic=False):
        act_op = self.model['mu'] if deterministic else self.model['pi']
        return self.sess.run(act_op, feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
    
    def set_weights(self,weight_vals):
        """
        Set weights without memory leakage
        """
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['pi_vars']+self.model['v_vars']):
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['pi_vars']+self.model['v_vars']):
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:weight_vals[w_idx]})    
        
    def rollout(self):
        """
        Rollout
        """
        if self.FIRST_ROLLOUT_FLAG:
            self.FIRST_ROLLOUT_FLAG = False
            self.o = self.env.reset() # reset environment
        # Loop
        for t in range(ep_len_rollout):
            a,v_t,logp_t = self.sess.run(
                self.model['get_action_ops'],feed_dict={self.model['o_ph']:self.o.reshape(1,-1)})
            o2, r, d, _ = self.env.step(a[0])
            # save and log
            self.buf.store(self.o,a,r,v_t,logp_t)
            # Update obs (critical!)
            self.o = o2
            if d:
                self.buf.finish_path(last_val=0.0)
                self.o = self.env.reset() # reset when done 
        
        last_val = self.sess.run(self.model['v'],
                                 feed_dict={self.model['o_ph']:self.o.reshape(1,-1)})
        self.buf.finish_path(last_val)
        return self.buf.get()

# %% [markdown]
# ### Initialize PyBullet Ant Environment

# %%
eval_env = get_eval_env()
adim,odim = eval_env.action_space.shape[0],eval_env.observation_space.shape[0]
print ("Environment Ready. odim:[%d] adim:[%d]."%(odim,adim))
# Out:
# Environment Ready. odim:[28] adim:[8].

# %%
n_cpu = n_workers = 15
total_steps,evaluate_every,print_every = 300,5,1
ep_len_rollout = 5000
batch_size,update_count = 128,ep_len_rollout
num_eval,max_ep_len_eval = 3,1e3
buffer_size_long,buffer_size_short = 1e6,1e5

# %% [markdown]
# ### Initialize Workers

# %%
ray.init(num_cpus=n_cpu,
         memory = 5*1024*1024*1024,
         object_store_memory = 10*1024*1024*1024,
         driver_object_store_memory = 1*1024*1024*1024)
tf.reset_default_graph()
R = RolloutWorkerClass(seed=0)
workers = [RayRolloutWorkerClass.remote(worker_id=i,ep_len_rollout=ep_len_rollout) 
           for i in range(n_workers)]
print ("RAY initialized with [%d] cpus and [%d] workers."%
       (n_cpu,n_workers))
# Out:
# 2020-06-29 20:29:05,292	WARNING services.py:586 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-06-29 20:29:05,295	INFO resource_spec.py:212 -- Starting Ray with 4.98 GiB memory available for workers and up to 10.0 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-06-29 20:29:05,692	INFO services.py:1078 -- View the Ray dashboard at localhost:8266
# RAY initialized with [15] cpus and [15] workers.

# %%
time.sleep(1)

# %% [markdown]
# ### Loop

# %%
start_time = time.time()
n_env_step = 0 # number of environment steps
for t in range(int(total_steps)):
    esec = time.time()-start_time
    
    # Synchronize worker weights
    weights = R.get_weights()
    set_weights_list = [worker.set_weights.remote(weights) for worker in workers] 
    
    # Make rollout and accumulate to Buffers
    t_start = time.time()
    ops = [worker.rollout.remote() for worker in workers]
    rollout_vals = ray.get(ops)
    sec_rollout = time.time() - t_start
    
    # Get stats before update
    t_start = time.time()
    feeds_list = []
    for rollout_val in rollout_vals:
        feeds = {k:v for k,v in zip(R.model['all_phs'],rollout_val)}
        feeds_list.append(feeds)
        pi_l_old, v_l_old, ent = R.sess.run(
            [R.graph['pi_loss'],R.graph['v_loss'],R.graph['approx_ent']],feed_dict=feeds)
        
    # Update the central agent 
    for _ in range(train_pi_iters):
        for r_idx,rollout_val in enumerate(rollout_vals):
            feeds = feeds_list[r_idx]
            _, kl = R.sess.run([R.graph['train_pi'],R.graph['approx_kl']],feed_dict=feeds)
            if kl > 1.5 * target_kl:
                break
    for _ in range(train_v_iters):
        for r_idx,rollout_val in enumerate(rollout_vals):
            feeds = feeds_list[r_idx]
            R.sess.run(R.graph['train_v'],feed_dict=feeds)
    
    # Get stats after update
    for r_idx,rollout_val in enumerate(rollout_vals):
        feeds = feeds_list[r_idx]
        pi_l_new,v_l_new,kl,cf = R.sess.run(
            [R.graph['pi_loss'],R.graph['v_loss'],R.graph['approx_kl'],R.graph['clipfrac']],
            feed_dict=feeds)
    sec_update = time.time() - t_start
    
    # Print
    if (t == 0) or (((t+1)%print_every) == 0): 
        print ("[%d/%d] rollout:[%.1f]s update:[%.1f]s."%
               (t+1,total_steps,sec_rollout,sec_update))
        
    # Evaluate
    if (t==0) or (((t+1)%evaluate_every) == 0):
        ram_percent = psutil.virtual_memory().percent # memory usage
        print ("[Eval. start] step:[%d/%d][%.1f%%] #step:[%.1e] time:[%s] ram:[%.1f%%]."%
               (t+1,total_steps,t/total_steps*100,
                n_env_step,
                time.strftime("%H:%M:%S", time.gmtime(time.time()-start_time)),
                ram_percent)
              )
        o,d,ep_ret,ep_len = eval_env.reset(),False,0,0
        _ = eval_env.render(mode='human') 
        while not(d or (ep_len == max_ep_len)):
            a = R.sess.run(R.model['mu'],feed_dict={R.model['o_ph']:o.reshape(1,-1)})
            o,r,d,_ = eval_env.step(a[0])
            _ = eval_env.render(mode='human') 
            ep_ret += r # compute return 
            ep_len += 1
        print ("[Evaluate] ep_ret:[%.4f] ep_len:[%d]"%(ep_ret,ep_len))
    
print ("Done.")
# Out:
# [1/300] rollout:[11.8]s update:[7.4]s.
# [Eval. start] step:[1/300][0.0%] #step:[0.0e+00] time:[00:00:19] ram:[39.6%].
# [Evaluate] ep_ret:[598.3478] ep_len:[1000]
# [2/300] rollout:[9.7]s update:[7.1]s.
# [3/300] rollout:[9.6]s update:[6.1]s.
# [4/300] rollout:[9.6]s update:[5.4]s.
# [5/300] rollout:[9.6]s update:[7.1]s.
# [Eval. start] step:[5/300][1.3%] #step:[0.0e+00] time:[00:01:25] ram:[39.7%].
# [Evaluate] ep_ret:[671.6047] ep_len:[1000]
# [6/300] rollout:[9.5]s update:[5.0]s.
# [7/300] rollout:[9.5]s update:[4.7]s.
# [8/300] rollout:[9.5]s update:[7.0]s.
# [9/300] rollout:[9.5]s update:[4.2]s.
# [10/300] rollout:[9.5]s update:[5.3]s.
# [Eval. start] step:[10/300][3.0%] #step:[0.0e+00] time:[00:02:41] ram:[39.9%].
# [Evaluate] ep_ret:[620.9814] ep_len:[1000]
# [11/300] rollout:[9.5]s update:[4.5]s.
# [12/300] rollout:[9.5]s update:[6.1]s.
# [13/300] rollout:[9.5]s update:[4.8]s.
# [14/300] rollout:[9.5]s update:[4.5]s.
# [15/300] rollout:[9.5]s update:[5.4]s.
# [Eval. start] step:[15/300][4.7%] #step:[0.0e+00] time:[00:03:57] ram:[40.1%].
# [Evaluate] ep_ret:[685.1054] ep_len:[1000]
# [16/300] rollout:[9.5]s update:[4.4]s.
# [17/300] rollout:[9.5]s update:[3.6]s.
# [18/300] rollout:[9.5]s update:[4.2]s.
# [19/300] rollout:[9.4]s update:[4.7]s.
# [20/300] rollout:[9.4]s update:[6.3]s.
# [Eval. start] step:[20/300][6.3%] #step:[0.0e+00] time:[00:05:09] ram:[40.2%].
# [Evaluate] ep_ret:[923.2135] ep_len:[1000]
# [21/300] rollout:[9.4]s update:[4.5]s.
# [22/300] rollout:[9.4]s update:[4.9]s.
# [23/300] rollout:[9.5]s update:[4.0]s.
# [24/300] rollout:[9.4]s update:[5.0]s.
# [25/300] rollout:[9.5]s update:[4.3]s.
# [Eval. start] step:[25/300][8.0%] #step:[0.0e+00] time:[00:06:22] ram:[40.4%].
# [Evaluate] ep_ret:[660.5186] ep_len:[1000]
# [26/300] rollout:[9.4]s update:[4.7]s.
# [27/300] rollout:[9.5]s update:[3.4]s.
# [28/300] rollout:[9.4]s update:[4.1]s.
# [29/300] rollout:[9.4]s update:[4.3]s.
# [30/300] rollout:[9.4]s update:[4.0]s.
# [Eval. start] step:[30/300][9.7%] #step:[0.0e+00] time:[00:07:31] ram:[40.6%].
# [Evaluate] ep_ret:[921.3934] ep_len:[1000]
# [31/300] rollout:[9.3]s update:[4.7]s.
# [32/300] rollout:[9.4]s update:[5.1]s.
# [33/300] rollout:[9.4]s update:[4.5]s.
# [34/300] rollout:[9.4]s update:[4.3]s.
# [35/300] rollout:[9.4]s update:[4.0]s.
# [Eval. start] step:[35/300][11.3%] #step:[0.0e+00] time:[00:08:43] ram:[40.8%].
# [Evaluate] ep_ret:[1110.6050] ep_len:[1000]
# [36/300] rollout:[9.4]s update:[4.6]s.
# [37/300] rollout:[9.4]s update:[3.8]s.
# [38/300] rollout:[9.4]s update:[4.0]s.
# [39/300] rollout:[9.4]s update:[4.4]s.
# [40/300] rollout:[9.4]s update:[4.6]s.
# [Eval. start] step:[40/300][13.0%] #step:[0.0e+00] time:[00:09:53] ram:[40.9%].
# [Evaluate] ep_ret:[771.1365] ep_len:[1000]
# [41/300] rollout:[9.4]s update:[4.5]s.
# [42/300] rollout:[9.4]s update:[4.8]s.
# [43/300] rollout:[9.4]s update:[4.9]s.
# [44/300] rollout:[9.3]s update:[4.0]s.
# [45/300] rollout:[9.4]s update:[4.5]s.
# [Eval. start] step:[45/300][14.7%] #step:[0.0e+00] time:[00:11:05] ram:[41.1%].
# [Evaluate] ep_ret:[1169.9309] ep_len:[1000]
# [46/300] rollout:[9.3]s update:[4.2]s.
# [47/300] rollout:[9.4]s update:[4.0]s.
# [48/300] rollout:[9.4]s update:[3.9]s.
# [49/300] rollout:[9.3]s update:[3.6]s.
# [50/300] rollout:[9.3]s update:[4.5]s.
# [Eval. start] step:[50/300][16.3%] #step:[0.0e+00] time:[00:12:15] ram:[41.3%].
# [Evaluate] ep_ret:[1285.8691] ep_len:[1000]
# [51/300] rollout:[9.4]s update:[4.5]s.
# [52/300] rollout:[9.3]s update:[4.8]s.
# [53/300] rollout:[9.3]s update:[4.8]s.
# [54/300] rollout:[9.3]s update:[4.4]s.
# [55/300] rollout:[9.4]s update:[4.0]s.
# [Eval. start] step:[55/300][18.0%] #step:[0.0e+00] time:[00:13:26] ram:[41.5%].
# [Evaluate] ep_ret:[1372.1382] ep_len:[1000]
# [56/300] rollout:[9.4]s update:[4.0]s.
# [57/300] rollout:[9.4]s update:[4.2]s.
# [58/300] rollout:[9.3]s update:[4.4]s.
# [59/300] rollout:[9.4]s update:[3.9]s.
# [60/300] rollout:[9.3]s update:[4.2]s.
# [Eval. start] step:[60/300][19.7%] #step:[0.0e+00] time:[00:14:36] ram:[41.7%].
# [Evaluate] ep_ret:[1316.2394] ep_len:[1000]
# [61/300] rollout:[9.4]s update:[3.8]s.
# [62/300] rollout:[9.4]s update:[4.1]s.
# [63/300] rollout:[9.3]s update:[3.7]s.
# [64/300] rollout:[9.3]s update:[3.8]s.
# [65/300] rollout:[9.4]s update:[3.9]s.
# [Eval. start] step:[65/300][21.3%] #step:[0.0e+00] time:[00:15:44] ram:[41.8%].
# [Evaluate] ep_ret:[1353.3734] ep_len:[1000]
# [66/300] rollout:[9.4]s update:[4.9]s.
# [67/300] rollout:[9.4]s update:[4.3]s.
# [68/300] rollout:[9.3]s update:[3.8]s.
# [69/300] rollout:[9.3]s update:[4.0]s.
# [70/300] rollout:[9.3]s update:[4.5]s.
# [Eval. start] step:[70/300][23.0%] #step:[0.0e+00] time:[00:16:55] ram:[42.3%].
# [Evaluate] ep_ret:[1530.2863] ep_len:[1000]
# [71/300] rollout:[9.8]s update:[3.4]s.
# [72/300] rollout:[9.4]s update:[3.7]s.
# [73/300] rollout:[9.6]s update:[4.4]s.
# [74/300] rollout:[10.0]s update:[3.9]s.
# [75/300] rollout:[9.4]s update:[5.2]s.
# [Eval. start] step:[75/300][24.7%] #step:[0.0e+00] time:[00:18:06] ram:[42.3%].
# [Evaluate] ep_ret:[1560.1420] ep_len:[1000]
# [76/300] rollout:[9.5]s update:[3.6]s.
# [77/300] rollout:[9.4]s update:[3.3]s.
# [78/300] rollout:[9.5]s update:[4.3]s.
# [79/300] rollout:[9.2]s update:[4.1]s.
# [80/300] rollout:[9.3]s update:[3.9]s.
# [Eval. start] step:[80/300][26.3%] #step:[0.0e+00] time:[00:19:15] ram:[38.7%].
# [Evaluate] ep_ret:[1723.9906] ep_len:[1000]
# [81/300] rollout:[9.3]s update:[3.4]s.
# [82/300] rollout:[9.3]s update:[4.2]s.
# [83/300] rollout:[9.4]s update:[3.7]s.
# [84/300] rollout:[9.4]s update:[3.9]s.
# [85/300] rollout:[9.3]s update:[3.9]s.
# [Eval. start] step:[85/300][28.0%] #step:[0.0e+00] time:[00:20:23] ram:[38.8%].
# [Evaluate] ep_ret:[1694.5265] ep_len:[1000]
# [86/300] rollout:[9.5]s update:[4.8]s.
# [87/300] rollout:[9.2]s update:[4.4]s.
# [88/300] rollout:[9.2]s update:[4.0]s.
# [89/300] rollout:[9.2]s update:[3.7]s.
# [90/300] rollout:[9.5]s update:[3.3]s.
# [Eval. start] step:[90/300][29.7%] #step:[0.0e+00] time:[00:21:32] ram:[39.1%].
# [Evaluate] ep_ret:[1837.1004] ep_len:[1000]
# [91/300] rollout:[9.4]s update:[3.7]s.
# [92/300] rollout:[9.5]s update:[4.1]s.
# [93/300] rollout:[9.5]s update:[3.8]s.
# [94/300] rollout:[9.2]s update:[3.7]s.
# [95/300] rollout:[9.3]s update:[4.5]s.
# [Eval. start] step:[95/300][31.3%] #step:[0.0e+00] time:[00:22:41] ram:[39.2%].
# [Evaluate] ep_ret:[1813.5223] ep_len:[1000]
# [96/300] rollout:[9.5]s update:[3.8]s.
# [97/300] rollout:[9.2]s update:[4.5]s.
# [98/300] rollout:[9.2]s update:[3.6]s.
# [99/300] rollout:[9.1]s update:[4.0]s.
# [100/300] rollout:[9.2]s update:[3.8]s.
# [Eval. start] step:[100/300][33.0%] #step:[0.0e+00] time:[00:23:49] ram:[39.4%].
# [Evaluate] ep_ret:[1801.8640] ep_len:[1000]
# [101/300] rollout:[9.2]s update:[3.7]s.
# [102/300] rollout:[9.2]s update:[4.0]s.
# [103/300] rollout:[9.2]s update:[3.4]s.
# [104/300] rollout:[9.2]s update:[4.2]s.
# [105/300] rollout:[9.2]s update:[3.3]s.
# [Eval. start] step:[105/300][34.7%] #step:[0.0e+00] time:[00:24:56] ram:[39.6%].
# [Evaluate] ep_ret:[1864.7607] ep_len:[1000]
# [106/300] rollout:[9.1]s update:[3.9]s.
# [107/300] rollout:[9.2]s update:[3.9]s.
# [108/300] rollout:[9.4]s update:[4.2]s.
# [109/300] rollout:[9.1]s update:[3.8]s.
# [110/300] rollout:[9.2]s update:[3.6]s.
# [Eval. start] step:[110/300][36.3%] #step:[0.0e+00] time:[00:26:04] ram:[39.7%].
# [Evaluate] ep_ret:[1906.7421] ep_len:[1000]
# [111/300] rollout:[9.1]s update:[3.8]s.
# [112/300] rollout:[9.1]s update:[3.7]s.
# [113/300] rollout:[9.2]s update:[3.4]s.
# [114/300] rollout:[9.1]s update:[3.7]s.
# [115/300] rollout:[9.2]s update:[3.4]s.
# [Eval. start] step:[115/300][38.0%] #step:[0.0e+00] time:[00:27:10] ram:[39.9%].
# [Evaluate] ep_ret:[1941.5880] ep_len:[1000]
# [116/300] rollout:[9.4]s update:[3.3]s.
# [117/300] rollout:[9.9]s update:[3.4]s.
# [118/300] rollout:[9.3]s update:[3.5]s.
# [119/300] rollout:[9.5]s update:[3.5]s.
# [120/300] rollout:[9.4]s update:[3.4]s.
# [Eval. start] step:[120/300][39.7%] #step:[0.0e+00] time:[00:28:17] ram:[40.6%].
# [Evaluate] ep_ret:[1981.1747] ep_len:[1000]

# %% [markdown]
# ### Close

# %%
eval_env.close()

# %%
ray.shutdown()
