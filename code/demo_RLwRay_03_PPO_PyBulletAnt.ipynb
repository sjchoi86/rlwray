# %% [markdown]
# # Synchronous PPO with PyBullet Ant

# %%
import datetime,gym,os,pybullet_envs,time,os,psutil,ray
import numpy as np
import tensorflow as tf
from util import gpu_sess,suppress_tf_warning
from ppo import PPOBuffer,create_ppo_model,create_ppo_graph,update_ppo
np.set_printoptions(precision=2)
suppress_tf_warning() # suppress warning 
gym.logger.set_level(40) # gym logger 
print ("Packaged loaded. TF version is [%s]."%(tf.__version__))
# Out:
# Packaged loaded. TF version is [1.14.0].

# %% [markdown]
# ### Rollout Worker

# %%
def get_env():
    import pybullet_envs,gym
    gym.logger.set_level(40) # gym logger 
    return gym.make('AntBulletEnv-v0')

def get_eval_env():
    import pybullet_envs,gym
    gym.logger.set_level(40) # gym logger
    eval_env = gym.make('AntBulletEnv-v0')
    _ = eval_env.render(mode='human') # enable rendering
    _ = eval_env.reset()
    for _ in range(3): # dummy run for proper rendering 
        a = eval_env.action_space.sample()
        o,r,d,_ = eval_env.step(a)
        time.sleep(0.01)
    return eval_env

# %%
# Model
hdims = [256,256]
# Graph
clip_ratio = 0.2
pi_lr = 3e-4
vf_lr = 1e-3
# Buffer
steps_per_epoch = 5000
gamma = 0.99
lam = 0.95
# Update
train_pi_iters = 100
train_v_iters = 100
target_kl = 0.01
epochs = 1000
max_ep_len = 1000

# %%
class RolloutWorkerClass(object):
    """
    Worker without RAY (for update purposes)
    """
    def __init__(self,seed=1):
        self.seed = seed
        # Each worker should maintain its own environment
        import pybullet_envs,gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) # gym logger 
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        # Initialize PPO
        self.model,self.sess = create_ppo_model(env=self.env,hdims=hdims)
        self.graph = create_ppo_graph(self.model,
                                      clip_ratio=clip_ratio,pi_lr=pi_lr,vf_lr=vf_lr)
        # Initialize model 
        tf.set_random_seed(self.seed)
        np.random.seed(self.seed)
        self.sess.run(tf.global_variables_initializer())
        
    def get_action(self,o,deterministic=False):
        act_op = self.model['mu'] if deterministic else self.model['pi']
        return self.sess.run(act_op, feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
    
    def get_weights(self):
        """
        Get weights
        """
        weight_vals = self.sess.run(self.model['pi_vars']+self.model['v_vars'])
        return weight_vals
    
@ray.remote
class RayRolloutWorkerClass(object):
    """
    Rollout Worker with RAY
    """
    def __init__(self,worker_id=0,ep_len_rollout=1000):
        # Parse
        self.worker_id = worker_id
        self.ep_len_rollout = ep_len_rollout
        # Each worker should maintain its own environment
        import pybullet_envs,gym
        from util import suppress_tf_warning
        suppress_tf_warning() # suppress TF warnings
        gym.logger.set_level(40) # gym logger 
        self.env = get_env()
        odim,adim = self.env.observation_space.shape[0],self.env.action_space.shape[0]
        self.odim = odim
        self.adim = adim
        # Replay buffers to pass
        self.o_buffer = np.zeros((self.ep_len_rollout,self.odim))
        self.a_buffer = np.zeros((self.ep_len_rollout,self.adim))
        self.r_buffer = np.zeros((self.ep_len_rollout))
        self.v_t_buffer = np.zeros((self.ep_len_rollout))
        self.logp_t_buffer = np.zeros((self.ep_len_rollout))
        # Create PPO model
        self.model,self.sess = create_ppo_model(env=self.env,hdims=hdims)
        # Initialize model 
        self.sess.run(tf.global_variables_initializer())
        # Buffer
        self.buf = PPOBuffer(odim=self.odim,adim=self.adim,
                             size=ep_len_rollout,gamma=gamma,lam=lam)
        
        # Flag to initialize assign operations for 'set_weights()'
        self.FIRST_SET_FLAG = True
        
        # Flag to initialize rollout
        self.FIRST_ROLLOUT_FLAG = True
        
    def get_action(self,o,deterministic=False):
        act_op = self.model['mu'] if deterministic else self.model['pi']
        return self.sess.run(act_op, feed_dict={self.model['o_ph']:o.reshape(1,-1)})[0]
    
    def set_weights(self,weight_vals):
        """
        Set weights without memory leakage
        """
        if self.FIRST_SET_FLAG:
            self.FIRST_SET_FLAG = False
            self.assign_placeholders = []
            self.assign_ops = []
            for w_idx,weight_tf_var in enumerate(self.model['pi_vars']+self.model['v_vars']):
                a = weight_tf_var
                assign_placeholder = tf.placeholder(a.dtype, shape=a.get_shape())
                assign_op = a.assign(assign_placeholder)
                self.assign_placeholders.append(assign_placeholder)
                self.assign_ops.append(assign_op)
        for w_idx,weight_tf_var in enumerate(self.model['pi_vars']+self.model['v_vars']):
            self.sess.run(self.assign_ops[w_idx],
                          {self.assign_placeholders[w_idx]:weight_vals[w_idx]})    
        
    def rollout(self):
        """
        Rollout
        """
        if self.FIRST_ROLLOUT_FLAG:
            self.FIRST_ROLLOUT_FLAG = False
            self.o = self.env.reset() # reset environment
        # Loop
        for t in range(ep_len_rollout):
            a,v_t,logp_t = self.sess.run(
                self.model['get_action_ops'],feed_dict={self.model['o_ph']:self.o.reshape(1,-1)})
            o2, r, d, _ = self.env.step(a[0])
            # save and log
            self.buf.store(self.o,a,r,v_t,logp_t)
            # Update obs (critical!)
            self.o = o2
            if d:
                self.buf.finish_path(last_val=0.0)
                self.o = self.env.reset() # reset when done 
        
        last_val = self.sess.run(self.model['v'],
                                 feed_dict={self.model['o_ph']:self.o.reshape(1,-1)})
        self.buf.finish_path(last_val)
        return self.buf.get()

# %% [markdown]
# ### Initialize PyBullet Ant Environment

# %%
eval_env = get_eval_env()
adim,odim = eval_env.action_space.shape[0],eval_env.observation_space.shape[0]
print ("Environment Ready. odim:[%d] adim:[%d]."%(odim,adim))
# Out:
# Environment Ready. odim:[28] adim:[8].

# %%
n_cpu = n_workers = 15
total_steps,evaluate_every,print_every = 1000,5,1
ep_len_rollout = 5000
batch_size,update_count = 128,ep_len_rollout
num_eval,max_ep_len_eval = 3,1e3
buffer_size_long,buffer_size_short = 1e6,1e5

# %% [markdown]
# ### Initialize Workers

# %%
ray.init(num_cpus=n_cpu,
         memory = 5*1024*1024*1024,
         object_store_memory = 10*1024*1024*1024,
         driver_object_store_memory = 1*1024*1024*1024)
tf.reset_default_graph()
R = RolloutWorkerClass(seed=0)
workers = [RayRolloutWorkerClass.remote(worker_id=i,ep_len_rollout=ep_len_rollout) 
           for i in range(n_workers)]
print ("RAY initialized with [%d] cpus and [%d] workers."%
       (n_cpu,n_workers))
# Out:
# 2020-06-29 19:10:35,751	WARNING services.py:586 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-06-29 19:10:35,753	INFO resource_spec.py:212 -- Starting Ray with 4.98 GiB memory available for workers and up to 10.0 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-06-29 19:10:36,149	INFO services.py:1078 -- View the Ray dashboard at localhost:8266
# RAY initialized with [15] cpus and [15] workers.

# %%
time.sleep(1)

# %% [markdown]
# ### Loop

# %%
start_time = time.time()
n_env_step = 0 # number of environment steps
for t in range(int(total_steps)):
    esec = time.time()-start_time
    
    # Synchronize worker weights
    weights = R.get_weights()
    set_weights_list = [worker.set_weights.remote(weights) for worker in workers] 
    
    # Make rollout and accumulate to Buffers
    t_start = time.time()
    ops = [worker.rollout.remote() for worker in workers]
    rollout_vals = ray.get(ops)
    sec_rollout = time.time() - t_start
    
    # Get stats before update
    t_start = time.time()
    feeds_list = []
    for rollout_val in rollout_vals:
        feeds = {k:v for k,v in zip(R.model['all_phs'],rollout_val)}
        feeds_list.append(feeds)
        pi_l_old, v_l_old, ent = R.sess.run(
            [R.graph['pi_loss'],R.graph['v_loss'],R.graph['approx_ent']],feed_dict=feeds)
        
    # Update the central agent 
    for _ in range(train_pi_iters):
        for r_idx,rollout_val in enumerate(rollout_vals):
            feeds = feeds_list[r_idx]
            _, kl = R.sess.run([R.graph['train_pi'],R.graph['approx_kl']],feed_dict=feeds)
            if kl > 1.5 * target_kl:
                break
    for _ in range(train_v_iters):
        for r_idx,rollout_val in enumerate(rollout_vals):
            feeds = feeds_list[r_idx]
            R.sess.run(R.graph['train_v'],feed_dict=feeds)
    
    # Get stats after update
    for r_idx,rollout_val in enumerate(rollout_vals):
        feeds = feeds_list[r_idx]
        pi_l_new,v_l_new,kl,cf = R.sess.run(
            [R.graph['pi_loss'],R.graph['v_loss'],R.graph['approx_kl'],R.graph['clipfrac']],
            feed_dict=feeds)
    sec_update = time.time() - t_start
    
    # Print
    if (t == 0) or (((t+1)%print_every) == 0): 
        print ("[%d/%d] rollout:[%.1f]s update:[%.1f]s."%
               (t+1,total_steps,sec_rollout,sec_update))
        
    # Evaluate
    if (t==0) or (((t+1)%evaluate_every) == 0):
        ram_percent = psutil.virtual_memory().percent # memory usage
        print ("[Eval. start] step:[%d/%d][%.1f%%] #step:[%.1e] time:[%s] ram:[%.1f%%]."%
               (t+1,total_steps,t/total_steps*100,
                n_env_step,
                time.strftime("%H:%M:%S", time.gmtime(time.time()-start_time)),
                ram_percent)
              )
        o,d,ep_ret,ep_len = eval_env.reset(),False,0,0
        _ = eval_env.render(mode='human') 
        while not(d or (ep_len == max_ep_len)):
            a = R.sess.run(R.model['mu'],feed_dict={R.model['o_ph']:o.reshape(1,-1)})
            o,r,d,_ = eval_env.step(a[0])
            _ = eval_env.render(mode='human') 
            ep_ret += r # compute return 
            ep_len += 1
        print ("[Evaluate] ep_ret:[%.4f] ep_len:[%d]"%(ep_ret,ep_len))
    
print ("Done.")
# Out:
# [1/1000] rollout:[11.7]s update:[7.4]s.
# [Eval. start] step:[1/1000][0.0%] #step:[0.0e+00] time:[00:00:19] ram:[39.6%].
# [Evaluate] ep_ret:[479.5266] ep_len:[1000]
# [2/1000] rollout:[9.8]s update:[7.1]s.
# [3/1000] rollout:[9.8]s update:[7.1]s.
# [4/1000] rollout:[9.9]s update:[4.2]s.
# [5/1000] rollout:[9.8]s update:[4.6]s.
# [Eval. start] step:[5/1000][0.4%] #step:[0.0e+00] time:[00:01:23] ram:[39.8%].
# [Evaluate] ep_ret:[328.1227] ep_len:[1000]
# [6/1000] rollout:[9.7]s update:[7.1]s.
# [7/1000] rollout:[9.8]s update:[5.1]s.
# [8/1000] rollout:[9.8]s update:[6.7]s.
# [9/1000] rollout:[9.7]s update:[6.0]s.
# [10/1000] rollout:[9.6]s update:[6.1]s.
# [Eval. start] step:[10/1000][0.9%] #step:[0.0e+00] time:[00:02:45] ram:[40.0%].
# [Evaluate] ep_ret:[522.8531] ep_len:[1000]
# [11/1000] rollout:[9.7]s update:[6.5]s.
# [12/1000] rollout:[9.7]s update:[5.2]s.
# [13/1000] rollout:[9.6]s update:[6.6]s.
# [14/1000] rollout:[9.6]s update:[4.9]s.
# [15/1000] rollout:[9.6]s update:[6.3]s.
# [Eval. start] step:[15/1000][1.4%] #step:[0.0e+00] time:[00:04:06] ram:[40.2%].
# [Evaluate] ep_ret:[824.0325] ep_len:[1000]
# [16/1000] rollout:[9.6]s update:[5.1]s.
# [17/1000] rollout:[9.5]s update:[4.3]s.
# [18/1000] rollout:[9.6]s update:[5.6]s.
# [19/1000] rollout:[9.6]s update:[6.1]s.
# [20/1000] rollout:[9.6]s update:[6.0]s.
# [Eval. start] step:[20/1000][1.9%] #step:[0.0e+00] time:[00:05:23] ram:[40.3%].
# [Evaluate] ep_ret:[826.5650] ep_len:[1000]
# [21/1000] rollout:[9.5]s update:[5.6]s.
# [22/1000] rollout:[9.6]s update:[5.3]s.
# [23/1000] rollout:[9.5]s update:[5.2]s.
# [24/1000] rollout:[9.5]s update:[5.9]s.
# [25/1000] rollout:[9.5]s update:[5.3]s.
# [Eval. start] step:[25/1000][2.4%] #step:[0.0e+00] time:[00:06:40] ram:[40.5%].
# [Evaluate] ep_ret:[879.9304] ep_len:[1000]
# [26/1000] rollout:[9.5]s update:[5.4]s.
# [27/1000] rollout:[9.5]s update:[6.0]s.
# [28/1000] rollout:[9.5]s update:[5.0]s.
# [29/1000] rollout:[9.5]s update:[5.6]s.
# [30/1000] rollout:[9.5]s update:[4.7]s.
# [Eval. start] step:[30/1000][2.9%] #step:[0.0e+00] time:[00:07:57] ram:[40.7%].
# [Evaluate] ep_ret:[962.8094] ep_len:[1000]
# [31/1000] rollout:[9.6]s update:[5.3]s.
# [32/1000] rollout:[9.5]s update:[6.3]s.
# [33/1000] rollout:[9.4]s update:[4.8]s.
# [34/1000] rollout:[9.5]s update:[5.1]s.
# [35/1000] rollout:[9.4]s update:[4.9]s.
# [Eval. start] step:[35/1000][3.4%] #step:[0.0e+00] time:[00:09:13] ram:[40.9%].
# [Evaluate] ep_ret:[992.5845] ep_len:[1000]
# [36/1000] rollout:[9.4]s update:[5.1]s.
# [37/1000] rollout:[9.4]s update:[4.7]s.
# [38/1000] rollout:[9.4]s update:[4.4]s.
# [39/1000] rollout:[9.4]s update:[4.7]s.
# [40/1000] rollout:[9.5]s update:[4.3]s.
# [Eval. start] step:[40/1000][3.9%] #step:[0.0e+00] time:[00:10:26] ram:[41.0%].
# [Evaluate] ep_ret:[1276.5416] ep_len:[1000]
# [41/1000] rollout:[9.4]s update:[4.2]s.
# [42/1000] rollout:[9.5]s update:[4.2]s.
# [43/1000] rollout:[9.4]s update:[4.8]s.
# [44/1000] rollout:[9.4]s update:[5.3]s.
# [45/1000] rollout:[9.5]s update:[4.1]s.
# [Eval. start] step:[45/1000][4.4%] #step:[0.0e+00] time:[00:11:38] ram:[41.2%].
# [Evaluate] ep_ret:[1351.1580] ep_len:[1000]
# [46/1000] rollout:[9.4]s update:[5.2]s.
# [47/1000] rollout:[9.4]s update:[4.9]s.
# [48/1000] rollout:[9.4]s update:[4.5]s.
# [49/1000] rollout:[9.4]s update:[4.8]s.
# [50/1000] rollout:[9.4]s update:[3.8]s.
# [Eval. start] step:[50/1000][4.9%] #step:[0.0e+00] time:[00:12:50] ram:[41.4%].
# [Evaluate] ep_ret:[1471.5587] ep_len:[1000]
# [51/1000] rollout:[9.3]s update:[4.2]s.
# [52/1000] rollout:[9.3]s update:[4.5]s.
# [53/1000] rollout:[9.3]s update:[3.9]s.
# [54/1000] rollout:[9.3]s update:[4.9]s.
# [55/1000] rollout:[9.3]s update:[4.4]s.
# [Eval. start] step:[55/1000][5.4%] #step:[0.0e+00] time:[00:14:01] ram:[41.6%].
# [Evaluate] ep_ret:[1416.0249] ep_len:[1000]
# [56/1000] rollout:[9.3]s update:[5.2]s.
# [57/1000] rollout:[9.4]s update:[4.8]s.
# [58/1000] rollout:[9.4]s update:[5.2]s.
# [59/1000] rollout:[9.3]s update:[4.3]s.
# [60/1000] rollout:[9.4]s update:[4.5]s.
# [Eval. start] step:[60/1000][5.9%] #step:[0.0e+00] time:[00:15:14] ram:[41.8%].
# [Evaluate] ep_ret:[1500.0556] ep_len:[1000]
# [61/1000] rollout:[9.3]s update:[4.6]s.
# [62/1000] rollout:[9.3]s update:[3.9]s.
# [63/1000] rollout:[9.3]s update:[3.7]s.
# [64/1000] rollout:[9.3]s update:[4.4]s.
# [65/1000] rollout:[9.3]s update:[4.4]s.
# [Eval. start] step:[65/1000][6.4%] #step:[0.0e+00] time:[00:16:24] ram:[41.9%].
# [Evaluate] ep_ret:[1562.7314] ep_len:[1000]
# [66/1000] rollout:[9.3]s update:[4.2]s.
# [67/1000] rollout:[9.4]s update:[5.5]s.
# [68/1000] rollout:[9.3]s update:[4.4]s.
# [69/1000] rollout:[9.3]s update:[3.9]s.
# [70/1000] rollout:[9.4]s update:[4.2]s.
# [Eval. start] step:[70/1000][6.9%] #step:[0.0e+00] time:[00:17:36] ram:[42.1%].
# [Evaluate] ep_ret:[1602.0546] ep_len:[1000]
# [71/1000] rollout:[9.3]s update:[5.3]s.
# [72/1000] rollout:[9.4]s update:[4.3]s.
# [73/1000] rollout:[9.3]s update:[4.7]s.
# [74/1000] rollout:[9.5]s update:[4.5]s.
# [75/1000] rollout:[9.4]s update:[4.4]s.
# [Eval. start] step:[75/1000][7.4%] #step:[0.0e+00] time:[00:18:48] ram:[42.3%].
# [Evaluate] ep_ret:[1631.0137] ep_len:[1000]
# [76/1000] rollout:[9.3]s update:[4.2]s.
# [77/1000] rollout:[9.3]s update:[4.6]s.
# [78/1000] rollout:[9.4]s update:[4.4]s.
# [79/1000] rollout:[9.3]s update:[5.1]s.
# [80/1000] rollout:[9.4]s update:[4.2]s.
# [Eval. start] step:[80/1000][7.9%] #step:[0.0e+00] time:[00:19:59] ram:[42.5%].
# [Evaluate] ep_ret:[1651.1021] ep_len:[1000]
# [81/1000] rollout:[9.3]s update:[4.7]s.
# [82/1000] rollout:[9.3]s update:[3.7]s.
# [83/1000] rollout:[9.3]s update:[4.2]s.
# [84/1000] rollout:[9.3]s update:[4.4]s.
# [85/1000] rollout:[9.3]s update:[4.1]s.
# [Eval. start] step:[85/1000][8.4%] #step:[0.0e+00] time:[00:21:09] ram:[42.7%].
# [Evaluate] ep_ret:[1681.0072] ep_len:[1000]
# [86/1000] rollout:[9.3]s update:[4.0]s.
# [87/1000] rollout:[9.3]s update:[4.1]s.
# [88/1000] rollout:[9.3]s update:[4.0]s.
# [89/1000] rollout:[9.3]s update:[4.0]s.
# [90/1000] rollout:[9.3]s update:[4.4]s.
# [Eval. start] step:[90/1000][8.9%] #step:[0.0e+00] time:[00:22:18] ram:[42.9%].
# [Evaluate] ep_ret:[1727.8810] ep_len:[1000]
# [91/1000] rollout:[9.3]s update:[4.3]s.
# [92/1000] rollout:[9.3]s update:[4.4]s.
# [93/1000] rollout:[9.3]s update:[3.7]s.
# [94/1000] rollout:[9.3]s update:[3.6]s.
# [95/1000] rollout:[9.3]s update:[4.0]s.
# [Eval. start] step:[95/1000][9.4%] #step:[0.0e+00] time:[00:23:27] ram:[43.0%].
# [Evaluate] ep_ret:[1764.5728] ep_len:[1000]
# [96/1000] rollout:[9.3]s update:[3.5]s.
# [97/1000] rollout:[9.3]s update:[3.6]s.
# [98/1000] rollout:[9.3]s update:[3.8]s.
# [99/1000] rollout:[9.3]s update:[3.5]s.
# [100/1000] rollout:[9.3]s update:[4.7]s.
# [Eval. start] step:[100/1000][9.9%] #step:[0.0e+00] time:[00:24:35] ram:[43.2%].
# [Evaluate] ep_ret:[1764.3163] ep_len:[1000]
# [101/1000] rollout:[9.3]s update:[3.9]s.
# [102/1000] rollout:[9.3]s update:[4.4]s.
# [103/1000] rollout:[9.3]s update:[4.2]s.
# [104/1000] rollout:[9.3]s update:[5.1]s.
# [105/1000] rollout:[9.2]s update:[4.2]s.
# [Eval. start] step:[105/1000][10.4%] #step:[0.0e+00] time:[00:25:46] ram:[43.4%].
# [Evaluate] ep_ret:[1815.7711] ep_len:[1000]
# [106/1000] rollout:[9.3]s update:[4.2]s.
# [107/1000] rollout:[9.2]s update:[3.7]s.
# [108/1000] rollout:[9.3]s update:[4.3]s.
# [109/1000] rollout:[9.3]s update:[3.9]s.
# [110/1000] rollout:[9.3]s update:[3.9]s.
# [Eval. start] step:[110/1000][10.9%] #step:[0.0e+00] time:[00:26:54] ram:[43.6%].
# [Evaluate] ep_ret:[1852.3438] ep_len:[1000]
# [111/1000] rollout:[9.3]s update:[4.3]s.
# [112/1000] rollout:[9.3]s update:[4.1]s.
# [113/1000] rollout:[9.3]s update:[4.2]s.
# [114/1000] rollout:[9.2]s update:[3.7]s.
# [115/1000] rollout:[9.4]s update:[4.0]s.
# [Eval. start] step:[115/1000][11.4%] #step:[0.0e+00] time:[00:28:03] ram:[43.8%].
# [Evaluate] ep_ret:[1827.9658] ep_len:[1000]
# [116/1000] rollout:[9.3]s update:[3.7]s.
# [117/1000] rollout:[9.3]s update:[4.0]s.
# [118/1000] rollout:[9.2]s update:[3.8]s.
# [119/1000] rollout:[9.3]s update:[3.4]s.
# [120/1000] rollout:[9.3]s update:[4.2]s.
# [Eval. start] step:[120/1000][11.9%] #step:[0.0e+00] time:[00:29:11] ram:[43.9%].
# [Evaluate] ep_ret:[1850.8716] ep_len:[1000]
# [121/1000] rollout:[9.3]s update:[3.6]s.
# [122/1000] rollout:[9.3]s update:[4.4]s.
# [123/1000] rollout:[9.3]s update:[4.2]s.
# [124/1000] rollout:[9.2]s update:[3.8]s.
# [125/1000] rollout:[9.3]s update:[4.0]s.
# [Eval. start] step:[125/1000][12.4%] #step:[0.0e+00] time:[00:30:20] ram:[44.1%].
# [Evaluate] ep_ret:[1899.5366] ep_len:[1000]
# [126/1000] rollout:[9.2]s update:[3.5]s.
# [127/1000] rollout:[9.2]s update:[3.5]s.
# [128/1000] rollout:[9.2]s update:[3.5]s.
# [129/1000] rollout:[9.3]s update:[3.4]s.
# [130/1000] rollout:[9.2]s update:[4.1]s.
# [Eval. start] step:[130/1000][12.9%] #step:[0.0e+00] time:[00:31:26] ram:[44.3%].
# [Evaluate] ep_ret:[1825.0861] ep_len:[1000]
# [131/1000] rollout:[9.2]s update:[4.0]s.
# [132/1000] rollout:[9.3]s update:[3.5]s.
# [133/1000] rollout:[9.3]s update:[3.7]s.
# [134/1000] rollout:[9.3]s update:[3.9]s.
# [135/1000] rollout:[9.2]s update:[3.7]s.
# [Eval. start] step:[135/1000][13.4%] #step:[0.0e+00] time:[00:32:34] ram:[44.5%].
# [Evaluate] ep_ret:[1922.1983] ep_len:[1000]
# [136/1000] rollout:[9.2]s update:[4.0]s.
# [137/1000] rollout:[9.3]s update:[3.5]s.
# [138/1000] rollout:[9.3]s update:[4.3]s.
# [139/1000] rollout:[9.3]s update:[3.7]s.
# [140/1000] rollout:[9.2]s update:[3.6]s.
# [Eval. start] step:[140/1000][13.9%] #step:[0.0e+00] time:[00:33:41] ram:[44.6%].
# [Evaluate] ep_ret:[1850.6451] ep_len:[1000]
# [141/1000] rollout:[9.2]s update:[3.6]s.
# [142/1000] rollout:[9.3]s update:[3.5]s.
# [143/1000] rollout:[9.3]s update:[3.7]s.
# [144/1000] rollout:[9.3]s update:[4.2]s.
# [145/1000] rollout:[9.2]s update:[3.4]s.
# [Eval. start] step:[145/1000][14.4%] #step:[0.0e+00] time:[00:34:48] ram:[44.8%].
# [Evaluate] ep_ret:[1912.3892] ep_len:[1000]
# [146/1000] rollout:[9.2]s update:[3.8]s.
# [147/1000] rollout:[9.3]s update:[3.8]s.
# [148/1000] rollout:[9.3]s update:[3.5]s.
# [149/1000] rollout:[9.2]s update:[3.8]s.
# [150/1000] rollout:[9.3]s update:[3.5]s.
# [Eval. start] step:[150/1000][14.9%] #step:[0.0e+00] time:[00:35:55] ram:[45.0%].
# [Evaluate] ep_ret:[1925.8650] ep_len:[1000]
# [151/1000] rollout:[9.2]s update:[3.5]s.
# [152/1000] rollout:[9.3]s update:[3.7]s.
# [153/1000] rollout:[9.2]s update:[3.5]s.
# [154/1000] rollout:[9.3]s update:[3.6]s.
# [155/1000] rollout:[9.2]s update:[3.6]s.
# [Eval. start] step:[155/1000][15.4%] #step:[0.0e+00] time:[00:37:02] ram:[45.1%].
# [Evaluate] ep_ret:[1936.7346] ep_len:[1000]
# [156/1000] rollout:[9.2]s update:[3.7]s.
# [157/1000] rollout:[9.2]s update:[3.9]s.
# [158/1000] rollout:[9.2]s update:[3.4]s.
# [159/1000] rollout:[9.2]s update:[3.4]s.
# [160/1000] rollout:[9.3]s update:[3.5]s.
# [Eval. start] step:[160/1000][15.9%] #step:[0.0e+00] time:[00:38:08] ram:[45.3%].
# [Evaluate] ep_ret:[1915.4077] ep_len:[1000]
# [161/1000] rollout:[9.3]s update:[3.7]s.
# [162/1000] rollout:[9.3]s update:[3.9]s.
# [163/1000] rollout:[9.3]s update:[3.6]s.
# [164/1000] rollout:[9.2]s update:[3.4]s.
# [165/1000] rollout:[9.2]s update:[3.7]s.
# [Eval. start] step:[165/1000][16.4%] #step:[0.0e+00] time:[00:39:15] ram:[45.5%].
# [Evaluate] ep_ret:[1966.1500] ep_len:[1000]
# [166/1000] rollout:[9.2]s update:[3.6]s.
# [167/1000] rollout:[9.2]s update:[3.8]s.
# [168/1000] rollout:[9.3]s update:[3.5]s.
# [169/1000] rollout:[9.2]s update:[3.5]s.
# [170/1000] rollout:[9.3]s update:[3.7]s.
# [Eval. start] step:[170/1000][16.9%] #step:[0.0e+00] time:[00:40:22] ram:[45.7%].
# [Evaluate] ep_ret:[1964.7867] ep_len:[1000]
# [171/1000] rollout:[9.2]s update:[4.2]s.
# [172/1000] rollout:[9.2]s update:[3.6]s.
# [173/1000] rollout:[9.2]s update:[3.8]s.
# [174/1000] rollout:[9.3]s update:[3.6]s.
# [175/1000] rollout:[9.2]s update:[3.6]s.
# [Eval. start] step:[175/1000][17.4%] #step:[0.0e+00] time:[00:41:29] ram:[45.9%].
# [Evaluate] ep_ret:[1933.7276] ep_len:[1000]
# [176/1000] rollout:[9.2]s update:[3.6]s.
# [177/1000] rollout:[9.3]s update:[3.4]s.
# [178/1000] rollout:[9.2]s update:[3.5]s.
# [179/1000] rollout:[9.3]s update:[3.7]s.
# [180/1000] rollout:[9.3]s update:[3.8]s.
# [Eval. start] step:[180/1000][17.9%] #step:[0.0e+00] time:[00:42:36] ram:[46.1%].
# [Evaluate] ep_ret:[1969.0330] ep_len:[1000]
# [181/1000] rollout:[9.3]s update:[3.6]s.
# [182/1000] rollout:[9.3]s update:[3.5]s.
# [183/1000] rollout:[9.2]s update:[3.5]s.
# [184/1000] rollout:[9.2]s update:[3.8]s.
# [185/1000] rollout:[9.3]s update:[4.0]s.
# [Eval. start] step:[185/1000][18.4%] #step:[0.0e+00] time:[00:43:43] ram:[46.2%].
# [Evaluate] ep_ret:[1940.4997] ep_len:[1000]
# [186/1000] rollout:[9.2]s update:[3.7]s.
# [187/1000] rollout:[9.2]s update:[3.7]s.
# [188/1000] rollout:[9.3]s update:[3.4]s.
# [189/1000] rollout:[9.2]s update:[3.4]s.
# [190/1000] rollout:[9.2]s update:[3.5]s.
# [Eval. start] step:[190/1000][18.9%] #step:[0.0e+00] time:[00:44:49] ram:[46.4%].
# [Evaluate] ep_ret:[1941.4577] ep_len:[1000]
# [191/1000] rollout:[9.2]s update:[3.5]s.
# [192/1000] rollout:[9.2]s update:[3.5]s.
# [193/1000] rollout:[9.3]s update:[3.9]s.
# [194/1000] rollout:[9.3]s update:[3.9]s.
# [195/1000] rollout:[9.2]s update:[3.7]s.
# [Eval. start] step:[195/1000][19.4%] #step:[0.0e+00] time:[00:45:56] ram:[46.6%].
# [Evaluate] ep_ret:[1964.9956] ep_len:[1000]
# [196/1000] rollout:[9.2]s update:[4.1]s.
# [197/1000] rollout:[9.3]s update:[3.7]s.
# [198/1000] rollout:[9.2]s update:[3.4]s.
# [199/1000] rollout:[9.3]s update:[3.4]s.
# [200/1000] rollout:[9.3]s update:[3.4]s.
# [Eval. start] step:[200/1000][19.9%] #step:[0.0e+00] time:[00:47:02] ram:[46.8%].
# [Evaluate] ep_ret:[1962.2061] ep_len:[1000]
# [201/1000] rollout:[9.3]s update:[3.6]s.
# [202/1000] rollout:[9.2]s update:[3.5]s.
# [203/1000] rollout:[9.2]s update:[3.7]s.
# [204/1000] rollout:[9.2]s update:[3.5]s.
# [205/1000] rollout:[9.3]s update:[3.5]s.
# [Eval. start] step:[205/1000][20.4%] #step:[0.0e+00] time:[00:48:09] ram:[47.0%].
# [Evaluate] ep_ret:[1981.7035] ep_len:[1000]
# [206/1000] rollout:[9.3]s update:[3.5]s.
# [207/1000] rollout:[9.2]s update:[3.6]s.
# [208/1000] rollout:[9.3]s update:[3.8]s.
# [209/1000] rollout:[9.3]s update:[3.4]s.
# [210/1000] rollout:[9.3]s update:[3.6]s.
# [Eval. start] step:[210/1000][20.9%] #step:[0.0e+00] time:[00:49:15] ram:[47.2%].
# [Evaluate] ep_ret:[2005.8887] ep_len:[1000]
# [211/1000] rollout:[9.2]s update:[3.6]s.
# [212/1000] rollout:[9.3]s update:[3.7]s.
# [213/1000] rollout:[9.2]s update:[4.0]s.
# [214/1000] rollout:[9.2]s update:[3.5]s.
# [215/1000] rollout:[9.2]s update:[3.5]s.
# [Eval. start] step:[215/1000][21.4%] #step:[0.0e+00] time:[00:50:22] ram:[47.3%].
# [Evaluate] ep_ret:[1995.7425] ep_len:[1000]
# [216/1000] rollout:[9.2]s update:[3.5]s.
# [217/1000] rollout:[9.3]s update:[3.8]s.
# [218/1000] rollout:[9.3]s update:[3.5]s.
# [219/1000] rollout:[9.3]s update:[3.4]s.
# [220/1000] rollout:[9.2]s update:[3.6]s.
# [Eval. start] step:[220/1000][21.9%] #step:[0.0e+00] time:[00:51:28] ram:[47.5%].
# [Evaluate] ep_ret:[1952.1496] ep_len:[1000]
# [221/1000] rollout:[9.3]s update:[3.5]s.
# [222/1000] rollout:[9.3]s update:[3.5]s.
# [223/1000] rollout:[9.3]s update:[3.8]s.
# [224/1000] rollout:[9.3]s update:[3.3]s.
# [225/1000] rollout:[9.2]s update:[3.6]s.
# [Eval. start] step:[225/1000][22.4%] #step:[0.0e+00] time:[00:52:34] ram:[47.7%].
# [Evaluate] ep_ret:[1920.0951] ep_len:[1000]
# [226/1000] rollout:[9.2]s update:[3.6]s.
# [227/1000] rollout:[9.2]s update:[3.3]s.
# [228/1000] rollout:[9.2]s update:[3.7]s.
# [229/1000] rollout:[9.2]s update:[4.0]s.
# [230/1000] rollout:[9.2]s update:[3.8]s.
# [Eval. start] step:[230/1000][22.9%] #step:[0.0e+00] time:[00:53:41] ram:[47.9%].
# [Evaluate] ep_ret:[2005.6380] ep_len:[1000]
# [231/1000] rollout:[9.2]s update:[3.7]s.
# [232/1000] rollout:[9.2]s update:[3.5]s.
# [233/1000] rollout:[9.5]s update:[3.7]s.
# [234/1000] rollout:[9.3]s update:[3.5]s.
# [235/1000] rollout:[9.2]s update:[3.5]s.
# [Eval. start] step:[235/1000][23.4%] #step:[0.0e+00] time:[00:54:48] ram:[48.0%].
# [Evaluate] ep_ret:[1995.2471] ep_len:[1000]
# [236/1000] rollout:[9.4]s update:[3.4]s.
# [237/1000] rollout:[9.2]s update:[3.5]s.
# [238/1000] rollout:[9.2]s update:[3.6]s.
# [239/1000] rollout:[9.2]s update:[3.5]s.
# [240/1000] rollout:[9.2]s update:[3.6]s.
# [Eval. start] step:[240/1000][23.9%] #step:[0.0e+00] time:[00:55:54] ram:[48.2%].
# [Evaluate] ep_ret:[1994.2083] ep_len:[1000]
# [241/1000] rollout:[9.2]s update:[3.8]s.
# [242/1000] rollout:[9.2]s update:[3.4]s.
# [243/1000] rollout:[9.3]s update:[3.5]s.
# [244/1000] rollout:[9.2]s update:[3.5]s.
# [245/1000] rollout:[9.2]s update:[3.6]s.
# [Eval. start] step:[245/1000][24.4%] #step:[0.0e+00] time:[00:57:00] ram:[48.4%].
# [Evaluate] ep_ret:[1981.8359] ep_len:[1000]
# [246/1000] rollout:[9.3]s update:[3.6]s.
# [247/1000] rollout:[9.6]s update:[3.6]s.
# [248/1000] rollout:[9.4]s update:[3.5]s.
# [249/1000] rollout:[9.2]s update:[3.5]s.
# [250/1000] rollout:[9.4]s update:[3.5]s.
# [Eval. start] step:[250/1000][24.9%] #step:[0.0e+00] time:[00:58:07] ram:[48.6%].
# [Evaluate] ep_ret:[1904.1268] ep_len:[1000]

# %% [markdown]
# ### Close

# %%
eval_env.close()
